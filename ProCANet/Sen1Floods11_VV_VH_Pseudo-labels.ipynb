# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install segmentation_models_pytorch
# !pip install git+https://github.com/lucasb-eyer/pydensecrf.git
# Out:
# Collecting segmentation_models_pytorch
#   Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: huggingface-hub>=0.24 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (0.31.2)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (2.0.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (11.2.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (0.5.3)
# Requirement already satisfied: timm>=0.9 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (1.0.15)
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8->segmentation_models_pytorch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8->segmentation_models_pytorch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (2025.4.26)
# Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 5.2 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 119.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 101.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 62.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 9.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 18.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 10.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 43.9 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, segmentation_models_pytorch
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 segmentation_models_pytorch-0.5.0
# Collecting git+https://github.com/lucasb-eyer/pydensecrf.git
#   Cloning https://github.com/lucasb-eyer/pydensecrf.git to /tmp/pip-req-build-v1_n9zpi
#   Running command git clone --filter=blob:none --quiet https://github.com/lucasb-eyer/pydensecrf.git /tmp/pip-req-build-v1_n9zpi
#   Resolved https://github.com/lucasb-eyer/pydensecrf.git to commit 2723c7fa4f2ead16ae1ce3d8afe977724bb8f87f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: pydensecrf
#   Building wheel for pydensecrf (pyproject.toml) ... done
#   Created wheel for pydensecrf: filename=pydensecrf-1.0-cp311-cp311-linux_x86_64.whl size=3440332 sha256=8e0822be5a646a98791dac1cf6a8f08f3ec1335281e0287b4bdca91569c931a5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-82s4n6w3/wheels/ce/8e/34/6dcfa200a9e2ae3627d8009b8bd1ca9b24512bec50a93304de
# Successfully built pydensecrf
# Installing collected packages: pydensecrf
# Successfully installed pydensecrf-1.0

# %%
import numpy as np
import segmentation_models_pytorch as smp
import torch
import os
import cv2
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, BoundaryNorm
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
import torch.nn as nn
import torch.nn.functional as F
import glob
from tqdm import tqdm
import albumentations as A
import tifffile
from torch.amp import autocast
from torch.amp import GradScaler
import logging
import pydensecrf.densecrf as dcrf
from pydensecrf.utils import unary_from_softmax, create_pairwise_gaussian, create_pairwise_bilateral
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.7' (you have '2.0.6'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
# !cp -r /content/drive/MyDrive/datasets_and_models/Pseudo-labels.zip /content/

# %%
# !unzip /content/Pseudo-labels.zip -d /
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_4_8306831_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_4_7358602_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_2_1714083_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_5231011_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_4_4048847_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_2_6027540_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Pakistan_2_1845772_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Sri-Lanka_4_9864720_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_4_9081352_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Sri-Lanka_2_2244305_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Sri-Lanka_3_551926_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_3_3278525_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_7751959_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_3_698338_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_3_7972821_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Ghana_4_247288_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Somalia_4_9481308_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_1_6796279_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_1_4245955_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_4_54421_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_3876222_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_8074049_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_4_7762884_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Spain_2_829579_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_2_5401982_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_1167947_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Spain_4_8268095_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Spain_4_1008288_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_2_9094316_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Bolivia_1_1966339_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_1_9237623_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_3_686604_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_3_4347691_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_4_5189300_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_2_438959_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_2_7942751_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_1_1011124_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_2_126224_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_2_6507403_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_1_909852_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_2_1391250_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_3_7923821_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_2865784_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_4501244_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_2838950_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Pakistan_2_6236200_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_4_9569854_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_3_5223338_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_3_605492_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_3_5179723_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_4_99909_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_2_848098_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_2_8428819_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_2_5438112_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Sri-Lanka_3_7504399_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_1_526005_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_1_8043790_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_3_232060_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_2_260929_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_1_5353218_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Ghana_4_1758500_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_3_2397799_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_2_6137087_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_9832629_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Sri-Lanka_2_748447_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Ghana_4_9944411_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Ghana_3_362274_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_728428_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_3642264_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Sri-Lanka_2_9621199_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_2_2513384_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Spain_4_8896493_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Somalia_1_8883386_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_1_2856694_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Somalia_2_886726_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_1841048_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_1_7091729_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Bolivia_2_6650924_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_3_265762_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_2_3795004_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_2_1796024_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_3_9628001_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_2_778143_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_2_7664214_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Sri-Lanka_1_2921607_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_3_2619614_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_1919660_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Nigeria_2_4281646_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_1_2051222_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_7821035_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_2_7634386_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_8417481_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_3895245_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_3_9046542_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Pakistan_1_246718_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_3_9027931_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_2_4125237_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_3_984611_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Spain_3_6059242_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_1_6655394_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_4_2672600_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Bolivia_4_4254793_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Spain_4_5268031_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_8570686_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_6205290_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Ghana_3_3335866_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_3_1930030_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_2_7091729_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_7945482_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Nigeria_1_3498415_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_3338823_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_963615_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_2_8985157_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Ghana_1_187318_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Spain_4_2644267_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_2_2585161_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_4_218546_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_4947020_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_8137564_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_2_5339058_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Ghana_2_6666049_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_4_5730123_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_335839_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Pakistan_2_146612_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_83755_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_3_8208025_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_2_156441_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_1_4256340_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_2_2052432_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_9713086_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_3_4023576_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_4_8064659_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Spain_1_4489691_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Spain_3_6119583_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_8633809_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Ghana_2_5526358_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Pakistan_4_1739575_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_9964146_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_546489_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_231955_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_2_1335806_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_1_6780993_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Nigeria_2_4869588_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Bolivia_4_4304185_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_1233832_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_4_8214347_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_4_3270236_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_2_9358756_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_3_9000558_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_2_6746841_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_3_6942054_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_7710539_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Pakistan_3_4738261_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_4210659_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Ghana_1_3335866_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_4_7410308_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_9692206_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Pakistan_3_2470997_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_2_5593307_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_1_2717123_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_1_943439_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Spain_1_4708203_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Sri-Lanka_1_3514923_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_3_482517_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_738351_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_3_7923882_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_7210733_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_3_8140977_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Sri-Lanka_3_7529814_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_1_8011014_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_7434407_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_1_5975012_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_3_5188429_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_3_7920109_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_4_375183_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_636219_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_3_6013156_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Nigeria_2_2578703_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Somalia_2_5541589_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_3524214_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_2_8298592_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Ghana_3_9373845_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_5698664_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_1_7417531_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Nigeria_2_7588469_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Pakistan_2_6958079_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Sri-Lanka_3_8939201_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_3_4527121_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_2_7379982_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_4_3261326_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_6611636_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_3057982_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_3_7798069_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Pakistan_3_2486610_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Bolivia_2_4138146_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_8654764_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_4_9000558_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_3_5097875_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_2_232060_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_3940964_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Nigeria_3_305031_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_2_5678600_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_8307611_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Somalia_3_7722308_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_2_953694_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_3_2018992_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_3_4171067_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_8990099_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_1_5478840_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Bolivia_3_7504428_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_4_6102900_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Bolivia_4_4551893_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_2_2344275_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_9278469_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_1595825_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_4_732556_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Somalia_4_383050_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_2_1843962_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_3218845_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_3576044_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_4_9916755_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_4270148_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Sri-Lanka_1_7792665_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_4_8361406_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Pakistan_3_7312986_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_2_9173901_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_1_4277664_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Pakistan_4_9071061_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_4_2398903_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_4_8748465_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_4_36146_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_1_786110_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_4_3171033_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_3_5002311_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Bolivia_1_1465379_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_2_392774_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_1_1114651_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_2960552_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_8801533_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_221509_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_2_2434853_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_4_3350804_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_1_3737312_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Sri-Lanka_1_6450196_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_1_3474345_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_584693_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_3_9190647_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_4_4883638_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_1_9060557_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_1_6970963_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_6833981_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_1_842775_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_3_3992299_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_2_6383448_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Bolivia_1_4090235_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Sri-Lanka_1_1074964_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_1_7499357_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_4_8871992_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_2_6314481_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_3_519071_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_3369723_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_2_6039078_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Somalia_2_3841405_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Bolivia_2_3059419_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_5002311_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_9924180_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_9304094_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_1_6759884_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_3_8059625_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Pakistan_2_6230618_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_4_5612039_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_8369112_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_4_4171067_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Spain_3_3941490_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_3_3793080_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_1_8985157_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Pakistan_3_4780492_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_4_9842688_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_7108305_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Ghana_2_362274_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_8758086_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_2_3448721_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_4_2348670_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Sri-Lanka_4_92824_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Somalia_2_6241684_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_3_4588084_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_3_1335617_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_7694776_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_2_2423316_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_4270148_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_9596351_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_5632549_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_7454361_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_5560614_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Nigeria_4_5272150_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_4_7801714_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_3_234470_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_1_3253224_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_7513366_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_4_7163359_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Somalia_2_7722308_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_3_5962075_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_4_5576194_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_8998047_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_3237207_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Spain_1_4734852_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_1_3229730_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_4_8171281_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_254524_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_5172654_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_1_3436653_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_8990099_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Pakistan_1_3006755_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_4_2923887_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_1_2347405_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_7994968_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_2_817096_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Spain_1_1262965_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_4996556_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_3_3726706_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Pakistan_1_6278779_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_1_181263_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_4_305270_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_2615980_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_3_9612365_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Spain_3_7356477_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_4_4515189_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_1_5216001_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Ghana_1_953791_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_545558_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_4_8428819_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_4_9017167_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_984611_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_5835847_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_4_3727555_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_1797992_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_3_9303709_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_963615_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_1_6812921_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_1_5539076_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_1_4485617_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_2_7226040_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_4_6222790_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_3_9961724_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_2_5912077_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_4_3740774_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_288497_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_3466065_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_3_8302962_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Bolivia_4_6485383_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_4_387945_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Ghana_3_7136337_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_3_7963941_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Pakistan_3_697548_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Ghana_1_7458277_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_1809445_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Pakistan_2_9832340_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_3_5816642_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_4_6759884_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_1_9628001_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_3_4216784_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_8602616_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_9295514_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_2_414996_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Spain_4_2491267_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_2_224845_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_4_3567835_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_9612365_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_1_9298147_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_1_9586613_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_3_5210911_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_1_6814744_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_6228259_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Pakistan_4_5560961_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Ghana_1_2832370_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_5246797_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_4_5575140_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_9893548_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_2_5197713_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Ghana_2_262437_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Ghana_4_4325636_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Pakistan_2_428373_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Spain_1_7612190_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Spain_1_2751173_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Pakistan_2_7762986_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_1_9466008_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_4_6300221_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_3_2043588_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_342411_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_4_9587418_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_2_9668511_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Nigeria_3_9950933_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_3_1922595_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_1_1380465_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_3_9599907_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_1_1585736_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Pakistan_3_4331468_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/India_3_8641929_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_4_719490_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_1_9342885_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_4_8248346_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Pakistan_1_1003422_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_9932473_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_4_7522985_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Somalia_3_2041382_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_227053_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_2_8171281_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Sri-Lanka_4_6546724_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Sri-Lanka_2_8743504_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Sri-Lanka_2_3776919_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Ghana_2_2752406_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_9973702_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_4_5869138_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Ghana_1_5262455_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/USA_1_3652823_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Sri-Lanka_3_5887708_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Colombia_3_5216001_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Paraguay_1_5556148_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_3_7060425_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Somalia_4_9488639_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Bolivia_4_8992052_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Ghana_4_4582075_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Ghana_3_3732879_S1Weak.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/VV_VH/Mekong_2_543016_S1Weak.tif
# ...
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/India_3_56450_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/USA_4_652955_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Pakistan_2_246510_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/India_1_500266_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/India_3_534470_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Mekong_1_1191208_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Spain_4_8104659_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Nigeria_1_952958_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Ghana_4_135389_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Paraguay_3_36015_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Mekong_4_269835_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Sri-Lanka_2_653336_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/India_1_285297_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/India_1_103447_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Spain_4_5816638_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Pakistan_4_909806_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/USA_4_348639_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/USA_2_11422_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Paraguay_3_149830_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Sri-Lanka_1_400518_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Sri-Lanka_1_883641_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Paraguay_4_403081_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Pakistan_2_401863_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Paraguay_2_24341_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Ghana_3_49890_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Sri-Lanka_1_233609_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/India_1_534470_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Pakistan_2_667363_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/India_4_179238_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/India_2_698338_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Sri-Lanka_3_551926_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/India_3_698338_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Ghana_4_247288_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Paraguay_4_54421_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/USA_2_438959_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Paraguay_2_126224_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/USA_3_605492_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/USA_3_232060_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/USA_2_260929_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Sri-Lanka_2_748447_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Ghana_3_362274_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Somalia_2_886726_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/India_3_265762_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Pakistan_1_246718_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Ghana_1_187318_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/India_1_943439_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Paraguay_3_482517_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/USA_4_375183_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/USA_2_232060_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Paraguay_4_36146_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/India_1_842775_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Ghana_2_362274_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Sri-Lanka_4_92824_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/USA_1_181263_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Ghana_1_953791_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/USA_4_387945_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Paraguay_2_224845_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Mekong_2_342411_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/USA_1_114964_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Ghana_4_161233_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Ghana_3_97516_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Ghana_3_11745_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Ghana_3_103272_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Sri-Lanka_3_92824_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Pakistan_2_740461_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/India_4_136196_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/India_1_287642_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Paraguay_4_191503_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Mekong_4_342411_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Sri-Lanka_2_120804_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/USA_3_655230_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Somalia_2_195014_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Somalia_3_1087508_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/USA_4_994009_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Mekong_1_846007_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Pakistan_4_1036366_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Paraguay_3_1029042_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Ghana_1_887131_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/USA_2_84195_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Paraguay_4_921838_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/USA_4_1068362_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Sri-Lanka_1_748447_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/India_1_566697_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Pakistan_3_401863_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/USA_2_908474_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Mekong_4_1248200_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Mekong_4_52610_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Mekong_4_1439641_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/India_2_287642_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Sri-Lanka_2_92824_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Ghana_3_24858_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/India_2_591549_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Paraguay_3_62897_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Ghana_4_7496_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Paraguay_1_224845_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Ghana_4_597288_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Somalia_2_7931_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Mekong_2_16233_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Ghana_2_135389_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Nigeria_3_143329_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Sri-Lanka_3_233609_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Sri-Lanka_3_55568_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Sri-Lanka_1_163406_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Sri-Lanka_1_92824_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Nigeria_2_707067_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Paraguay_2_822142_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/USA_1_170264_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/USA_1_86502_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Somalia_3_1068756_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Mekong_3_269835_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/USA_2_604222_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Ghana_3_194723_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Paraguay_2_1056717_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Spain_2_2938657_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/USA_2_354981_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/USA_1_604222_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Paraguay_4_1056717_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/USA_3_638521_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Spain_2_3285448_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Pakistan_3_1036366_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Spain_1_2472849_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/India_2_373039_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Paraguay_2_44682_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/USA_1_224165_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Paraguay_3_149787_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Sri-Lanka_1_845821_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Mekong_1_342411_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Sri-Lanka_1_49764_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/USA_4_955053_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Pakistan_3_712873_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Paraguay_3_12870_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Paraguay_3_791364_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Pakistan_4_132143_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/USA_3_181263_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Nigeria_4_600295_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Paraguay_3_54421_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Spain_3_2523247_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Sri-Lanka_4_653336_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Somalia_2_989553_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/USA_1_655230_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Paraguay_3_212687_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Paraguay_3_148318_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/India_1_373039_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/Paraguay_4_126224_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled/VV_VH/India_2_265762_S1Hand.tif

# %%
# Параметры конфигурации
train_dir = "/content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels"
validation_dir = "/content/dataset_sen1floods11_RGB_NIR_VV_VH/validation"
test_dir = "/content/dataset_sen1floods11_RGB_NIR_VV_VH/test"
test_Bolivia_dir = "/content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia"
local_batch_size = 64
learning_rate = 1e-3
num_epochs = 100
model_serialization = "ProCANet"
folder = "ProCANet"
channels = "VV_VH"
data = "Pseudo-labels"

# %%
# Предопределённые списки для преобразований D4 и их инверсии
D4_TRANSFORMS = [
    lambda x: x,                                 # I
    lambda x: torch.rot90(x, 1, [2, 3]),         # R90
    lambda x: torch.rot90(x, 2, [2, 3]),         # R180
    lambda x: torch.rot90(x, 3, [2, 3]),         # R270
    lambda x: torch.flip(x, [3]),                # F
    lambda x: torch.rot90(torch.flip(x, [3]), 1, [2, 3]),  # F_R90
    lambda x: torch.rot90(torch.flip(x, [3]), 2, [2, 3]),  # F_R180
    lambda x: torch.rot90(torch.flip(x, [3]), 3, [2, 3]),  # F_R270
]

INVERSE_TRANSFORMS = [
    lambda x: x,                                 # I
    lambda x: torch.rot90(x, -1, [2, 3]),        # R90
    lambda x: torch.rot90(x, -2, [2, 3]),        # R180
    lambda x: torch.rot90(x, -3, [2, 3]),        # R270
    lambda x: torch.flip(x, [3]),                # F
    lambda x: torch.flip(torch.rot90(x, -1, [2, 3]), [3]),  # F_R90
    lambda x: torch.flip(torch.rot90(x, -2, [2, 3]), [3]),  # F_R180
    lambda x: torch.flip(torch.rot90(x, -3, [2, 3]), [3]),  # F_R270
]

# %%
transform = A.Compose([
    A.HorizontalFlip(p = 0.5),
    A.RandomRotate90(p = 0.5),
    A.VerticalFlip(p = 0.5)
])

# %%
def get_filename(filepath):
    return os.path.split(filepath)[1]

# %%
def create_df(main_dir):
    vv_vh_image_paths = sorted(glob.glob(main_dir + '/VV_VH/*.tif', recursive=True))
    vv_vh_image_names = [get_filename(pth) for pth in vv_vh_image_paths]
    mask_paths = []

    for i in range(len(vv_vh_image_paths)):
        # Путь к изображению vh
        mask_name = vv_vh_image_names[i]
        parts = mask_name.split('_')
        mask_name = '_'.join(parts[:3]) + '_'

        if 'Weak' in parts[3]:
            a = "Pseudo-label"
        elif 'Hand' in parts[3]:
            a = "LabelHand"

        mask_path = os.path.join(
            main_dir, "Label", f"{mask_name}{a}.tif"
        )
        mask_paths.append(mask_path)

    paths = {
        "vv_vh_image_path": vv_vh_image_paths,
        "mask_path": mask_paths,
    }

    return pd.DataFrame(paths)

# %%
class MyDataset(Dataset):
    def __init__(self, dataframe, split, transform=None):
        self.split = split
        self.dataset = dataframe
        self.transform = transform

    def __len__(self):
        return self.dataset.shape[0]

    def __getitem__(self, index):

        row = self.dataset.iloc[index]
        img_path = row["vv_vh_image_path"]
        mask_path = row["mask_path"]

        # Загружаем 2-канальное изображение TIFF (VV, VH)
        image = tifffile.imread(img_path).astype(np.float32)
        image = np.nan_to_num(image, 0)

        # Нормируем [0, 1]
        image = np.clip(image, -35, 3)
        image = (image + 35.0)/38.0

        image = image.transpose(1, 2, 0)  # (H, W, 2), каналы: VV, VH

        # Вычисляем ratio и добавляем как третий канал
        VV = image[:, :, 0]
        VH = image[:, :, 1]
        ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
        ratio = ratio[:, :, np.newaxis]

        # Объединяем в трёхканальное изображение (VV, VH, ratio)
        image = np.concatenate((image, ratio), axis=2)

        # Загружаем маску (одноканальная)
        mask = tifffile.imread(mask_path).astype(np.int64)

        # Аугментация только для train
        if self.split == "train" and self.transform is not None:
            augmented = self.transform(image=image, mask=mask)
            image = augmented["image"]
            mask = augmented["mask"]

        # Транспонируем каналы для PyTorch (C, H, W)
        image = image.transpose(2, 0, 1)

        return {
                "image": torch.from_numpy(image.astype(np.float32)),
                "mask": torch.from_numpy(mask).long()
            }

# %%
def calculate_TP_FP_TN_FN(pred, target):
    # Получаем предсказанные метки (из логитов)
    pred_labels = pred.argmax(dim=1)  # dim=1 — классы, на выходе (B, H, W)

    TP = ((pred_labels == 1) & (target == 1)).sum().item()
    FP = ((pred_labels == 1) & (target == 0)).sum().item()
    TN = ((pred_labels == 0) & (target == 0)).sum().item()
    FN = ((pred_labels == 0) & (target == 1)).sum().item()

    return float(TP), float(FP), float(TN), float(FN), float(TN), float(FN), float(TP), float(FP)

# %%
def calculate_metrics(TP_flood, FP_flood, TN_flood, FN_flood, TP_background, FP_background, TN_background, FN_background):
    Accuracy = (TP_flood + TN_flood)/(TP_flood + FP_flood + TN_flood + FN_flood + 1e-6)
    IoU_flood = TP_flood/(TP_flood + FP_flood + FN_flood + 1e-6)
    IoU_background = TP_background/(TP_background + FP_background + FN_background + 1e-6)
    IoU = (IoU_flood + IoU_background)/2
    Dice_flood = 2*TP_flood/(2*TP_flood + FP_flood + FN_flood + 1e-6)
    Dice_background = 2*TP_background/(2*TP_background + FP_background + FN_background + 1e-6)
    Dice = (Dice_flood + Dice_background)/2
    Precision_flood = TP_flood/(TP_flood + FP_flood + 1e-6)
    Precision_background = TP_background/(TP_background + FP_background + 1e-6)
    Precision = (Precision_flood + Precision_background)/2
    Recall_flood = TP_flood/(TP_flood + FN_flood + 1e-6)
    Recall_background = TP_background/(TP_background + FN_background + 1e-6)
    Recall = (Recall_flood + Recall_background)/2
    BalancedAccuracy = (TP_flood/(TP_flood + FN_flood + 1e-6) + TN_flood/(TN_flood + FP_flood + 1e-6))/2

    return Accuracy, IoU_flood, IoU_background, IoU, Dice_flood, Dice_background, Dice, Precision_flood, Precision_background, Precision, Recall_flood, Recall_background, Recall, BalancedAccuracy

# %%
def d4_mask_batch(images: torch.Tensor, model: torch.nn.Module, device="cuda" if torch.cuda.is_available() else "cpu") -> torch.Tensor:
    """
    Test-Time D4-аугментация: возвращает усреднённые вероятности классов (B,2,H,W).
    """
    model.eval()
    images = images.to(device)
    B, C, H, W = images.shape
    acc = torch.zeros((B, 2, H, W), dtype=torch.float32, device=device)

    with torch.no_grad():
        for transform, inv in zip(D4_TRANSFORMS, INVERSE_TRANSFORMS):

            imgs_t = transform(images)
            VV_t = imgs_t[:, 0:1]
            logits = model(imgs_t, VV_t)                 # (B,2,H,W)
            prob = F.softmax(logits, dim=1)
            prob_inv = inv(prob)
            acc += prob_inv

    # Усреднение по 8 вариантам
    avg = acc / len(D4_TRANSFORMS)          # (B,2,H,W)
    return avg

# %%
def apply_crf_to_batch(images, probs, n_iters=10):
    """
    Применяет CRF к батчу изображений.

    :param images: тензор изображений формы (B, C, H, W), где C >= 3
    :param probs: тензор вероятностей классов формы (B, 2, H, W)
    :param n_iters: количество итераций для CRF
    :return: тензор уточнённых масок формы (B, H, W)
    """
    B, C, H, W = probs.shape
    device = images.device
    refined_masks = torch.zeros((B, 2, H, W), dtype = torch.uint8, device = device)
    for i in range(B):
        # Извлекаем первые три канала изображения и масштабируем в диапазон [0, 255]
        image_rgb = (images[i, :3, :, :] * 255).cpu().numpy().transpose(1, 2, 0).copy().astype(np.uint8)

        # Получаем вероятности классов
        prob = probs[i].cpu().numpy()

        # Инициализация CRF
        d = dcrf.DenseCRF2D(W, H, 2)
        unary = unary_from_softmax(prob)
        d.setUnaryEnergy(unary)

        # Добавление парных потенциалов
        d.addPairwiseGaussian(sxy=3, compat=3)
        d.addPairwiseBilateral(sxy=80, srgb=13, rgbim=image_rgb, compat=10)

        # Инференс CRF
        Q = d.inference(n_iters)
        refined_mask = np.array(Q).reshape((2, H, W)).astype(np.float32)

        refined_masks[i] = torch.tensor(refined_mask, dtype = torch.float32, device = device)

    return refined_masks

# %%
def calculate_flood_percentage(mask):
    flood_pixels = np.sum(mask == 1)
    total_pixels = mask.size
    return (flood_pixels / total_pixels) * 100

# %%
def visualize_predictions(images, masks, predictions):

    cmap = ListedColormap(['black', '#ffc0cb', '#0000FF'])  # Цвета для -1, 0, 1
    bounds = [-1.5, -0.5, 0.5, 1.5]  # Границы значений
    norm = BoundaryNorm(bounds, cmap.N)

    batch_size = images.shape[0]
    for i in range(batch_size):
        # Извлечение изображения и маски
        image = images[i].permute(1, 2, 0).cpu().numpy()  # Перестановка осей и перевод на CPU
        mask = masks[i].cpu().numpy()  # Перевод маски на CPU
        prediction = predictions[i].argmax(dim=0).cpu().numpy()  # Перевод предсказания на CPU

        # Расчёт процента затопления
        flood_percentage = calculate_flood_percentage(prediction)

        # Отображение изображений
        fig, axes = plt.subplots(1, 3, figsize=(15, 5))

        # 3-х канальное изображение
        axes[0].imshow(image)
        axes[0].set_title("3-х канальное изображение")
        axes[0].axis("off")

        # Маска
        axes[1].imshow(mask, cmap=cmap, norm=norm)
        axes[1].set_title("Маска")
        axes[1].axis("off")

        # Предсказание модели
        axes[2].imshow(prediction, cmap=cmap, norm=norm)
        axes[2].set_title(f"Сегментация модели\n{flood_percentage:.2f}% воды")
        axes[2].axis("off")

        plt.tight_layout()
        plt.show()

# %%
class Conv1(nn.Module):
    """(Conv => BatchNorm => ReLU) * 2"""
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU()
        )

    def forward(self, x):
        return self.block(x)

class Down(nn.Module):
    """Downscaling with maxpool then double conv"""
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.block = nn.Sequential(
            nn.MaxPool2d(2),
            Conv1(in_ch, out_ch)
        )

    def forward(self, x):
        return self.block(x)

class ConvTransposeUp(nn.Module):
    """Concatenate x and skip, then upsample with ConvTranspose2d and conv"""
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.up = nn.ConvTranspose2d(in_ch, 2*out_ch, kernel_size=2, stride=2)
        self.conv = nn.Conv2d(2*out_ch, out_ch, kernel_size=3, padding=1)

    def forward(self, x, skip):
        x = torch.cat([skip, x], dim=1)
        x = self.up(x)
        x = self.conv(x)
        return x

class AttentionBlock(nn.Module):
    """Attention mechanism for dual encoder feature fusion."""
    def __init__(self, in_ch):
        super().__init__()
        self.conv_x1 = nn.Conv2d(in_ch, in_ch, kernel_size=3, padding=1)
        self.conv_x2 = nn.Conv2d(in_ch, in_ch, kernel_size=3, padding=1)
        self.conv_x1_2 = nn.Conv2d(in_ch, in_ch, kernel_size=3, padding=1)
        self.conv_x2_2 = nn.Conv2d(in_ch, in_ch, kernel_size=3, padding=1)

    def forward(self, x1, x2):
        x1_1 = torch.sigmoid(self.conv_x1(x1))
        x1_2 = x1 * x1_1

        x2_1 = torch.sigmoid(self.conv_x2(x2))
        x2_2 = x2 * x2_1

        x1_3 = torch.sigmoid(self.conv_x1_2(x1_2))
        x1_4 = x1_3 * x2_2

        x2_3 = torch.sigmoid(self.conv_x2_2(x2_2))
        x2_4 = x2_3 * x1_2

        return x1_4 + x2_4

class ProCANet(nn.Module):
    """
    U-Net with two encoders:
     - Encoder1: takes 4-channel input (e.g., R,G,B,NIR)
     - Encoder2: takes 1-channel input (e.g., NIR)
    """
    def __init__(self, in_ch1, in_ch2, n_classes):
        super().__init__()
        # Encoder 1 (4-channel)
        self.inc1 = Conv1(in_ch1, 64) #256x256 64
        self.down1_1 = Down(64, 128) #128x128 128
        self.down2_1 = Down(128, 256) #64x64 256
        self.down3_1 = Down(256, 512) #32x32 512
        self.down4_1 = Down(512, 1024) #16x16 1024

        # Encoder 2 (1-channel)
        self.inc2 = Conv1(in_ch2, 64) #256x256 64
        self.down1_2 = Down(64, 128) #128x128 128
        self.down2_2 = Down(128, 256) #64x64 256
        self.down3_2 = Down(256, 512) #32x32 512

        # Attention at skip levels
        self.att4 = AttentionBlock(512)
        self.att3 = AttentionBlock(256)
        self.att2 = AttentionBlock(128)
        self.att1 = AttentionBlock(64)

        # Decoder
        self.up0 = nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2) #32x32
        self.up1 = ConvTransposeUp(1024, 256) #64x64
        self.up2 = ConvTransposeUp(512, 128) #128x128
        self.up3 = ConvTransposeUp(256, 64) #256x256
        self.outc = nn.Conv2d(128, n_classes, kernel_size=3, padding=1)

    def forward(self, x1, x2):
        # Encoder 1 path
        x1_1 = self.inc1(x1) # 64
        x2_1 = self.down1_1(x1_1) #128
        x3_1 = self.down2_1(x2_1) #256
        x4_1 = self.down3_1(x3_1) #512
        x5_1 = self.down4_1(x4_1) #1024

        # Encoder 2 path
        y1_1 = self.inc2(x2) # 64
        y2_1 = self.down1_2(y1_1) #128
        y3_1 = self.down2_2(y2_1) #256
        y4_1 = self.down3_2(y3_1) #512

        # Bottleneck upsample
        d5 = self.up0(x5_1) # 1024 -> 512

        # Decoder with attention-fused skips
        d4 = self.up1(d5, self.att4(x4_1, y4_1)) # 1024 -> 256
        d3 = self.up2(d4, self.att3(x3_1, y3_1)) # 512 -> 128
        d2 = self.up3(d3, self.att2(x2_1, y2_1)) # 256 -> 64
        d1 = torch.cat([d2, self.att1(x1_1, y1_1)], dim=1) # 128 -> 128

        return self.outc(d1)

# %%
def train(num_epochs = 200):

    global validation_iou
    global num_best_epoch

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Создание модели
    model = ProCANet(in_ch1=3, in_ch2=1, n_classes=2).to(device)

    # Оптимизатор
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    # Шедулер
    scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
        optimizer,
        T_0=25,
        T_mult=1,
        eta_min=5e-6
    )

    scaler = GradScaler('cuda')

    # Функция потерь
    criterion_dice = smp.losses.DiceLoss(mode="multiclass", ignore_index=-1)

    # Создание DataLoader-ов
    train_df = create_df(train_dir)
    validation_df = create_df(validation_dir)
    if train_df.empty:
        raise ValueError("Train DataFrame is empty!")
    if validation_df.empty:
        raise ValueError("Validation DataFrame is empty!")

    train_dataset = MyDataset(train_df, split="train", transform = transform)
    validation_dataset = MyDataset(validation_df, split="validation", transform=None)

    train_loader = DataLoader(
        train_dataset, batch_size=local_batch_size, shuffle=True, num_workers = os.cpu_count()-1,
        pin_memory=True, persistent_workers=True
    )
    validation_loader = DataLoader(
        validation_dataset, batch_size=local_batch_size, shuffle=False, num_workers = os.cpu_count()-1,
        pin_memory=True, persistent_workers=True
    )
    if len(train_loader) == 0:
        raise ValueError("Train DataLoader is empty!")
    if len(validation_loader) == 0:
        raise ValueError("Validation DataLoader is empty!")

    ## Начало обучения ##
    for epoch in range(num_epochs):
        # Тренировочный этап
        model.train()
        train_losses = []
        TP_flood, FP_flood, TN_flood, FN_flood = 0.0, 0.0, 0.0, 0.0
        TP_background, FP_background, TN_background, FN_background = 0.0, 0.0, 0.0, 0.0

        progress_bar = tqdm(train_loader, desc="Train", unit="batch", leave=True)
        for batch in progress_bar:

            image = batch["image"].to(device, non_blocking=True)
            VV = image[:,0:1]
            mask = batch["mask"].to(device, non_blocking=True)

            optimizer.zero_grad()

            with autocast('cuda'):
                pred = model(image, VV)
                loss = criterion_dice(pred, mask)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            train_losses.append(loss.item())
            TP_flood_batch, FP_flood_batch, TN_flood_batch, FN_flood_batch, TP_background_batch, FP_background_batch, TN_background_batch, FN_background_batch = calculate_TP_FP_TN_FN(pred, mask)
            TP_flood += TP_flood_batch
            FP_flood += FP_flood_batch
            TN_flood += TN_flood_batch
            FN_flood += FN_flood_batch
            TP_background += TP_background_batch
            FP_background += FP_background_batch
            TN_background += TN_background_batch
            FN_background += FN_background_batch

        Avg_loss = sum(train_losses) / (len(train_losses) + 1e-6)
        Accuracy, IoU_flood, IoU_background, IoU, Dice_flood, Dice_background, Dice, Precision_flood, Precision_background, Precision, Recall_flood, Recall_background, Recall, BalancedAccuracy = calculate_metrics(TP_flood = TP_flood, FP_flood = FP_flood, TN_flood = TN_flood, FN_flood = FN_flood, TP_background = TP_background, FP_background = FP_background, TN_background = TN_background, FN_background = FN_background)
        logger1.info(f"Epoch {epoch+1}, LR: {optimizer.param_groups[0]['lr']:.8f}, Train Loss: {Avg_loss:.4f}, Train IoU: {IoU:.4f}, Train Accuracy: {Accuracy:.4f}, Train Dice: {Dice:.4f}, Train Precision: {Precision:.4f}, Train Recall: {Recall:.4f}, Train BalancedAccuracy: {BalancedAccuracy:.4f}, Train IoU_flood: {IoU_flood:.4f}, Train IoU_background: {IoU_background:.4f}, Train Dice_flood: {Dice_flood:.4f}, Train Dice_background: {Dice_background:.4f}, Train Precision_flood: {Precision_flood:.4f}, Train Precision_background: {Precision_background:.4f}, Train Recall_flood: {Recall_flood:.4f}, Train Recall_background: {Recall_background:.4f}")

        scheduler.step()

        # Оценка на валидационном наборе
        model.eval()
        with torch.no_grad():
            valid_losses = []
            TP_flood, FP_flood, TN_flood, FN_flood = 0.0, 0.0, 0.0, 0.0
            TP_background, FP_background, TN_background, FN_background = 0.0, 0.0, 0.0, 0.0

            progress_bar = tqdm(validation_loader, desc="Valid", unit="batch", leave=True)
            for batch in progress_bar:
                image = batch["image"].to(device, non_blocking=True)
                VV = image[:,0:1]
                mask = batch["mask"].to(device, non_blocking=True)

                with autocast('cuda'):
                    pred = model(image, VV)
                    loss = criterion_dice(pred, mask)

                # Метрики
                valid_losses.append(loss.item())
                TP_flood_batch, FP_flood_batch, TN_flood_batch, FN_flood_batch, TP_background_batch, FP_background_batch, TN_background_batch, FN_background_batch = calculate_TP_FP_TN_FN(pred, mask)
                TP_flood += TP_flood_batch
                FP_flood += FP_flood_batch
                TN_flood += TN_flood_batch
                FN_flood += FN_flood_batch
                TP_background += TP_background_batch
                FP_background += FP_background_batch
                TN_background += TN_background_batch
                FN_background += FN_background_batch

        Avg_loss = sum(valid_losses) / (len(valid_losses) + 1e-6)
        Accuracy, IoU_flood, IoU_background, IoU, Dice_flood, Dice_background, Dice, Precision_flood, Precision_background, Precision, Recall_flood, Recall_background, Recall, BalancedAccuracy = calculate_metrics(TP_flood = TP_flood, FP_flood = FP_flood, TN_flood = TN_flood, FN_flood = FN_flood, TP_background = TP_background, FP_background = FP_background, TN_background = TN_background, FN_background = FN_background)
        if (IoU > validation_iou):
            num_best_epoch = epoch + 1
            validation_iou = IoU
        logger1.info(f"Epoch {epoch+1}, Valid Loss: {Avg_loss:.4f}, Valid IoU: {IoU:.4f}, Valid Accuracy: {Accuracy:.4f}, Valid Dice: {Dice:.4f}, Valid Precision: {Precision:.4f}, Valid Recall: {Recall:.4f}, Valid BalancedAccuracy: {BalancedAccuracy:.4f}, Valid IoU_flood: {IoU_flood:.4f}, Valid IoU_background: {IoU_background:.4f}, Valid Dice_flood: {Dice_flood:.4f}, Valid Dice_background: {Dice_background:.4f}, Valid Precision_flood: {Precision_flood:.4f}, Valid Precision_background: {Precision_background:.4f}, Valid Recall_flood: {Recall_flood:.4f}, Valid Recall_background: {Recall_background:.4f}")

        # Сохранение модели
        torch.save({
            'epoch': epoch+1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'scheduler_state_dict': scheduler.state_dict(),
            'loss': Avg_loss
        }, f"/content/{model_serialization}_{epoch+1}_{channels}_{data}.pth")

# %%
def addtrain(num_epochs = 100, initEpoch = 100):

    global validation_iou
    global num_best_epoch

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    checkpoint = torch.load(f"/content/drive/MyDrive/datasets_and_models/{folder}/{folder_of_weights}/{model_serialization}_{initEpoch}_{channels}_{data}.pth", map_location=device)

    # Создание модели
    model = ProCANet(in_ch1=3, in_ch2=1, n_classes=2).to(device)
    model.load_state_dict(checkpoint['model_state_dict'])

    # Оптимизатор
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

    # Шедулер
    scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
        optimizer,
        T_0=25,
        T_mult=1,
        eta_min=5e-6
    )
    scheduler.load_state_dict(checkpoint['scheduler_state_dict'])

    scaler = GradScaler('cuda')

    # Функция потерь
    criterion_dice = smp.losses.DiceLoss(mode="multiclass", ignore_index=-1)

    # Создание DataLoader-ов
    train_df = create_df(train_dir)
    validation_df = create_df(validation_dir)
    if train_df.empty:
        raise ValueError("Train DataFrame is empty!")
    if validation_df.empty:
        raise ValueError("Validation DataFrame is empty!")

    train_dataset = MyDataset(train_df, split="train", transform = transform)
    validation_dataset = MyDataset(validation_df, split="validation", transform=None)

    train_loader = DataLoader(
        train_dataset, batch_size=local_batch_size, shuffle=True, num_workers = os.cpu_count()-1,
        pin_memory=True, persistent_workers=True
    )
    validation_loader = DataLoader(
        validation_dataset, batch_size=local_batch_size, shuffle=False, num_workers = os.cpu_count()-1,
        pin_memory=True, persistent_workers=True
    )
    if len(train_loader) == 0:
        raise ValueError("Train DataLoader is empty!")
    if len(validation_loader) == 0:
        raise ValueError("Validation DataLoader is empty!")

    ## Начало обучения ##
    for epoch in range(num_epochs):
        # Тренировочный этап
        model.train()
        train_losses = []
        TP_flood, FP_flood, TN_flood, FN_flood = 0.0, 0.0, 0.0, 0.0
        TP_background, FP_background, TN_background, FN_background = 0.0, 0.0, 0.0, 0.0

        progress_bar = tqdm(train_loader, desc="Train", unit="batch", leave=True)
        for batch in progress_bar:

            image = batch["image"].to(device, non_blocking=True)
            VV = image[:,0:1]
            mask = batch["mask"].to(device, non_blocking=True)

            optimizer.zero_grad()

            with autocast('cuda'):
                pred = model(image, VV)
                loss = criterion_dice(pred, mask)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            train_losses.append(loss.item())
            TP_flood_batch, FP_flood_batch, TN_flood_batch, FN_flood_batch, TP_background_batch, FP_background_batch, TN_background_batch, FN_background_batch = calculate_TP_FP_TN_FN(pred, mask)
            TP_flood += TP_flood_batch
            FP_flood += FP_flood_batch
            TN_flood += TN_flood_batch
            FN_flood += FN_flood_batch
            TP_background += TP_background_batch
            FP_background += FP_background_batch
            TN_background += TN_background_batch
            FN_background += FN_background_batch

        Avg_loss = sum(train_losses) / (len(train_losses) + 1e-6)
        Accuracy, IoU_flood, IoU_background, IoU, Dice_flood, Dice_background, Dice, Precision_flood, Precision_background, Precision, Recall_flood, Recall_background, Recall, BalancedAccuracy = calculate_metrics(TP_flood = TP_flood, FP_flood = FP_flood, TN_flood = TN_flood, FN_flood = FN_flood, TP_background = TP_background, FP_background = FP_background, TN_background = TN_background, FN_background = FN_background)
        logger1.info(f"Epoch {epoch+initEpoch+1}, LR: {optimizer.param_groups[0]['lr']:.8f}, Train Loss: {Avg_loss:.4f}, Train IoU: {IoU:.4f}, Train Accuracy: {Accuracy:.4f}, Train Dice: {Dice:.4f}, Train Precision: {Precision:.4f}, Train Recall: {Recall:.4f}, Train BalancedAccuracy: {BalancedAccuracy:.4f}, Train IoU_flood: {IoU_flood:.4f}, Train IoU_background: {IoU_background:.4f}, Train Dice_flood: {Dice_flood:.4f}, Train Dice_background: {Dice_background:.4f}, Train Precision_flood: {Precision_flood:.4f}, Train Precision_background: {Precision_background:.4f}, Train Recall_flood: {Recall_flood:.4f}, Train Recall_background: {Recall_background:.4f}")

        scheduler.step()

        # Оценка на валидационном наборе
        model.eval()
        with torch.no_grad():
            valid_losses = []
            TP_flood, FP_flood, TN_flood, FN_flood = 0.0, 0.0, 0.0, 0.0
            TP_background, FP_background, TN_background, FN_background = 0.0, 0.0, 0.0, 0.0

            progress_bar = tqdm(validation_loader, desc="Valid", unit="batch", leave=True)
            for batch in progress_bar:
                image = batch["image"].to(device, non_blocking=True)
                VV = image[:,0:1]
                mask = batch["mask"].to(device, non_blocking=True)

                with autocast('cuda'):
                    pred = model(image, VV)
                    loss = criterion_dice(pred, mask)

                # Метрики
                valid_losses.append(loss.item())
                TP_flood_batch, FP_flood_batch, TN_flood_batch, FN_flood_batch, TP_background_batch, FP_background_batch, TN_background_batch, FN_background_batch = calculate_TP_FP_TN_FN(pred, mask)
                TP_flood += TP_flood_batch
                FP_flood += FP_flood_batch
                TN_flood += TN_flood_batch
                FN_flood += FN_flood_batch
                TP_background += TP_background_batch
                FP_background += FP_background_batch
                TN_background += TN_background_batch
                FN_background += FN_background_batch

        Avg_loss = sum(valid_losses) / (len(valid_losses) + 1e-6)
        Accuracy, IoU_flood, IoU_background, IoU, Dice_flood, Dice_background, Dice, Precision_flood, Precision_background, Precision, Recall_flood, Recall_background, Recall, BalancedAccuracy = calculate_metrics(TP_flood = TP_flood, FP_flood = FP_flood, TN_flood = TN_flood, FN_flood = FN_flood, TP_background = TP_background, FP_background = FP_background, TN_background = TN_background, FN_background = FN_background)
        if (IoU > validation_iou):
            num_best_epoch = epoch + initEpoch +1
            validation_iou = IoU
        logger1.info(f"Epoch {epoch+initEpoch+1}, Valid Loss: {Avg_loss:.4f}, Valid IoU: {IoU:.4f}, Valid Accuracy: {Accuracy:.4f}, Valid Dice: {Dice:.4f}, Valid Precision: {Precision:.4f}, Valid Recall: {Recall:.4f}, Valid BalancedAccuracy: {BalancedAccuracy:.4f}, Valid IoU_flood: {IoU_flood:.4f}, Valid IoU_background: {IoU_background:.4f}, Valid Dice_flood: {Dice_flood:.4f}, Valid Dice_background: {Dice_background:.4f}, Valid Precision_flood: {Precision_flood:.4f}, Valid Precision_background: {Precision_background:.4f}, Valid Recall_flood: {Recall_flood:.4f}, Valid Recall_background: {Recall_background:.4f}")

        # Сохранение модели
        torch.save({
            'epoch': epoch+initEpoch+1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'scheduler_state_dict': scheduler.state_dict(),
            'loss': Avg_loss
        }, f"/content/{model_serialization}_{epoch+initEpoch+1}_{channels}_{data}.pth")

# %%
def test(TestEpoch = 200):

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    checkpoint = torch.load(f"/content/drive/MyDrive/datasets_and_models/{folder}/{folder_of_weights}/{model_serialization}_{TestEpoch}_{channels}_{data}.pth", map_location=device)

    # Создание модели
    model = ProCANet(in_ch1=3, in_ch2=1, n_classes=2).to(device)
    model.load_state_dict(checkpoint['model_state_dict'])

    scaler = GradScaler('cuda')

    # Создание DataLoader-ов
    test_df = create_df(test_dir)
    test_Bolivia_df = create_df(test_Bolivia_dir)
    if test_df.empty:
        raise ValueError("Test DataFrame is empty!")
    if  test_Bolivia_df.empty:
        raise ValueError("Test Bolivia DataFrame is empty!")

    test_dataset = MyDataset(test_df, split="test", transform = None)
    test_Bolivia_dataset = MyDataset(test_Bolivia_df, split="test", transform=None)

    test_loader = DataLoader(
        test_dataset, batch_size=16, shuffle=False, num_workers = os.cpu_count()-1,
        pin_memory=True, persistent_workers=True
    )
    test_Bolivia_loader = DataLoader(
        test_Bolivia_dataset, batch_size=16, shuffle=False, num_workers = os.cpu_count()-1,
        pin_memory=True, persistent_workers=True
    )
    if len(test_loader) == 0:
        raise ValueError("Test DataLoader is empty!")
    if len(test_Bolivia_loader) == 0:
        raise ValueError("Test Bolivia DataLoader is empty!")

    # Оценка на тестовом наборе
    model.eval()
    with torch.no_grad():
        test_losses = []
        TP_flood, FP_flood, TN_flood, FN_flood = 0.0, 0.0, 0.0, 0.0
        TP_background, FP_background, TN_background, FN_background = 0.0, 0.0, 0.0, 0.0
        TP_flood_aug, FP_flood_aug, TN_flood_aug, FN_flood_aug = 0.0, 0.0, 0.0, 0.0
        TP_background_aug, FP_background_aug, TN_background_aug, FN_background_aug = 0.0, 0.0, 0.0, 0.0
        TP_flood_aug_crf, FP_flood_aug_crf, TN_flood_aug_crf, FN_flood_aug_crf = 0.0, 0.0, 0.0, 0.0
        TP_background_aug_crf, FP_background_aug_crf, TN_background_aug_crf, FN_background_aug_crf = 0.0, 0.0, 0.0, 0.0

        progress_bar = tqdm(test_loader, desc="Test", unit="batch", leave=True)
        for batch in progress_bar:
            image = batch["image"].to(device, non_blocking=True)
            VV = image[:,0:1]
            mask = batch["mask"].to(device, non_blocking=True)

            with autocast('cuda'):
                pred = model(image, VV)

            pred_aug = d4_mask_batch(images = image, model = model, device = device)
            pred_aug_CRF = apply_crf_to_batch(images = image, probs = pred_aug)

            #visualize_predictions(images = image , masks = mask, predictions = pred)
            #visualize_predictions(images = image , masks = mask, predictions = pred_aug)
            #visualize_predictions(images = image , masks = mask, predictions = pred_aug_CRF)

            # Метрики
            TP_flood_batch, FP_flood_batch, TN_flood_batch, FN_flood_batch, TP_background_batch, FP_background_batch, TN_background_batch, FN_background_batch = calculate_TP_FP_TN_FN(pred, mask)
            TP_flood += TP_flood_batch
            FP_flood += FP_flood_batch
            TN_flood += TN_flood_batch
            FN_flood += FN_flood_batch
            TP_background += TP_background_batch
            FP_background += FP_background_batch
            TN_background += TN_background_batch
            FN_background += FN_background_batch
            TP_flood_batch, FP_flood_batch, TN_flood_batch, FN_flood_batch, TP_background_batch, FP_background_batch, TN_background_batch, FN_background_batch = calculate_TP_FP_TN_FN(pred_aug, mask)
            TP_flood_aug += TP_flood_batch
            FP_flood_aug += FP_flood_batch
            TN_flood_aug += TN_flood_batch
            FN_flood_aug += FN_flood_batch
            TP_background_aug += TP_background_batch
            FP_background_aug += FP_background_batch
            TN_background_aug += TN_background_batch
            FN_background_aug += FN_background_batch
            TP_flood_batch, FP_flood_batch, TN_flood_batch, FN_flood_batch, TP_background_batch, FP_background_batch, TN_background_batch, FN_background_batch = calculate_TP_FP_TN_FN(pred_aug_CRF, mask)
            TP_flood_aug_crf += TP_flood_batch
            FP_flood_aug_crf += FP_flood_batch
            TN_flood_aug_crf += TN_flood_batch
            FN_flood_aug_crf += FN_flood_batch
            TP_background_aug_crf += TP_background_batch
            FP_background_aug_crf += FP_background_batch
            TN_background_aug_crf += TN_background_batch
            FN_background_aug_crf += FN_background_batch
    print(f"TP_flood = {TP_flood}, FP_flood = {FP_flood}, TN_flood = {TN_flood}, FN_flood = {FN_flood}")
    print(f"TP_flood_aug = {TP_flood_aug}, FP_flood_aug = {FP_flood_aug}, TN_flood_aug = {TN_flood_aug}, FN_flood_aug = {FN_flood_aug}")
    print(f"TP_floodaug_crf = {TP_flood_aug_crf}, FP_floodaug_crf = {FP_flood_aug_crf}, TN_floodaug_crf = {TN_flood_aug_crf}, FN_floodaug_crf = {FN_flood_aug_crf}")
    Accuracy, IoU_flood, IoU_background, IoU, Dice_flood, Dice_background, Dice, Precision_flood, Precision_background, Precision, Recall_flood, Recall_background, Recall, BalancedAccuracy = calculate_metrics(TP_flood = TP_flood, FP_flood = FP_flood, TN_flood = TN_flood, FN_flood = FN_flood, TP_background = TP_background, FP_background = FP_background, TN_background = TN_background, FN_background = FN_background)
    Accuracy_aug, IoU_flood_aug, IoU_background_aug, IoU_aug, Dice_flood_aug, Dice_background_aug, Dice_aug, Precision_flood_aug, Precision_background_aug, Precision_aug, Recall_flood_aug, Recall_background_aug, Recall_aug, BalancedAccuracy_aug = calculate_metrics(TP_flood = TP_flood_aug, FP_flood = FP_flood_aug, TN_flood = TN_flood_aug, FN_flood = FN_flood_aug, TP_background = TP_background_aug, FP_background = FP_background_aug, TN_background = TN_background_aug, FN_background = FN_background_aug)
    Accuracy_aug_crf, IoU_flood_aug_crf, IoU_background_aug_crf, IoU_aug_crf, Dice_flood_aug_crf, Dice_background_aug_crf, Dice_aug_crf, Precision_flood_aug_crf, Precision_background_aug_crf, Precision_aug_crf, Recall_flood_aug_crf, Recall_background_aug_crf, Recall_aug_crf, BalancedAccuracy_aug_crf = calculate_metrics(TP_flood = TP_flood_aug_crf, FP_flood = FP_flood_aug_crf, TN_flood = TN_flood_aug_crf, FN_flood = FN_flood_aug_crf, TP_background = TP_background_aug_crf, FP_background = FP_background_aug_crf, TN_background = TN_background_aug_crf, FN_background = FN_background_aug_crf)
    logger2.info(f"WeightsEpoch: {checkpoint['epoch']}, Test IoU: {IoU:.4f}, Test Accuracy: {Accuracy:.4f}, Test Dice: {Dice:.4f}, Test Precision: {Precision:.4f}, Test Recall: {Recall:.4f}, Test BalancedAccuracy: {BalancedAccuracy:.4f}, Test IoU_flood: {IoU_flood:.4f}, Test IoU_background: {IoU_background:.4f}, Test Dice_flood: {Dice_flood:.4f}, Test Dice_background: {Dice_background:.4f}, Test Precision_flood: {Precision_flood:.4f}, Test Precision_background: {Precision_background:.4f}, Test Recall_flood: {Recall_flood:.4f}, Test Recall_background: {Recall_background:.4f}")
    logger2.info(f"WeightsEpoch: {checkpoint['epoch']}, Test Aug IoU: {IoU_aug:.4f}, Test Accuracy: {Accuracy_aug:.4f}, Test Dice: {Dice_aug:.4f}, Test Precision: {Precision_aug:.4f}, Test Recall: {Recall_aug:.4f}, Test BalancedAccuracy: {BalancedAccuracy_aug:.4f}, Test IoU_flood: {IoU_flood_aug:.4f}, Test IoU_background: {IoU_background_aug:.4f}, Test Dice_flood: {Dice_flood_aug:.4f}, Test Dice_background: {Dice_background_aug:.4f}, Test Precision_flood: {Precision_flood_aug:.4f}, Test Precision_background: {Precision_background_aug:.4f}, Test Recall_flood: {Recall_flood_aug:.4f}, Test Recall_background: {Recall_background_aug:.4f}")
    logger2.info(f"WeightsEpoch: {checkpoint['epoch']}, Test Aug CRF IoU: {IoU_aug_crf:.4f}, Test Accuracy: {Accuracy_aug_crf:.4f}, Test Dice: {Dice_aug_crf:.4f}, Test Precision: {Precision_aug_crf:.4f}, Test Recall: {Recall_aug_crf:.4f}, Test BalancedAccuracy: {BalancedAccuracy_aug_crf:.4f}, Test IoU_flood: {IoU_flood_aug_crf:.4f}, Test IoU_background: {IoU_background_aug_crf:.4f}, Test Dice_flood: {Dice_flood_aug_crf:.4f}, Test Dice_background: {Dice_background_aug_crf:.4f}, Test Precision_flood: {Precision_flood_aug_crf:.4f}, Test Precision_background: {Precision_background_aug_crf:.4f}, Test Recall_flood: {Recall_flood_aug_crf:.4f}, Test Recall_background: {Recall_background_aug_crf:.4f}")

    # Оценка на тестовом наборе Боливии
    model.eval()
    with torch.no_grad():
        test_Bolivia_losses = []
        TP_flood, FP_flood, TN_flood, FN_flood = 0.0, 0.0, 0.0, 0.0
        TP_background, FP_background, TN_background, FN_background = 0.0, 0.0, 0.0, 0.0

        progress_bar = tqdm(test_Bolivia_loader, desc="Test Bolivia", unit="batch", leave=True)
        for batch in progress_bar:
            image = batch["image"].to(device, non_blocking=True)
            VV = image[:,0:1]
            mask = batch["mask"].to(device, non_blocking=True)

            with autocast('cuda'):
                pred = model(image, VV)

            pred_aug = d4_mask_batch(images = image, model = model, device = device)
            pred_aug_CRF = apply_crf_to_batch(images = image, probs = pred_aug)

            #visualize_predictions(images = image , masks = mask, predictions = pred)
            #visualize_predictions(images = image , masks = mask, predictions = pred_aug)
            #visualize_predictions(images = image , masks = mask, predictions = pred_aug_CRF)

            # Метрики
            TP_flood_batch, FP_flood_batch, TN_flood_batch, FN_flood_batch, TP_background_batch, FP_background_batch, TN_background_batch, FN_background_batch = calculate_TP_FP_TN_FN(pred, mask)
            TP_flood += TP_flood_batch
            FP_flood += FP_flood_batch
            TN_flood += TN_flood_batch
            FN_flood += FN_flood_batch
            TP_background += TP_background_batch
            FP_background += FP_background_batch
            TN_background += TN_background_batch
            FN_background += FN_background_batch
            TP_flood_batch, FP_flood_batch, TN_flood_batch, FN_flood_batch, TP_background_batch, FP_background_batch, TN_background_batch, FN_background_batch = calculate_TP_FP_TN_FN(pred_aug, mask)
            TP_flood_aug += TP_flood_batch
            FP_flood_aug += FP_flood_batch
            TN_flood_aug += TN_flood_batch
            FN_flood_aug += FN_flood_batch
            TP_background_aug += TP_background_batch
            FP_background_aug += FP_background_batch
            TN_background_aug += TN_background_batch
            FN_background_aug += FN_background_batch
            TP_flood_batch, FP_flood_batch, TN_flood_batch, FN_flood_batch, TP_background_batch, FP_background_batch, TN_background_batch, FN_background_batch = calculate_TP_FP_TN_FN(pred_aug_CRF, mask)
            TP_flood_aug_crf += TP_flood_batch
            FP_flood_aug_crf += FP_flood_batch
            TN_flood_aug_crf += TN_flood_batch
            FN_flood_aug_crf += FN_flood_batch
            TP_background_aug_crf += TP_background_batch
            FP_background_aug_crf += FP_background_batch
            TN_background_aug_crf += TN_background_batch
            FN_background_aug_crf += FN_background_batch

    Accuracy, IoU_flood, IoU_background, IoU, Dice_flood, Dice_background, Dice, Precision_flood, Precision_background, Precision, Recall_flood, Recall_background, Recall, BalancedAccuracy = calculate_metrics(TP_flood = TP_flood, FP_flood = FP_flood, TN_flood = TN_flood, FN_flood = FN_flood, TP_background = TP_background, FP_background = FP_background, TN_background = TN_background, FN_background = FN_background)
    Accuracy_aug, IoU_flood_aug, IoU_background_aug, IoU_aug, Dice_flood_aug, Dice_background_aug, Dice_aug, Precision_flood_aug, Precision_background_aug, Precision_aug, Recall_flood_aug, Recall_background_aug, Recall_aug, BalancedAccuracy_aug = calculate_metrics(TP_flood = TP_flood_aug, FP_flood = FP_flood_aug, TN_flood = TN_flood_aug, FN_flood = FN_flood_aug, TP_background = TP_background_aug, FP_background = FP_background_aug, TN_background = TN_background_aug, FN_background = FN_background_aug)
    Accuracy_aug_crf, IoU_flood_aug_crf, IoU_background_aug_crf, IoU_aug_crf, Dice_flood_aug_crf, Dice_background_aug_crf, Dice_aug_crf, Precision_flood_aug_crf, Precision_background_aug_crf, Precision_aug_crf, Recall_flood_aug_crf, Recall_background_aug_crf, Recall_aug_crf, BalancedAccuracy_aug_crf = calculate_metrics(TP_flood = TP_flood_aug_crf, FP_flood = FP_flood_aug_crf, TN_flood = TN_flood_aug_crf, FN_flood = FN_flood_aug_crf, TP_background = TP_background_aug_crf, FP_background = FP_background_aug_crf, TN_background = TN_background_aug_crf, FN_background = FN_background_aug_crf)
    logger2.info(f"WeightsEpoch: {checkpoint['epoch']}, TestBolivia IoU: {IoU:.4f}, TestB Accuracy: {Accuracy:.4f}, TestB Dice: {Dice:.4f}, TestB Precision: {Precision:.4f}, TestB Recall: {Recall:.4f}, TestB BalancedAccuracy: {BalancedAccuracy:.4f}, TestB IoU_flood: {IoU_flood:.4f}, TestB IoU_background: {IoU_background:.4f}, TestB Dice_flood: {Dice_flood:.4f}, TestB Dice_background: {Dice_background:.4f}, TestB Precision_flood: {Precision_flood:.4f}, TestB Precision_background: {Precision_background:.4f}, TestB Recall_flood: {Recall_flood:.4f}, TestB Recall_background: {Recall_background:.4f}")
    logger2.info(f"WeightsEpoch: {checkpoint['epoch']}, TestBolivia Aug IoU: {IoU_aug:.4f}, TestB Accuracy: {Accuracy_aug:.4f}, TestB Dice: {Dice_aug:.4f}, TestB Precision: {Precision_aug:.4f}, TestB Recall: {Recall_aug:.4f}, TestB BalancedAccuracy: {BalancedAccuracy_aug:.4f}, TestB IoU_flood: {IoU_flood_aug:.4f}, TestB IoU_background: {IoU_background_aug:.4f}, TestB Dice_flood: {Dice_flood_aug:.4f}, TestB Dice_background: {Dice_background_aug:.4f}, TestB Precision_flood: {Precision_flood_aug:.4f}, TestB Precision_background: {Precision_background_aug:.4f}, TestB Recall_flood: {Recall_flood_aug:.4f}, TestB Recall_background: {Recall_background_aug:.4f}")
    logger2.info(f"WeightsEpoch: {checkpoint['epoch']}, TestBolivia Aug CRF IoU: {IoU_aug_crf:.4f}, TestB Accuracy: {Accuracy_aug_crf:.4f}, TestB Dice: {Dice_aug_crf:.4f}, TestB Precision: {Precision_aug_crf:.4f}, TestB Recall: {Recall_aug_crf:.4f}, TestB BalancedAccuracy: {BalancedAccuracy_aug_crf:.4f}, TestB IoU_flood: {IoU_flood_aug_crf:.4f}, TestB IoU_background: {IoU_background_aug_crf:.4f}, TestB Dice_flood: {Dice_flood_aug_crf:.4f}, TestB Dice_background: {Dice_background_aug_crf:.4f}, TestB Precision_flood: {Precision_flood_aug_crf:.4f}, TestB Precision_background: {Precision_background_aug_crf:.4f}, TestB Recall_flood: {Recall_flood_aug_crf:.4f}, TestB Recall_background: {Recall_background_aug_crf:.4f}")

# %%
if __name__ == "__main__":

    folder_of_weights = "Weights_VV_VH_Pseudo-labels"

    num_best_epoch = 0
    validation_iou = 0
    # Настройка логирования train
    logger1 = logging.getLogger(f"training_logger")
    logger1.setLevel(logging.INFO)
    # Формат логов
    formatter = logging.Formatter('%(message)s')
    # Вывод в консоль
    console_handler = logging.StreamHandler()
    console_handler.setFormatter(formatter)
    # Запись в файл
    file_handler = logging.FileHandler(f"/content/{channels}_{data}_train_30.txt", mode='a')
    file_handler.setFormatter(formatter)
    if not logger1.handlers:
      logger1.addHandler(console_handler)
      logger1.addHandler(file_handler)

    # Настройка логирования test
    logger2 = logging.getLogger(f"testing_logger")
    logger2.setLevel(logging.INFO)
    # Формат логов
    formatter2 = logging.Formatter('%(message)s')
    # Вывод в консоль
    console_handler2 = logging.StreamHandler()
    console_handler2.setFormatter(formatter2)
    # Запись в файл
    file_handler2 = logging.FileHandler(f"/content/{channels}_{data}_test_30.txt", mode='a')
    file_handler2.setFormatter(formatter2)
    if not logger2.handlers:
      logger2.addHandler(console_handler2)
      logger2.addHandler(file_handler2)

    addtrain(num_epochs = 170, initEpoch = 30)

    txt_train = f"{channels}_{data}_train_30.txt"
    txt_test = f"{channels}_{data}_test_30.txt"
    best_weights = f"{model_serialization}_{num_best_epoch}_{channels}_{data}.pth"
    weights = f"{model_serialization}_{num_epochs}_{channels}_{data}.pth"
    txt_dir = f"/content/drive/MyDrive/datasets_and_models/{folder}"
    weights_dir = f"/content/drive/MyDrive/datasets_and_models/{folder}/{folder_of_weights}"
# Out:
# Train:   0%|          | 0/219 [00:00<?, ?batch/s]<ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# Train: 100%|██████████| 219/219 [01:56<00:00,  1.87batch/s]
# Epoch 31, LR: 0.00010000, Train Loss: 0.0919, Train IoU: 0.8405, Train Accuracy: 0.9509, Train Dice: 0.9099, Train Precision: 0.9086, Train Recall: 0.9113, Train BalancedAccuracy: 0.9113, Train IoU_flood: 0.7379, Train IoU_background: 0.9430, Train Dice_flood: 0.8492, Train Dice_background: 0.9707, Train Precision_flood: 0.8459, Train Precision_background: 0.9714, Train Recall_flood: 0.8526, Train Recall_background: 0.9699
# INFO:training_logger:Epoch 31, LR: 0.00010000, Train Loss: 0.0919, Train IoU: 0.8405, Train Accuracy: 0.9509, Train Dice: 0.9099, Train Precision: 0.9086, Train Recall: 0.9113, Train BalancedAccuracy: 0.9113, Train IoU_flood: 0.7379, Train IoU_background: 0.9430, Train Dice_flood: 0.8492, Train Dice_background: 0.9707, Train Precision_flood: 0.8459, Train Precision_background: 0.9714, Train Recall_flood: 0.8526, Train Recall_background: 0.9699
# Valid:   0%|          | 0/5 [00:00<?, ?batch/s]<ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# Valid: 100%|██████████| 5/5 [00:02<00:00,  1.83batch/s]
# Epoch 31, Valid Loss: 0.1046, Valid IoU: 0.8187, Valid Accuracy: 0.9610, Valid Dice: 0.8939, Valid Precision: 0.9236, Valid Recall: 0.8691, Valid BalancedAccuracy: 0.8691, Valid IoU_flood: 0.6799, Valid IoU_background: 0.9575, Valid Dice_flood: 0.8095, Valid Dice_background: 0.9783, Valid Precision_flood: 0.8775, Valid Precision_background: 0.9697, Valid Recall_flood: 0.7512, Valid Recall_background: 0.9870
# INFO:training_logger:Epoch 31, Valid Loss: 0.1046, Valid IoU: 0.8187, Valid Accuracy: 0.9610, Valid Dice: 0.8939, Valid Precision: 0.9236, Valid Recall: 0.8691, Valid BalancedAccuracy: 0.8691, Valid IoU_flood: 0.6799, Valid IoU_background: 0.9575, Valid Dice_flood: 0.8095, Valid Dice_background: 0.9783, Valid Precision_flood: 0.8775, Valid Precision_background: 0.9697, Valid Recall_flood: 0.7512, Valid Recall_background: 0.9870
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 32, LR: 0.00008713, Train Loss: 0.0916, Train IoU: 0.8409, Train Accuracy: 0.9510, Train Dice: 0.9102, Train Precision: 0.9086, Train Recall: 0.9118, Train BalancedAccuracy: 0.9118, Train IoU_flood: 0.7387, Train IoU_background: 0.9432, Train Dice_flood: 0.8497, Train Dice_background: 0.9708, Train Precision_flood: 0.8456, Train Precision_background: 0.9717, Train Recall_flood: 0.8538, Train Recall_background: 0.9698
# INFO:training_logger:Epoch 32, LR: 0.00008713, Train Loss: 0.0916, Train IoU: 0.8409, Train Accuracy: 0.9510, Train Dice: 0.9102, Train Precision: 0.9086, Train Recall: 0.9118, Train BalancedAccuracy: 0.9118, Train IoU_flood: 0.7387, Train IoU_background: 0.9432, Train Dice_flood: 0.8497, Train Dice_background: 0.9708, Train Precision_flood: 0.8456, Train Precision_background: 0.9717, Train Recall_flood: 0.8538, Train Recall_background: 0.9698
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.06batch/s]
# Epoch 32, Valid Loss: 0.1040, Valid IoU: 0.8196, Valid Accuracy: 0.9618, Valid Dice: 0.8944, Valid Precision: 0.9322, Valid Recall: 0.8642, Valid BalancedAccuracy: 0.8642, Valid IoU_flood: 0.6807, Valid IoU_background: 0.9584, Valid Dice_flood: 0.8101, Valid Dice_background: 0.9788, Valid Precision_flood: 0.8961, Valid Precision_background: 0.9684, Valid Recall_flood: 0.7391, Valid Recall_background: 0.9894
# INFO:training_logger:Epoch 32, Valid Loss: 0.1040, Valid IoU: 0.8196, Valid Accuracy: 0.9618, Valid Dice: 0.8944, Valid Precision: 0.9322, Valid Recall: 0.8642, Valid BalancedAccuracy: 0.8642, Valid IoU_flood: 0.6807, Valid IoU_background: 0.9584, Valid Dice_flood: 0.8101, Valid Dice_background: 0.9788, Valid Precision_flood: 0.8961, Valid Precision_background: 0.9684, Valid Recall_flood: 0.7391, Valid Recall_background: 0.9894
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 33, LR: 0.00008278, Train Loss: 0.0912, Train IoU: 0.8411, Train Accuracy: 0.9512, Train Dice: 0.9104, Train Precision: 0.9095, Train Recall: 0.9112, Train BalancedAccuracy: 0.9112, Train IoU_flood: 0.7389, Train IoU_background: 0.9434, Train Dice_flood: 0.8499, Train Dice_background: 0.9709, Train Precision_flood: 0.8476, Train Precision_background: 0.9714, Train Recall_flood: 0.8521, Train Recall_background: 0.9704
# INFO:training_logger:Epoch 33, LR: 0.00008278, Train Loss: 0.0912, Train IoU: 0.8411, Train Accuracy: 0.9512, Train Dice: 0.9104, Train Precision: 0.9095, Train Recall: 0.9112, Train BalancedAccuracy: 0.9112, Train IoU_flood: 0.7389, Train IoU_background: 0.9434, Train Dice_flood: 0.8499, Train Dice_background: 0.9709, Train Precision_flood: 0.8476, Train Precision_background: 0.9714, Train Recall_flood: 0.8521, Train Recall_background: 0.9704
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.12batch/s]
# Epoch 33, Valid Loss: 0.1026, Valid IoU: 0.8232, Valid Accuracy: 0.9622, Valid Dice: 0.8969, Valid Precision: 0.9275, Valid Recall: 0.8716, Valid BalancedAccuracy: 0.8716, Valid IoU_flood: 0.6877, Valid IoU_background: 0.9587, Valid Dice_flood: 0.8150, Valid Dice_background: 0.9789, Valid Precision_flood: 0.8849, Valid Precision_background: 0.9702, Valid Recall_flood: 0.7553, Valid Recall_background: 0.9878
# INFO:training_logger:Epoch 33, Valid Loss: 0.1026, Valid IoU: 0.8232, Valid Accuracy: 0.9622, Valid Dice: 0.8969, Valid Precision: 0.9275, Valid Recall: 0.8716, Valid BalancedAccuracy: 0.8716, Valid IoU_flood: 0.6877, Valid IoU_background: 0.9587, Valid Dice_flood: 0.8150, Valid Dice_background: 0.9789, Valid Precision_flood: 0.8849, Valid Precision_background: 0.9702, Valid Recall_flood: 0.7553, Valid Recall_background: 0.9878
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 34, LR: 0.00007795, Train Loss: 0.0912, Train IoU: 0.8413, Train Accuracy: 0.9512, Train Dice: 0.9105, Train Precision: 0.9092, Train Recall: 0.9118, Train BalancedAccuracy: 0.9118, Train IoU_flood: 0.7392, Train IoU_background: 0.9434, Train Dice_flood: 0.8501, Train Dice_background: 0.9709, Train Precision_flood: 0.8467, Train Precision_background: 0.9716, Train Recall_flood: 0.8534, Train Recall_background: 0.9701
# INFO:training_logger:Epoch 34, LR: 0.00007795, Train Loss: 0.0912, Train IoU: 0.8413, Train Accuracy: 0.9512, Train Dice: 0.9105, Train Precision: 0.9092, Train Recall: 0.9118, Train BalancedAccuracy: 0.9118, Train IoU_flood: 0.7392, Train IoU_background: 0.9434, Train Dice_flood: 0.8501, Train Dice_background: 0.9709, Train Precision_flood: 0.8467, Train Precision_background: 0.9716, Train Recall_flood: 0.8534, Train Recall_background: 0.9701
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.11batch/s]
# Epoch 34, Valid Loss: 0.1060, Valid IoU: 0.8170, Valid Accuracy: 0.9613, Valid Dice: 0.8926, Valid Precision: 0.9326, Valid Recall: 0.8611, Valid BalancedAccuracy: 0.8611, Valid IoU_flood: 0.6760, Valid IoU_background: 0.9579, Valid Dice_flood: 0.8067, Valid Dice_background: 0.9785, Valid Precision_flood: 0.8977, Valid Precision_background: 0.9676, Valid Recall_flood: 0.7325, Valid Recall_background: 0.9897
# INFO:training_logger:Epoch 34, Valid Loss: 0.1060, Valid IoU: 0.8170, Valid Accuracy: 0.9613, Valid Dice: 0.8926, Valid Precision: 0.9326, Valid Recall: 0.8611, Valid BalancedAccuracy: 0.8611, Valid IoU_flood: 0.6760, Valid IoU_background: 0.9579, Valid Dice_flood: 0.8067, Valid Dice_background: 0.9785, Valid Precision_flood: 0.8977, Valid Precision_background: 0.9676, Valid Recall_flood: 0.7325, Valid Recall_background: 0.9897
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 35, LR: 0.00007272, Train Loss: 0.0905, Train IoU: 0.8421, Train Accuracy: 0.9515, Train Dice: 0.9110, Train Precision: 0.9097, Train Recall: 0.9123, Train BalancedAccuracy: 0.9123, Train IoU_flood: 0.7405, Train IoU_background: 0.9437, Train Dice_flood: 0.8509, Train Dice_background: 0.9710, Train Precision_flood: 0.8476, Train Precision_background: 0.9718, Train Recall_flood: 0.8543, Train Recall_background: 0.9703
# INFO:training_logger:Epoch 35, LR: 0.00007272, Train Loss: 0.0905, Train IoU: 0.8421, Train Accuracy: 0.9515, Train Dice: 0.9110, Train Precision: 0.9097, Train Recall: 0.9123, Train BalancedAccuracy: 0.9123, Train IoU_flood: 0.7405, Train IoU_background: 0.9437, Train Dice_flood: 0.8509, Train Dice_background: 0.9710, Train Precision_flood: 0.8476, Train Precision_background: 0.9718, Train Recall_flood: 0.8543, Train Recall_background: 0.9703
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.24batch/s]
# Epoch 35, Valid Loss: 0.1030, Valid IoU: 0.8230, Valid Accuracy: 0.9625, Valid Dice: 0.8968, Valid Precision: 0.9322, Valid Recall: 0.8681, Valid BalancedAccuracy: 0.8681, Valid IoU_flood: 0.6869, Valid IoU_background: 0.9591, Valid Dice_flood: 0.8144, Valid Dice_background: 0.9791, Valid Precision_flood: 0.8950, Valid Precision_background: 0.9693, Valid Recall_flood: 0.7471, Valid Recall_background: 0.9891
# INFO:training_logger:Epoch 35, Valid Loss: 0.1030, Valid IoU: 0.8230, Valid Accuracy: 0.9625, Valid Dice: 0.8968, Valid Precision: 0.9322, Valid Recall: 0.8681, Valid BalancedAccuracy: 0.8681, Valid IoU_flood: 0.6869, Valid IoU_background: 0.9591, Valid Dice_flood: 0.8144, Valid Dice_background: 0.9791, Valid Precision_flood: 0.8950, Valid Precision_background: 0.9693, Valid Recall_flood: 0.7471, Valid Recall_background: 0.9891
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 36, LR: 0.00006718, Train Loss: 0.0906, Train IoU: 0.8423, Train Accuracy: 0.9515, Train Dice: 0.9111, Train Precision: 0.9096, Train Recall: 0.9126, Train BalancedAccuracy: 0.9126, Train IoU_flood: 0.7408, Train IoU_background: 0.9437, Train Dice_flood: 0.8511, Train Dice_background: 0.9710, Train Precision_flood: 0.8473, Train Precision_background: 0.9719, Train Recall_flood: 0.8550, Train Recall_background: 0.9702
# INFO:training_logger:Epoch 36, LR: 0.00006718, Train Loss: 0.0906, Train IoU: 0.8423, Train Accuracy: 0.9515, Train Dice: 0.9111, Train Precision: 0.9096, Train Recall: 0.9126, Train BalancedAccuracy: 0.9126, Train IoU_flood: 0.7408, Train IoU_background: 0.9437, Train Dice_flood: 0.8511, Train Dice_background: 0.9710, Train Precision_flood: 0.8473, Train Precision_background: 0.9719, Train Recall_flood: 0.8550, Train Recall_background: 0.9702
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.38batch/s]
# Epoch 36, Valid Loss: 0.1076, Valid IoU: 0.8146, Valid Accuracy: 0.9607, Valid Dice: 0.8910, Valid Precision: 0.9303, Valid Recall: 0.8600, Valid BalancedAccuracy: 0.8600, Valid IoU_flood: 0.6720, Valid IoU_background: 0.9572, Valid Dice_flood: 0.8039, Valid Dice_background: 0.9782, Valid Precision_flood: 0.8932, Valid Precision_background: 0.9674, Valid Recall_flood: 0.7308, Valid Recall_background: 0.9892
# INFO:training_logger:Epoch 36, Valid Loss: 0.1076, Valid IoU: 0.8146, Valid Accuracy: 0.9607, Valid Dice: 0.8910, Valid Precision: 0.9303, Valid Recall: 0.8600, Valid BalancedAccuracy: 0.8600, Valid IoU_flood: 0.6720, Valid IoU_background: 0.9572, Valid Dice_flood: 0.8039, Valid Dice_background: 0.9782, Valid Precision_flood: 0.8932, Valid Precision_background: 0.9674, Valid Recall_flood: 0.7308, Valid Recall_background: 0.9892
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 37, LR: 0.00006140, Train Loss: 0.0902, Train IoU: 0.8422, Train Accuracy: 0.9515, Train Dice: 0.9111, Train Precision: 0.9100, Train Recall: 0.9121, Train BalancedAccuracy: 0.9121, Train IoU_flood: 0.7407, Train IoU_background: 0.9438, Train Dice_flood: 0.8510, Train Dice_background: 0.9711, Train Precision_flood: 0.8483, Train Precision_background: 0.9717, Train Recall_flood: 0.8538, Train Recall_background: 0.9705
# INFO:training_logger:Epoch 37, LR: 0.00006140, Train Loss: 0.0902, Train IoU: 0.8422, Train Accuracy: 0.9515, Train Dice: 0.9111, Train Precision: 0.9100, Train Recall: 0.9121, Train BalancedAccuracy: 0.9121, Train IoU_flood: 0.7407, Train IoU_background: 0.9438, Train Dice_flood: 0.8510, Train Dice_background: 0.9711, Train Precision_flood: 0.8483, Train Precision_background: 0.9717, Train Recall_flood: 0.8538, Train Recall_background: 0.9705
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.26batch/s]
# Epoch 37, Valid Loss: 0.1037, Valid IoU: 0.8198, Valid Accuracy: 0.9616, Valid Dice: 0.8946, Valid Precision: 0.9287, Valid Recall: 0.8668, Valid BalancedAccuracy: 0.8668, Valid IoU_flood: 0.6814, Valid IoU_background: 0.9581, Valid Dice_flood: 0.8105, Valid Dice_background: 0.9786, Valid Precision_flood: 0.8884, Valid Precision_background: 0.9690, Valid Recall_flood: 0.7452, Valid Recall_background: 0.9884
# INFO:training_logger:Epoch 37, Valid Loss: 0.1037, Valid IoU: 0.8198, Valid Accuracy: 0.9616, Valid Dice: 0.8946, Valid Precision: 0.9287, Valid Recall: 0.8668, Valid BalancedAccuracy: 0.8668, Valid IoU_flood: 0.6814, Valid IoU_background: 0.9581, Valid Dice_flood: 0.8105, Valid Dice_background: 0.9786, Valid Precision_flood: 0.8884, Valid Precision_background: 0.9690, Valid Recall_flood: 0.7452, Valid Recall_background: 0.9884
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 38, LR: 0.00005548, Train Loss: 0.0898, Train IoU: 0.8427, Train Accuracy: 0.9517, Train Dice: 0.9114, Train Precision: 0.9101, Train Recall: 0.9127, Train BalancedAccuracy: 0.9127, Train IoU_flood: 0.7416, Train IoU_background: 0.9439, Train Dice_flood: 0.8516, Train Dice_background: 0.9712, Train Precision_flood: 0.8482, Train Precision_background: 0.9719, Train Recall_flood: 0.8550, Train Recall_background: 0.9704
# INFO:training_logger:Epoch 38, LR: 0.00005548, Train Loss: 0.0898, Train IoU: 0.8427, Train Accuracy: 0.9517, Train Dice: 0.9114, Train Precision: 0.9101, Train Recall: 0.9127, Train BalancedAccuracy: 0.9127, Train IoU_flood: 0.7416, Train IoU_background: 0.9439, Train Dice_flood: 0.8516, Train Dice_background: 0.9712, Train Precision_flood: 0.8482, Train Precision_background: 0.9719, Train Recall_flood: 0.8550, Train Recall_background: 0.9704
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.13batch/s]
# Epoch 38, Valid Loss: 0.1032, Valid IoU: 0.8216, Valid Accuracy: 0.9619, Valid Dice: 0.8958, Valid Precision: 0.9284, Valid Recall: 0.8691, Valid BalancedAccuracy: 0.8691, Valid IoU_flood: 0.6847, Valid IoU_background: 0.9585, Valid Dice_flood: 0.8129, Valid Dice_background: 0.9788, Valid Precision_flood: 0.8871, Valid Precision_background: 0.9696, Valid Recall_flood: 0.7501, Valid Recall_background: 0.9882
# INFO:training_logger:Epoch 38, Valid Loss: 0.1032, Valid IoU: 0.8216, Valid Accuracy: 0.9619, Valid Dice: 0.8958, Valid Precision: 0.9284, Valid Recall: 0.8691, Valid BalancedAccuracy: 0.8691, Valid IoU_flood: 0.6847, Valid IoU_background: 0.9585, Valid Dice_flood: 0.8129, Valid Dice_background: 0.9788, Valid Precision_flood: 0.8871, Valid Precision_background: 0.9696, Valid Recall_flood: 0.7501, Valid Recall_background: 0.9882
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 39, LR: 0.00004952, Train Loss: 0.0892, Train IoU: 0.8435, Train Accuracy: 0.9519, Train Dice: 0.9118, Train Precision: 0.9105, Train Recall: 0.9132, Train BalancedAccuracy: 0.9132, Train IoU_flood: 0.7427, Train IoU_background: 0.9442, Train Dice_flood: 0.8524, Train Dice_background: 0.9713, Train Precision_flood: 0.8489, Train Precision_background: 0.9721, Train Recall_flood: 0.8559, Train Recall_background: 0.9705
# INFO:training_logger:Epoch 39, LR: 0.00004952, Train Loss: 0.0892, Train IoU: 0.8435, Train Accuracy: 0.9519, Train Dice: 0.9118, Train Precision: 0.9105, Train Recall: 0.9132, Train BalancedAccuracy: 0.9132, Train IoU_flood: 0.7427, Train IoU_background: 0.9442, Train Dice_flood: 0.8524, Train Dice_background: 0.9713, Train Precision_flood: 0.8489, Train Precision_background: 0.9721, Train Recall_flood: 0.8559, Train Recall_background: 0.9705
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.22batch/s]
# Epoch 39, Valid Loss: 0.1080, Valid IoU: 0.8123, Valid Accuracy: 0.9598, Valid Dice: 0.8894, Valid Precision: 0.9245, Valid Recall: 0.8611, Valid BalancedAccuracy: 0.8611, Valid IoU_flood: 0.6683, Valid IoU_background: 0.9563, Valid Dice_flood: 0.8012, Valid Dice_background: 0.9776, Valid Precision_flood: 0.8813, Valid Precision_background: 0.9678, Valid Recall_flood: 0.7344, Valid Recall_background: 0.9877
# INFO:training_logger:Epoch 39, Valid Loss: 0.1080, Valid IoU: 0.8123, Valid Accuracy: 0.9598, Valid Dice: 0.8894, Valid Precision: 0.9245, Valid Recall: 0.8611, Valid BalancedAccuracy: 0.8611, Valid IoU_flood: 0.6683, Valid IoU_background: 0.9563, Valid Dice_flood: 0.8012, Valid Dice_background: 0.9776, Valid Precision_flood: 0.8813, Valid Precision_background: 0.9678, Valid Recall_flood: 0.7344, Valid Recall_background: 0.9877
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 40, LR: 0.00004360, Train Loss: 0.0898, Train IoU: 0.8435, Train Accuracy: 0.9519, Train Dice: 0.9118, Train Precision: 0.9102, Train Recall: 0.9135, Train BalancedAccuracy: 0.9135, Train IoU_flood: 0.7428, Train IoU_background: 0.9442, Train Dice_flood: 0.8524, Train Dice_background: 0.9713, Train Precision_flood: 0.8482, Train Precision_background: 0.9722, Train Recall_flood: 0.8566, Train Recall_background: 0.9703
# INFO:training_logger:Epoch 40, LR: 0.00004360, Train Loss: 0.0898, Train IoU: 0.8435, Train Accuracy: 0.9519, Train Dice: 0.9118, Train Precision: 0.9102, Train Recall: 0.9135, Train BalancedAccuracy: 0.9135, Train IoU_flood: 0.7428, Train IoU_background: 0.9442, Train Dice_flood: 0.8524, Train Dice_background: 0.9713, Train Precision_flood: 0.8482, Train Precision_background: 0.9722, Train Recall_flood: 0.8566, Train Recall_background: 0.9703
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.53batch/s]
# Epoch 40, Valid Loss: 0.1006, Valid IoU: 0.8250, Valid Accuracy: 0.9622, Valid Dice: 0.8982, Valid Precision: 0.9221, Valid Recall: 0.8776, Valid BalancedAccuracy: 0.8776, Valid IoU_flood: 0.6914, Valid IoU_background: 0.9586, Valid Dice_flood: 0.8176, Valid Dice_background: 0.9789, Valid Precision_flood: 0.8724, Valid Precision_background: 0.9718, Valid Recall_flood: 0.7692, Valid Recall_background: 0.9861
# INFO:training_logger:Epoch 40, Valid Loss: 0.1006, Valid IoU: 0.8250, Valid Accuracy: 0.9622, Valid Dice: 0.8982, Valid Precision: 0.9221, Valid Recall: 0.8776, Valid BalancedAccuracy: 0.8776, Valid IoU_flood: 0.6914, Valid IoU_background: 0.9586, Valid Dice_flood: 0.8176, Valid Dice_background: 0.9789, Valid Precision_flood: 0.8724, Valid Precision_background: 0.9718, Valid Recall_flood: 0.7692, Valid Recall_background: 0.9861
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 41, LR: 0.00003782, Train Loss: 0.0894, Train IoU: 0.8440, Train Accuracy: 0.9521, Train Dice: 0.9122, Train Precision: 0.9107, Train Recall: 0.9136, Train BalancedAccuracy: 0.9136, Train IoU_flood: 0.7436, Train IoU_background: 0.9444, Train Dice_flood: 0.8530, Train Dice_background: 0.9714, Train Precision_flood: 0.8493, Train Precision_background: 0.9722, Train Recall_flood: 0.8567, Train Recall_background: 0.9706
# INFO:training_logger:Epoch 41, LR: 0.00003782, Train Loss: 0.0894, Train IoU: 0.8440, Train Accuracy: 0.9521, Train Dice: 0.9122, Train Precision: 0.9107, Train Recall: 0.9136, Train BalancedAccuracy: 0.9136, Train IoU_flood: 0.7436, Train IoU_background: 0.9444, Train Dice_flood: 0.8530, Train Dice_background: 0.9714, Train Precision_flood: 0.8493, Train Precision_background: 0.9722, Train Recall_flood: 0.8567, Train Recall_background: 0.9706
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.23batch/s]
# Epoch 41, Valid Loss: 0.1009, Valid IoU: 0.8253, Valid Accuracy: 0.9631, Valid Dice: 0.8983, Valid Precision: 0.9355, Valid Recall: 0.8685, Valid BalancedAccuracy: 0.8685, Valid IoU_flood: 0.6908, Valid IoU_background: 0.9598, Valid Dice_flood: 0.8172, Valid Dice_background: 0.9795, Valid Precision_flood: 0.9016, Valid Precision_background: 0.9693, Valid Recall_flood: 0.7472, Valid Recall_background: 0.9899
# INFO:training_logger:Epoch 41, Valid Loss: 0.1009, Valid IoU: 0.8253, Valid Accuracy: 0.9631, Valid Dice: 0.8983, Valid Precision: 0.9355, Valid Recall: 0.8685, Valid BalancedAccuracy: 0.8685, Valid IoU_flood: 0.6908, Valid IoU_background: 0.9598, Valid Dice_flood: 0.8172, Valid Dice_background: 0.9795, Valid Precision_flood: 0.9016, Valid Precision_background: 0.9693, Valid Recall_flood: 0.7472, Valid Recall_background: 0.9899
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 42, LR: 0.00003228, Train Loss: 0.0892, Train IoU: 0.8443, Train Accuracy: 0.9522, Train Dice: 0.9124, Train Precision: 0.9110, Train Recall: 0.9138, Train BalancedAccuracy: 0.9138, Train IoU_flood: 0.7441, Train IoU_background: 0.9445, Train Dice_flood: 0.8533, Train Dice_background: 0.9715, Train Precision_flood: 0.8497, Train Precision_background: 0.9723, Train Recall_flood: 0.8569, Train Recall_background: 0.9707
# INFO:training_logger:Epoch 42, LR: 0.00003228, Train Loss: 0.0892, Train IoU: 0.8443, Train Accuracy: 0.9522, Train Dice: 0.9124, Train Precision: 0.9110, Train Recall: 0.9138, Train BalancedAccuracy: 0.9138, Train IoU_flood: 0.7441, Train IoU_background: 0.9445, Train Dice_flood: 0.8533, Train Dice_background: 0.9715, Train Precision_flood: 0.8497, Train Precision_background: 0.9723, Train Recall_flood: 0.8569, Train Recall_background: 0.9707
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.36batch/s]
# Epoch 42, Valid Loss: 0.1016, Valid IoU: 0.8236, Valid Accuracy: 0.9621, Valid Dice: 0.8972, Valid Precision: 0.9249, Valid Recall: 0.8739, Valid BalancedAccuracy: 0.8739, Valid IoU_flood: 0.6886, Valid IoU_background: 0.9586, Valid Dice_flood: 0.8156, Valid Dice_background: 0.9789, Valid Precision_flood: 0.8789, Valid Precision_background: 0.9708, Valid Recall_flood: 0.7607, Valid Recall_background: 0.9870
# INFO:training_logger:Epoch 42, Valid Loss: 0.1016, Valid IoU: 0.8236, Valid Accuracy: 0.9621, Valid Dice: 0.8972, Valid Precision: 0.9249, Valid Recall: 0.8739, Valid BalancedAccuracy: 0.8739, Valid IoU_flood: 0.6886, Valid IoU_background: 0.9586, Valid Dice_flood: 0.8156, Valid Dice_background: 0.9789, Valid Precision_flood: 0.8789, Valid Precision_background: 0.9708, Valid Recall_flood: 0.7607, Valid Recall_background: 0.9870
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 43, LR: 0.00002705, Train Loss: 0.0889, Train IoU: 0.8445, Train Accuracy: 0.9523, Train Dice: 0.9125, Train Precision: 0.9108, Train Recall: 0.9143, Train BalancedAccuracy: 0.9143, Train IoU_flood: 0.7445, Train IoU_background: 0.9446, Train Dice_flood: 0.8535, Train Dice_background: 0.9715, Train Precision_flood: 0.8491, Train Precision_background: 0.9725, Train Recall_flood: 0.8580, Train Recall_background: 0.9705
# INFO:training_logger:Epoch 43, LR: 0.00002705, Train Loss: 0.0889, Train IoU: 0.8445, Train Accuracy: 0.9523, Train Dice: 0.9125, Train Precision: 0.9108, Train Recall: 0.9143, Train BalancedAccuracy: 0.9143, Train IoU_flood: 0.7445, Train IoU_background: 0.9446, Train Dice_flood: 0.8535, Train Dice_background: 0.9715, Train Precision_flood: 0.8491, Train Precision_background: 0.9725, Train Recall_flood: 0.8580, Train Recall_background: 0.9705
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.11batch/s]
# Epoch 43, Valid Loss: 0.1030, Valid IoU: 0.8225, Valid Accuracy: 0.9627, Valid Dice: 0.8964, Valid Precision: 0.9371, Valid Recall: 0.8643, Valid BalancedAccuracy: 0.8643, Valid IoU_flood: 0.6856, Valid IoU_background: 0.9594, Valid Dice_flood: 0.8135, Valid Dice_background: 0.9793, Valid Precision_flood: 0.9059, Valid Precision_background: 0.9683, Valid Recall_flood: 0.7382, Valid Recall_background: 0.9905
# INFO:training_logger:Epoch 43, Valid Loss: 0.1030, Valid IoU: 0.8225, Valid Accuracy: 0.9627, Valid Dice: 0.8964, Valid Precision: 0.9371, Valid Recall: 0.8643, Valid BalancedAccuracy: 0.8643, Valid IoU_flood: 0.6856, Valid IoU_background: 0.9594, Valid Dice_flood: 0.8135, Valid Dice_background: 0.9793, Valid Precision_flood: 0.9059, Valid Precision_background: 0.9683, Valid Recall_flood: 0.7382, Valid Recall_background: 0.9905
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 44, LR: 0.00002222, Train Loss: 0.0888, Train IoU: 0.8451, Train Accuracy: 0.9525, Train Dice: 0.9128, Train Precision: 0.9115, Train Recall: 0.9142, Train BalancedAccuracy: 0.9142, Train IoU_flood: 0.7453, Train IoU_background: 0.9448, Train Dice_flood: 0.8541, Train Dice_background: 0.9716, Train Precision_flood: 0.8505, Train Precision_background: 0.9724, Train Recall_flood: 0.8577, Train Recall_background: 0.9708
# INFO:training_logger:Epoch 44, LR: 0.00002222, Train Loss: 0.0888, Train IoU: 0.8451, Train Accuracy: 0.9525, Train Dice: 0.9128, Train Precision: 0.9115, Train Recall: 0.9142, Train BalancedAccuracy: 0.9142, Train IoU_flood: 0.7453, Train IoU_background: 0.9448, Train Dice_flood: 0.8541, Train Dice_background: 0.9716, Train Precision_flood: 0.8505, Train Precision_background: 0.9724, Train Recall_flood: 0.8577, Train Recall_background: 0.9708
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.53batch/s]
# Epoch 44, Valid Loss: 0.1001, Valid IoU: 0.8261, Valid Accuracy: 0.9624, Valid Dice: 0.8989, Valid Precision: 0.9229, Valid Recall: 0.8782, Valid BalancedAccuracy: 0.8782, Valid IoU_flood: 0.6932, Valid IoU_background: 0.9589, Valid Dice_flood: 0.8188, Valid Dice_background: 0.9790, Valid Precision_flood: 0.8739, Valid Precision_background: 0.9719, Valid Recall_flood: 0.7702, Valid Recall_background: 0.9862
# INFO:training_logger:Epoch 44, Valid Loss: 0.1001, Valid IoU: 0.8261, Valid Accuracy: 0.9624, Valid Dice: 0.8989, Valid Precision: 0.9229, Valid Recall: 0.8782, Valid BalancedAccuracy: 0.8782, Valid IoU_flood: 0.6932, Valid IoU_background: 0.9589, Valid Dice_flood: 0.8188, Valid Dice_background: 0.9790, Valid Precision_flood: 0.8739, Valid Precision_background: 0.9719, Valid Recall_flood: 0.7702, Valid Recall_background: 0.9862
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 45, LR: 0.00001787, Train Loss: 0.0888, Train IoU: 0.8452, Train Accuracy: 0.9525, Train Dice: 0.9129, Train Precision: 0.9112, Train Recall: 0.9147, Train BalancedAccuracy: 0.9147, Train IoU_flood: 0.7455, Train IoU_background: 0.9448, Train Dice_flood: 0.8542, Train Dice_background: 0.9716, Train Precision_flood: 0.8498, Train Precision_background: 0.9726, Train Recall_flood: 0.8587, Train Recall_background: 0.9706
# INFO:training_logger:Epoch 45, LR: 0.00001787, Train Loss: 0.0888, Train IoU: 0.8452, Train Accuracy: 0.9525, Train Dice: 0.9129, Train Precision: 0.9112, Train Recall: 0.9147, Train BalancedAccuracy: 0.9147, Train IoU_flood: 0.7455, Train IoU_background: 0.9448, Train Dice_flood: 0.8542, Train Dice_background: 0.9716, Train Precision_flood: 0.8498, Train Precision_background: 0.9726, Train Recall_flood: 0.8587, Train Recall_background: 0.9706
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.11batch/s]
# Epoch 45, Valid Loss: 0.0993, Valid IoU: 0.8281, Valid Accuracy: 0.9631, Valid Dice: 0.9003, Valid Precision: 0.9275, Valid Recall: 0.8772, Valid BalancedAccuracy: 0.8772, Valid IoU_flood: 0.6964, Valid IoU_background: 0.9597, Valid Dice_flood: 0.8211, Valid Dice_background: 0.9795, Valid Precision_flood: 0.8834, Valid Precision_background: 0.9716, Valid Recall_flood: 0.7670, Valid Recall_background: 0.9874
# INFO:training_logger:Epoch 45, Valid Loss: 0.0993, Valid IoU: 0.8281, Valid Accuracy: 0.9631, Valid Dice: 0.9003, Valid Precision: 0.9275, Valid Recall: 0.8772, Valid BalancedAccuracy: 0.8772, Valid IoU_flood: 0.6964, Valid IoU_background: 0.9597, Valid Dice_flood: 0.8211, Valid Dice_background: 0.9795, Valid Precision_flood: 0.8834, Valid Precision_background: 0.9716, Valid Recall_flood: 0.7670, Valid Recall_background: 0.9874
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 46, LR: 0.00001407, Train Loss: 0.0879, Train IoU: 0.8457, Train Accuracy: 0.9527, Train Dice: 0.9133, Train Precision: 0.9117, Train Recall: 0.9149, Train BalancedAccuracy: 0.9149, Train IoU_flood: 0.7464, Train IoU_background: 0.9450, Train Dice_flood: 0.8548, Train Dice_background: 0.9717, Train Precision_flood: 0.8506, Train Precision_background: 0.9727, Train Recall_flood: 0.8590, Train Recall_background: 0.9708
# INFO:training_logger:Epoch 46, LR: 0.00001407, Train Loss: 0.0879, Train IoU: 0.8457, Train Accuracy: 0.9527, Train Dice: 0.9133, Train Precision: 0.9117, Train Recall: 0.9149, Train BalancedAccuracy: 0.9149, Train IoU_flood: 0.7464, Train IoU_background: 0.9450, Train Dice_flood: 0.8548, Train Dice_background: 0.9717, Train Precision_flood: 0.8506, Train Precision_background: 0.9727, Train Recall_flood: 0.8590, Train Recall_background: 0.9708
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.37batch/s]
# Epoch 46, Valid Loss: 0.1000, Valid IoU: 0.8267, Valid Accuracy: 0.9626, Valid Dice: 0.8994, Valid Precision: 0.9234, Valid Recall: 0.8786, Valid BalancedAccuracy: 0.8786, Valid IoU_flood: 0.6944, Valid IoU_background: 0.9591, Valid Dice_flood: 0.8196, Valid Dice_background: 0.9791, Valid Precision_flood: 0.8749, Valid Precision_background: 0.9720, Valid Recall_flood: 0.7709, Valid Recall_background: 0.9863
# INFO:training_logger:Epoch 46, Valid Loss: 0.1000, Valid IoU: 0.8267, Valid Accuracy: 0.9626, Valid Dice: 0.8994, Valid Precision: 0.9234, Valid Recall: 0.8786, Valid BalancedAccuracy: 0.8786, Valid IoU_flood: 0.6944, Valid IoU_background: 0.9591, Valid Dice_flood: 0.8196, Valid Dice_background: 0.9791, Valid Precision_flood: 0.8749, Valid Precision_background: 0.9720, Valid Recall_flood: 0.7709, Valid Recall_background: 0.9863
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 47, LR: 0.00001088, Train Loss: 0.0884, Train IoU: 0.8457, Train Accuracy: 0.9527, Train Dice: 0.9133, Train Precision: 0.9118, Train Recall: 0.9147, Train BalancedAccuracy: 0.9147, Train IoU_flood: 0.7464, Train IoU_background: 0.9451, Train Dice_flood: 0.8548, Train Dice_background: 0.9718, Train Precision_flood: 0.8511, Train Precision_background: 0.9726, Train Recall_flood: 0.8585, Train Recall_background: 0.9709
# INFO:training_logger:Epoch 47, LR: 0.00001088, Train Loss: 0.0884, Train IoU: 0.8457, Train Accuracy: 0.9527, Train Dice: 0.9133, Train Precision: 0.9118, Train Recall: 0.9147, Train BalancedAccuracy: 0.9147, Train IoU_flood: 0.7464, Train IoU_background: 0.9451, Train Dice_flood: 0.8548, Train Dice_background: 0.9718, Train Precision_flood: 0.8511, Train Precision_background: 0.9726, Train Recall_flood: 0.8585, Train Recall_background: 0.9709
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.10batch/s]
# Epoch 47, Valid Loss: 0.1002, Valid IoU: 0.8269, Valid Accuracy: 0.9628, Valid Dice: 0.8995, Valid Precision: 0.9258, Valid Recall: 0.8770, Valid BalancedAccuracy: 0.8770, Valid IoU_flood: 0.6945, Valid IoU_background: 0.9594, Valid Dice_flood: 0.8197, Valid Dice_background: 0.9793, Valid Precision_flood: 0.8801, Valid Precision_background: 0.9716, Valid Recall_flood: 0.7670, Valid Recall_background: 0.9871
# INFO:training_logger:Epoch 47, Valid Loss: 0.1002, Valid IoU: 0.8269, Valid Accuracy: 0.9628, Valid Dice: 0.8995, Valid Precision: 0.9258, Valid Recall: 0.8770, Valid BalancedAccuracy: 0.8770, Valid IoU_flood: 0.6945, Valid IoU_background: 0.9594, Valid Dice_flood: 0.8197, Valid Dice_background: 0.9793, Valid Precision_flood: 0.8801, Valid Precision_background: 0.9716, Valid Recall_flood: 0.7670, Valid Recall_background: 0.9871
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 48, LR: 0.00000834, Train Loss: 0.0879, Train IoU: 0.8460, Train Accuracy: 0.9528, Train Dice: 0.9134, Train Precision: 0.9117, Train Recall: 0.9152, Train BalancedAccuracy: 0.9152, Train IoU_flood: 0.7469, Train IoU_background: 0.9451, Train Dice_flood: 0.8551, Train Dice_background: 0.9718, Train Precision_flood: 0.8506, Train Precision_background: 0.9728, Train Recall_flood: 0.8597, Train Recall_background: 0.9708
# INFO:training_logger:Epoch 48, LR: 0.00000834, Train Loss: 0.0879, Train IoU: 0.8460, Train Accuracy: 0.9528, Train Dice: 0.9134, Train Precision: 0.9117, Train Recall: 0.9152, Train BalancedAccuracy: 0.9152, Train IoU_flood: 0.7469, Train IoU_background: 0.9451, Train Dice_flood: 0.8551, Train Dice_background: 0.9718, Train Precision_flood: 0.8506, Train Precision_background: 0.9728, Train Recall_flood: 0.8597, Train Recall_background: 0.9708
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.11batch/s]
# Epoch 48, Valid Loss: 0.0989, Valid IoU: 0.8292, Valid Accuracy: 0.9635, Valid Dice: 0.9010, Valid Precision: 0.9298, Valid Recall: 0.8769, Valid BalancedAccuracy: 0.8769, Valid IoU_flood: 0.6983, Valid IoU_background: 0.9602, Valid Dice_flood: 0.8223, Valid Dice_background: 0.9797, Valid Precision_flood: 0.8881, Valid Precision_background: 0.9715, Valid Recall_flood: 0.7657, Valid Recall_background: 0.9880
# INFO:training_logger:Epoch 48, Valid Loss: 0.0989, Valid IoU: 0.8292, Valid Accuracy: 0.9635, Valid Dice: 0.9010, Valid Precision: 0.9298, Valid Recall: 0.8769, Valid BalancedAccuracy: 0.8769, Valid IoU_flood: 0.6983, Valid IoU_background: 0.9602, Valid Dice_flood: 0.8223, Valid Dice_background: 0.9797, Valid Precision_flood: 0.8881, Valid Precision_background: 0.9715, Valid Recall_flood: 0.7657, Valid Recall_background: 0.9880
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.94batch/s]
# Epoch 49, LR: 0.00000649, Train Loss: 0.0877, Train IoU: 0.8463, Train Accuracy: 0.9529, Train Dice: 0.9136, Train Precision: 0.9120, Train Recall: 0.9153, Train BalancedAccuracy: 0.9153, Train IoU_flood: 0.7473, Train IoU_background: 0.9453, Train Dice_flood: 0.8554, Train Dice_background: 0.9719, Train Precision_flood: 0.8512, Train Precision_background: 0.9728, Train Recall_flood: 0.8597, Train Recall_background: 0.9709
# INFO:training_logger:Epoch 49, LR: 0.00000649, Train Loss: 0.0877, Train IoU: 0.8463, Train Accuracy: 0.9529, Train Dice: 0.9136, Train Precision: 0.9120, Train Recall: 0.9153, Train BalancedAccuracy: 0.9153, Train IoU_flood: 0.7473, Train IoU_background: 0.9453, Train Dice_flood: 0.8554, Train Dice_background: 0.9719, Train Precision_flood: 0.8512, Train Precision_background: 0.9728, Train Recall_flood: 0.8597, Train Recall_background: 0.9709
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.07batch/s]
# Epoch 49, Valid Loss: 0.0996, Valid IoU: 0.8275, Valid Accuracy: 0.9630, Valid Dice: 0.8999, Valid Precision: 0.9264, Valid Recall: 0.8773, Valid BalancedAccuracy: 0.8773, Valid IoU_flood: 0.6955, Valid IoU_background: 0.9595, Valid Dice_flood: 0.8204, Valid Dice_background: 0.9793, Valid Precision_flood: 0.8812, Valid Precision_background: 0.9716, Valid Recall_flood: 0.7675, Valid Recall_background: 0.9872
# INFO:training_logger:Epoch 49, Valid Loss: 0.0996, Valid IoU: 0.8275, Valid Accuracy: 0.9630, Valid Dice: 0.8999, Valid Precision: 0.9264, Valid Recall: 0.8773, Valid BalancedAccuracy: 0.8773, Valid IoU_flood: 0.6955, Valid IoU_background: 0.9595, Valid Dice_flood: 0.8204, Valid Dice_background: 0.9793, Valid Precision_flood: 0.8812, Valid Precision_background: 0.9716, Valid Recall_flood: 0.7675, Valid Recall_background: 0.9872
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 50, LR: 0.00000537, Train Loss: 0.0876, Train IoU: 0.8463, Train Accuracy: 0.9529, Train Dice: 0.9137, Train Precision: 0.9121, Train Recall: 0.9153, Train BalancedAccuracy: 0.9153, Train IoU_flood: 0.7474, Train IoU_background: 0.9453, Train Dice_flood: 0.8555, Train Dice_background: 0.9719, Train Precision_flood: 0.8513, Train Precision_background: 0.9728, Train Recall_flood: 0.8596, Train Recall_background: 0.9710
# INFO:training_logger:Epoch 50, LR: 0.00000537, Train Loss: 0.0876, Train IoU: 0.8463, Train Accuracy: 0.9529, Train Dice: 0.9137, Train Precision: 0.9121, Train Recall: 0.9153, Train BalancedAccuracy: 0.9153, Train IoU_flood: 0.7474, Train IoU_background: 0.9453, Train Dice_flood: 0.8555, Train Dice_background: 0.9719, Train Precision_flood: 0.8513, Train Precision_background: 0.9728, Train Recall_flood: 0.8596, Train Recall_background: 0.9710
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.39batch/s]
# Epoch 50, Valid Loss: 0.0998, Valid IoU: 0.8268, Valid Accuracy: 0.9628, Valid Dice: 0.8994, Valid Precision: 0.9261, Valid Recall: 0.8768, Valid BalancedAccuracy: 0.8768, Valid IoU_flood: 0.6943, Valid IoU_background: 0.9594, Valid Dice_flood: 0.8196, Valid Dice_background: 0.9793, Valid Precision_flood: 0.8808, Valid Precision_background: 0.9715, Valid Recall_flood: 0.7664, Valid Recall_background: 0.9871
# INFO:training_logger:Epoch 50, Valid Loss: 0.0998, Valid IoU: 0.8268, Valid Accuracy: 0.9628, Valid Dice: 0.8994, Valid Precision: 0.9261, Valid Recall: 0.8768, Valid BalancedAccuracy: 0.8768, Valid IoU_flood: 0.6943, Valid IoU_background: 0.9594, Valid Dice_flood: 0.8196, Valid Dice_background: 0.9793, Valid Precision_flood: 0.8808, Valid Precision_background: 0.9715, Valid Recall_flood: 0.7664, Valid Recall_background: 0.9871
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 51, LR: 0.00010000, Train Loss: 0.0913, Train IoU: 0.8417, Train Accuracy: 0.9513, Train Dice: 0.9107, Train Precision: 0.9093, Train Recall: 0.9121, Train BalancedAccuracy: 0.9121, Train IoU_flood: 0.7398, Train IoU_background: 0.9435, Train Dice_flood: 0.8505, Train Dice_background: 0.9709, Train Precision_flood: 0.8469, Train Precision_background: 0.9717, Train Recall_flood: 0.8541, Train Recall_background: 0.9701
# INFO:training_logger:Epoch 51, LR: 0.00010000, Train Loss: 0.0913, Train IoU: 0.8417, Train Accuracy: 0.9513, Train Dice: 0.9107, Train Precision: 0.9093, Train Recall: 0.9121, Train BalancedAccuracy: 0.9121, Train IoU_flood: 0.7398, Train IoU_background: 0.9435, Train Dice_flood: 0.8505, Train Dice_background: 0.9709, Train Precision_flood: 0.8469, Train Precision_background: 0.9717, Train Recall_flood: 0.8541, Train Recall_background: 0.9701
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.39batch/s]
# Epoch 51, Valid Loss: 0.1029, Valid IoU: 0.8216, Valid Accuracy: 0.9623, Valid Dice: 0.8958, Valid Precision: 0.9333, Valid Recall: 0.8659, Valid BalancedAccuracy: 0.8659, Valid IoU_flood: 0.6844, Valid IoU_background: 0.9589, Valid Dice_flood: 0.8126, Valid Dice_background: 0.9790, Valid Precision_flood: 0.8979, Valid Precision_background: 0.9687, Valid Recall_flood: 0.7422, Valid Recall_background: 0.9895
# INFO:training_logger:Epoch 51, Valid Loss: 0.1029, Valid IoU: 0.8216, Valid Accuracy: 0.9623, Valid Dice: 0.8958, Valid Precision: 0.9333, Valid Recall: 0.8659, Valid BalancedAccuracy: 0.8659, Valid IoU_flood: 0.6844, Valid IoU_background: 0.9589, Valid Dice_flood: 0.8126, Valid Dice_background: 0.9790, Valid Precision_flood: 0.8979, Valid Precision_background: 0.9687, Valid Recall_flood: 0.7422, Valid Recall_background: 0.9895
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 52, LR: 0.00009963, Train Loss: 0.0906, Train IoU: 0.8425, Train Accuracy: 0.9516, Train Dice: 0.9113, Train Precision: 0.9098, Train Recall: 0.9127, Train BalancedAccuracy: 0.9127, Train IoU_flood: 0.7413, Train IoU_background: 0.9438, Train Dice_flood: 0.8514, Train Dice_background: 0.9711, Train Precision_flood: 0.8477, Train Precision_background: 0.9719, Train Recall_flood: 0.8552, Train Recall_background: 0.9703
# INFO:training_logger:Epoch 52, LR: 0.00009963, Train Loss: 0.0906, Train IoU: 0.8425, Train Accuracy: 0.9516, Train Dice: 0.9113, Train Precision: 0.9098, Train Recall: 0.9127, Train BalancedAccuracy: 0.9127, Train IoU_flood: 0.7413, Train IoU_background: 0.9438, Train Dice_flood: 0.8514, Train Dice_background: 0.9711, Train Precision_flood: 0.8477, Train Precision_background: 0.9719, Train Recall_flood: 0.8552, Train Recall_background: 0.9703
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.08batch/s]
# Epoch 52, Valid Loss: 0.1034, Valid IoU: 0.8217, Valid Accuracy: 0.9624, Valid Dice: 0.8958, Valid Precision: 0.9354, Valid Recall: 0.8645, Valid BalancedAccuracy: 0.8645, Valid IoU_flood: 0.6843, Valid IoU_background: 0.9591, Valid Dice_flood: 0.8126, Valid Dice_background: 0.9791, Valid Precision_flood: 0.9025, Valid Precision_background: 0.9684, Valid Recall_flood: 0.7389, Valid Recall_background: 0.9901
# INFO:training_logger:Epoch 52, Valid Loss: 0.1034, Valid IoU: 0.8217, Valid Accuracy: 0.9624, Valid Dice: 0.8958, Valid Precision: 0.9354, Valid Recall: 0.8645, Valid BalancedAccuracy: 0.8645, Valid IoU_flood: 0.6843, Valid IoU_background: 0.9591, Valid Dice_flood: 0.8126, Valid Dice_background: 0.9791, Valid Precision_flood: 0.9025, Valid Precision_background: 0.9684, Valid Recall_flood: 0.7389, Valid Recall_background: 0.9901
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 53, LR: 0.00009851, Train Loss: 0.0904, Train IoU: 0.8425, Train Accuracy: 0.9516, Train Dice: 0.9112, Train Precision: 0.9099, Train Recall: 0.9125, Train BalancedAccuracy: 0.9125, Train IoU_flood: 0.7411, Train IoU_background: 0.9438, Train Dice_flood: 0.8513, Train Dice_background: 0.9711, Train Precision_flood: 0.8481, Train Precision_background: 0.9718, Train Recall_flood: 0.8545, Train Recall_background: 0.9704
# INFO:training_logger:Epoch 53, LR: 0.00009851, Train Loss: 0.0904, Train IoU: 0.8425, Train Accuracy: 0.9516, Train Dice: 0.9112, Train Precision: 0.9099, Train Recall: 0.9125, Train BalancedAccuracy: 0.9125, Train IoU_flood: 0.7411, Train IoU_background: 0.9438, Train Dice_flood: 0.8513, Train Dice_background: 0.9711, Train Precision_flood: 0.8481, Train Precision_background: 0.9718, Train Recall_flood: 0.8545, Train Recall_background: 0.9704
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.23batch/s]
# Epoch 53, Valid Loss: 0.1050, Valid IoU: 0.8185, Valid Accuracy: 0.9614, Valid Dice: 0.8937, Valid Precision: 0.9293, Valid Recall: 0.8650, Valid BalancedAccuracy: 0.8650, Valid IoU_flood: 0.6791, Valid IoU_background: 0.9579, Valid Dice_flood: 0.8089, Valid Dice_background: 0.9785, Valid Precision_flood: 0.8900, Valid Precision_background: 0.9686, Valid Recall_flood: 0.7414, Valid Recall_background: 0.9886
# INFO:training_logger:Epoch 53, Valid Loss: 0.1050, Valid IoU: 0.8185, Valid Accuracy: 0.9614, Valid Dice: 0.8937, Valid Precision: 0.9293, Valid Recall: 0.8650, Valid BalancedAccuracy: 0.8650, Valid IoU_flood: 0.6791, Valid IoU_background: 0.9579, Valid Dice_flood: 0.8089, Valid Dice_background: 0.9785, Valid Precision_flood: 0.8900, Valid Precision_background: 0.9686, Valid Recall_flood: 0.7414, Valid Recall_background: 0.9886
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 54, LR: 0.00009666, Train Loss: 0.0903, Train IoU: 0.8429, Train Accuracy: 0.9517, Train Dice: 0.9115, Train Precision: 0.9100, Train Recall: 0.9130, Train BalancedAccuracy: 0.9130, Train IoU_flood: 0.7418, Train IoU_background: 0.9439, Train Dice_flood: 0.8518, Train Dice_background: 0.9712, Train Precision_flood: 0.8479, Train Precision_background: 0.9720, Train Recall_flood: 0.8556, Train Recall_background: 0.9703
# INFO:training_logger:Epoch 54, LR: 0.00009666, Train Loss: 0.0903, Train IoU: 0.8429, Train Accuracy: 0.9517, Train Dice: 0.9115, Train Precision: 0.9100, Train Recall: 0.9130, Train BalancedAccuracy: 0.9130, Train IoU_flood: 0.7418, Train IoU_background: 0.9439, Train Dice_flood: 0.8518, Train Dice_background: 0.9712, Train Precision_flood: 0.8479, Train Precision_background: 0.9720, Train Recall_flood: 0.8556, Train Recall_background: 0.9703
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.20batch/s]
# Epoch 54, Valid Loss: 0.1011, Valid IoU: 0.8255, Valid Accuracy: 0.9618, Valid Dice: 0.8986, Valid Precision: 0.9163, Valid Recall: 0.8827, Valid BalancedAccuracy: 0.8827, Valid IoU_flood: 0.6927, Valid IoU_background: 0.9582, Valid Dice_flood: 0.8185, Valid Dice_background: 0.9787, Valid Precision_flood: 0.8595, Valid Precision_background: 0.9732, Valid Recall_flood: 0.7812, Valid Recall_background: 0.9842
# INFO:training_logger:Epoch 54, Valid Loss: 0.1011, Valid IoU: 0.8255, Valid Accuracy: 0.9618, Valid Dice: 0.8986, Valid Precision: 0.9163, Valid Recall: 0.8827, Valid BalancedAccuracy: 0.8827, Valid IoU_flood: 0.6927, Valid IoU_background: 0.9582, Valid Dice_flood: 0.8185, Valid Dice_background: 0.9787, Valid Precision_flood: 0.8595, Valid Precision_background: 0.9732, Valid Recall_flood: 0.7812, Valid Recall_background: 0.9842
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 55, LR: 0.00009412, Train Loss: 0.0900, Train IoU: 0.8430, Train Accuracy: 0.9517, Train Dice: 0.9116, Train Precision: 0.9098, Train Recall: 0.9133, Train BalancedAccuracy: 0.9133, Train IoU_flood: 0.7421, Train IoU_background: 0.9440, Train Dice_flood: 0.8520, Train Dice_background: 0.9712, Train Precision_flood: 0.8474, Train Precision_background: 0.9722, Train Recall_flood: 0.8565, Train Recall_background: 0.9702
# INFO:training_logger:Epoch 55, LR: 0.00009412, Train Loss: 0.0900, Train IoU: 0.8430, Train Accuracy: 0.9517, Train Dice: 0.9116, Train Precision: 0.9098, Train Recall: 0.9133, Train BalancedAccuracy: 0.9133, Train IoU_flood: 0.7421, Train IoU_background: 0.9440, Train Dice_flood: 0.8520, Train Dice_background: 0.9712, Train Precision_flood: 0.8474, Train Precision_background: 0.9722, Train Recall_flood: 0.8565, Train Recall_background: 0.9702
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.18batch/s]
# Epoch 55, Valid Loss: 0.1053, Valid IoU: 0.8178, Valid Accuracy: 0.9611, Valid Dice: 0.8932, Valid Precision: 0.9267, Valid Recall: 0.8659, Valid BalancedAccuracy: 0.8659, Valid IoU_flood: 0.6780, Valid IoU_background: 0.9576, Valid Dice_flood: 0.8081, Valid Dice_background: 0.9783, Valid Precision_flood: 0.8846, Valid Precision_background: 0.9689, Valid Recall_flood: 0.7438, Valid Recall_background: 0.9880
# ...
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.37batch/s]
# Epoch 192, Valid Loss: 0.0966, Valid IoU: 0.8319, Valid Accuracy: 0.9645, Valid Dice: 0.9027, Valid Precision: 0.9372, Valid Recall: 0.8746, Valid BalancedAccuracy: 0.8746, Valid IoU_flood: 0.7025, Valid IoU_background: 0.9613, Valid Dice_flood: 0.8252, Valid Dice_background: 0.9803, Valid Precision_flood: 0.9037, Valid Precision_background: 0.9708, Valid Recall_flood: 0.7593, Valid Recall_background: 0.9900
# INFO:training_logger:Epoch 192, Valid Loss: 0.0966, Valid IoU: 0.8319, Valid Accuracy: 0.9645, Valid Dice: 0.9027, Valid Precision: 0.9372, Valid Recall: 0.8746, Valid BalancedAccuracy: 0.8746, Valid IoU_flood: 0.7025, Valid IoU_background: 0.9613, Valid Dice_flood: 0.8252, Valid Dice_background: 0.9803, Valid Precision_flood: 0.9037, Valid Precision_background: 0.9708, Valid Recall_flood: 0.7593, Valid Recall_background: 0.9900
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 193, LR: 0.00002705, Train Loss: 0.0794, Train IoU: 0.8608, Train Accuracy: 0.9577, Train Dice: 0.9227, Train Precision: 0.9201, Train Recall: 0.9254, Train BalancedAccuracy: 0.9254, Train IoU_flood: 0.7709, Train IoU_background: 0.9507, Train Dice_flood: 0.8706, Train Dice_background: 0.9747, Train Precision_flood: 0.8639, Train Precision_background: 0.9762, Train Recall_flood: 0.8775, Train Recall_background: 0.9733
# INFO:training_logger:Epoch 193, LR: 0.00002705, Train Loss: 0.0794, Train IoU: 0.8608, Train Accuracy: 0.9577, Train Dice: 0.9227, Train Precision: 0.9201, Train Recall: 0.9254, Train BalancedAccuracy: 0.9254, Train IoU_flood: 0.7709, Train IoU_background: 0.9507, Train Dice_flood: 0.8706, Train Dice_background: 0.9747, Train Precision_flood: 0.8639, Train Precision_background: 0.9762, Train Recall_flood: 0.8775, Train Recall_background: 0.9733
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.08batch/s]
# Epoch 193, Valid Loss: 0.0924, Valid IoU: 0.8383, Valid Accuracy: 0.9650, Valid Dice: 0.9071, Valid Precision: 0.9255, Valid Recall: 0.8907, Valid BalancedAccuracy: 0.8907, Valid IoU_flood: 0.7149, Valid IoU_background: 0.9617, Valid Dice_flood: 0.8337, Valid Dice_background: 0.9805, Valid Precision_flood: 0.8760, Valid Precision_background: 0.9749, Valid Recall_flood: 0.7954, Valid Recall_background: 0.9860
# INFO:training_logger:Epoch 193, Valid Loss: 0.0924, Valid IoU: 0.8383, Valid Accuracy: 0.9650, Valid Dice: 0.9071, Valid Precision: 0.9255, Valid Recall: 0.8907, Valid BalancedAccuracy: 0.8907, Valid IoU_flood: 0.7149, Valid IoU_background: 0.9617, Valid Dice_flood: 0.8337, Valid Dice_background: 0.9805, Valid Precision_flood: 0.8760, Valid Precision_background: 0.9749, Valid Recall_flood: 0.7954, Valid Recall_background: 0.9860
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 194, LR: 0.00002222, Train Loss: 0.0782, Train IoU: 0.8611, Train Accuracy: 0.9578, Train Dice: 0.9228, Train Precision: 0.9202, Train Recall: 0.9255, Train BalancedAccuracy: 0.9255, Train IoU_flood: 0.7713, Train IoU_background: 0.9508, Train Dice_flood: 0.8709, Train Dice_background: 0.9748, Train Precision_flood: 0.8642, Train Precision_background: 0.9763, Train Recall_flood: 0.8777, Train Recall_background: 0.9733
# INFO:training_logger:Epoch 194, LR: 0.00002222, Train Loss: 0.0782, Train IoU: 0.8611, Train Accuracy: 0.9578, Train Dice: 0.9228, Train Precision: 0.9202, Train Recall: 0.9255, Train BalancedAccuracy: 0.9255, Train IoU_flood: 0.7713, Train IoU_background: 0.9508, Train Dice_flood: 0.8709, Train Dice_background: 0.9748, Train Precision_flood: 0.8642, Train Precision_background: 0.9763, Train Recall_flood: 0.8777, Train Recall_background: 0.9733
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.23batch/s]
# Epoch 194, Valid Loss: 0.0940, Valid IoU: 0.8356, Valid Accuracy: 0.9646, Valid Dice: 0.9053, Valid Precision: 0.9271, Valid Recall: 0.8863, Valid BalancedAccuracy: 0.8863, Valid IoU_flood: 0.7100, Valid IoU_background: 0.9612, Valid Dice_flood: 0.8304, Valid Dice_background: 0.9802, Valid Precision_flood: 0.8803, Valid Precision_background: 0.9738, Valid Recall_flood: 0.7858, Valid Recall_background: 0.9868
# INFO:training_logger:Epoch 194, Valid Loss: 0.0940, Valid IoU: 0.8356, Valid Accuracy: 0.9646, Valid Dice: 0.9053, Valid Precision: 0.9271, Valid Recall: 0.8863, Valid BalancedAccuracy: 0.8863, Valid IoU_flood: 0.7100, Valid IoU_background: 0.9612, Valid Dice_flood: 0.8304, Valid Dice_background: 0.9802, Valid Precision_flood: 0.8803, Valid Precision_background: 0.9738, Valid Recall_flood: 0.7858, Valid Recall_background: 0.9868
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 195, LR: 0.00001787, Train Loss: 0.0782, Train IoU: 0.8615, Train Accuracy: 0.9579, Train Dice: 0.9231, Train Precision: 0.9205, Train Recall: 0.9257, Train BalancedAccuracy: 0.9257, Train IoU_flood: 0.7719, Train IoU_background: 0.9510, Train Dice_flood: 0.8713, Train Dice_background: 0.9749, Train Precision_flood: 0.8646, Train Precision_background: 0.9763, Train Recall_flood: 0.8781, Train Recall_background: 0.9734
# INFO:training_logger:Epoch 195, LR: 0.00001787, Train Loss: 0.0782, Train IoU: 0.8615, Train Accuracy: 0.9579, Train Dice: 0.9231, Train Precision: 0.9205, Train Recall: 0.9257, Train BalancedAccuracy: 0.9257, Train IoU_flood: 0.7719, Train IoU_background: 0.9510, Train Dice_flood: 0.8713, Train Dice_background: 0.9749, Train Precision_flood: 0.8646, Train Precision_background: 0.9763, Train Recall_flood: 0.8781, Train Recall_background: 0.9734
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.23batch/s]
# Epoch 195, Valid Loss: 0.0928, Valid IoU: 0.8375, Valid Accuracy: 0.9651, Valid Dice: 0.9065, Valid Precision: 0.9282, Valid Recall: 0.8876, Valid BalancedAccuracy: 0.8876, Valid IoU_flood: 0.7132, Valid IoU_background: 0.9617, Valid Dice_flood: 0.8326, Valid Dice_background: 0.9805, Valid Precision_flood: 0.8823, Valid Precision_background: 0.9741, Valid Recall_flood: 0.7882, Valid Recall_background: 0.9870
# INFO:training_logger:Epoch 195, Valid Loss: 0.0928, Valid IoU: 0.8375, Valid Accuracy: 0.9651, Valid Dice: 0.9065, Valid Precision: 0.9282, Valid Recall: 0.8876, Valid BalancedAccuracy: 0.8876, Valid IoU_flood: 0.7132, Valid IoU_background: 0.9617, Valid Dice_flood: 0.8326, Valid Dice_background: 0.9805, Valid Precision_flood: 0.8823, Valid Precision_background: 0.9741, Valid Recall_flood: 0.7882, Valid Recall_background: 0.9870
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 196, LR: 0.00001407, Train Loss: 0.0784, Train IoU: 0.8618, Train Accuracy: 0.9581, Train Dice: 0.9233, Train Precision: 0.9207, Train Recall: 0.9260, Train BalancedAccuracy: 0.9260, Train IoU_flood: 0.7725, Train IoU_background: 0.9511, Train Dice_flood: 0.8716, Train Dice_background: 0.9749, Train Precision_flood: 0.8650, Train Precision_background: 0.9764, Train Recall_flood: 0.8784, Train Recall_background: 0.9735
# INFO:training_logger:Epoch 196, LR: 0.00001407, Train Loss: 0.0784, Train IoU: 0.8618, Train Accuracy: 0.9581, Train Dice: 0.9233, Train Precision: 0.9207, Train Recall: 0.9260, Train BalancedAccuracy: 0.9260, Train IoU_flood: 0.7725, Train IoU_background: 0.9511, Train Dice_flood: 0.8716, Train Dice_background: 0.9749, Train Precision_flood: 0.8650, Train Precision_background: 0.9764, Train Recall_flood: 0.8784, Train Recall_background: 0.9735
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.10batch/s]
# Epoch 196, Valid Loss: 0.0922, Valid IoU: 0.8391, Valid Accuracy: 0.9652, Valid Dice: 0.9076, Valid Precision: 0.9253, Valid Recall: 0.8918, Valid BalancedAccuracy: 0.8918, Valid IoU_flood: 0.7163, Valid IoU_background: 0.9618, Valid Dice_flood: 0.8347, Valid Dice_background: 0.9805, Valid Precision_flood: 0.8753, Valid Precision_background: 0.9752, Valid Recall_flood: 0.7978, Valid Recall_background: 0.9859
# INFO:training_logger:Epoch 196, Valid Loss: 0.0922, Valid IoU: 0.8391, Valid Accuracy: 0.9652, Valid Dice: 0.9076, Valid Precision: 0.9253, Valid Recall: 0.8918, Valid BalancedAccuracy: 0.8918, Valid IoU_flood: 0.7163, Valid IoU_background: 0.9618, Valid Dice_flood: 0.8347, Valid Dice_background: 0.9805, Valid Precision_flood: 0.8753, Valid Precision_background: 0.9752, Valid Recall_flood: 0.7978, Valid Recall_background: 0.9859
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 197, LR: 0.00001088, Train Loss: 0.0777, Train IoU: 0.8619, Train Accuracy: 0.9581, Train Dice: 0.9234, Train Precision: 0.9208, Train Recall: 0.9260, Train BalancedAccuracy: 0.9260, Train IoU_flood: 0.7727, Train IoU_background: 0.9511, Train Dice_flood: 0.8717, Train Dice_background: 0.9750, Train Precision_flood: 0.8651, Train Precision_background: 0.9764, Train Recall_flood: 0.8785, Train Recall_background: 0.9735
# INFO:training_logger:Epoch 197, LR: 0.00001088, Train Loss: 0.0777, Train IoU: 0.8619, Train Accuracy: 0.9581, Train Dice: 0.9234, Train Precision: 0.9208, Train Recall: 0.9260, Train BalancedAccuracy: 0.9260, Train IoU_flood: 0.7727, Train IoU_background: 0.9511, Train Dice_flood: 0.8717, Train Dice_background: 0.9750, Train Precision_flood: 0.8651, Train Precision_background: 0.9764, Train Recall_flood: 0.8785, Train Recall_background: 0.9735
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.35batch/s]
# Epoch 197, Valid Loss: 0.0932, Valid IoU: 0.8370, Valid Accuracy: 0.9648, Valid Dice: 0.9063, Valid Precision: 0.9259, Valid Recall: 0.8889, Valid BalancedAccuracy: 0.8889, Valid IoU_flood: 0.7126, Valid IoU_background: 0.9614, Valid Dice_flood: 0.8322, Valid Dice_background: 0.9803, Valid Precision_flood: 0.8773, Valid Precision_background: 0.9745, Valid Recall_flood: 0.7915, Valid Recall_background: 0.9863
# INFO:training_logger:Epoch 197, Valid Loss: 0.0932, Valid IoU: 0.8370, Valid Accuracy: 0.9648, Valid Dice: 0.9063, Valid Precision: 0.9259, Valid Recall: 0.8889, Valid BalancedAccuracy: 0.8889, Valid IoU_flood: 0.7126, Valid IoU_background: 0.9614, Valid Dice_flood: 0.8322, Valid Dice_background: 0.9803, Valid Precision_flood: 0.8773, Valid Precision_background: 0.9745, Valid Recall_flood: 0.7915, Valid Recall_background: 0.9863
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.92batch/s]
# Epoch 198, LR: 0.00000834, Train Loss: 0.0777, Train IoU: 0.8621, Train Accuracy: 0.9582, Train Dice: 0.9235, Train Precision: 0.9208, Train Recall: 0.9262, Train BalancedAccuracy: 0.9262, Train IoU_flood: 0.7730, Train IoU_background: 0.9512, Train Dice_flood: 0.8720, Train Dice_background: 0.9750, Train Precision_flood: 0.8652, Train Precision_background: 0.9765, Train Recall_flood: 0.8788, Train Recall_background: 0.9735
# INFO:training_logger:Epoch 198, LR: 0.00000834, Train Loss: 0.0777, Train IoU: 0.8621, Train Accuracy: 0.9582, Train Dice: 0.9235, Train Precision: 0.9208, Train Recall: 0.9262, Train BalancedAccuracy: 0.9262, Train IoU_flood: 0.7730, Train IoU_background: 0.9512, Train Dice_flood: 0.8720, Train Dice_background: 0.9750, Train Precision_flood: 0.8652, Train Precision_background: 0.9765, Train Recall_flood: 0.8788, Train Recall_background: 0.9735
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.11batch/s]
# Epoch 198, Valid Loss: 0.0933, Valid IoU: 0.8368, Valid Accuracy: 0.9648, Valid Dice: 0.9061, Valid Precision: 0.9260, Valid Recall: 0.8885, Valid BalancedAccuracy: 0.8885, Valid IoU_flood: 0.7122, Valid IoU_background: 0.9614, Valid Dice_flood: 0.8319, Valid Dice_background: 0.9803, Valid Precision_flood: 0.8777, Valid Precision_background: 0.9744, Valid Recall_flood: 0.7906, Valid Recall_background: 0.9863
# INFO:training_logger:Epoch 198, Valid Loss: 0.0933, Valid IoU: 0.8368, Valid Accuracy: 0.9648, Valid Dice: 0.9061, Valid Precision: 0.9260, Valid Recall: 0.8885, Valid BalancedAccuracy: 0.8885, Valid IoU_flood: 0.7122, Valid IoU_background: 0.9614, Valid Dice_flood: 0.8319, Valid Dice_background: 0.9803, Valid Precision_flood: 0.8777, Valid Precision_background: 0.9744, Valid Recall_flood: 0.7906, Valid Recall_background: 0.9863
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 199, LR: 0.00000649, Train Loss: 0.0778, Train IoU: 0.8623, Train Accuracy: 0.9582, Train Dice: 0.9236, Train Precision: 0.9210, Train Recall: 0.9262, Train BalancedAccuracy: 0.9262, Train IoU_flood: 0.7733, Train IoU_background: 0.9513, Train Dice_flood: 0.8721, Train Dice_background: 0.9750, Train Precision_flood: 0.8656, Train Precision_background: 0.9765, Train Recall_flood: 0.8788, Train Recall_background: 0.9736
# INFO:training_logger:Epoch 199, LR: 0.00000649, Train Loss: 0.0778, Train IoU: 0.8623, Train Accuracy: 0.9582, Train Dice: 0.9236, Train Precision: 0.9210, Train Recall: 0.9262, Train BalancedAccuracy: 0.9262, Train IoU_flood: 0.7733, Train IoU_background: 0.9513, Train Dice_flood: 0.8721, Train Dice_background: 0.9750, Train Precision_flood: 0.8656, Train Precision_background: 0.9765, Train Recall_flood: 0.8788, Train Recall_background: 0.9736
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.54batch/s]
# Epoch 199, Valid Loss: 0.0938, Valid IoU: 0.8361, Valid Accuracy: 0.9646, Valid Dice: 0.9057, Valid Precision: 0.9261, Valid Recall: 0.8877, Valid BalancedAccuracy: 0.8877, Valid IoU_flood: 0.7110, Valid IoU_background: 0.9613, Valid Dice_flood: 0.8311, Valid Dice_background: 0.9803, Valid Precision_flood: 0.8780, Valid Precision_background: 0.9742, Valid Recall_flood: 0.7889, Valid Recall_background: 0.9864
# INFO:training_logger:Epoch 199, Valid Loss: 0.0938, Valid IoU: 0.8361, Valid Accuracy: 0.9646, Valid Dice: 0.9057, Valid Precision: 0.9261, Valid Recall: 0.8877, Valid BalancedAccuracy: 0.8877, Valid IoU_flood: 0.7110, Valid IoU_background: 0.9613, Valid Dice_flood: 0.8311, Valid Dice_background: 0.9803, Valid Precision_flood: 0.8780, Valid Precision_background: 0.9742, Valid Recall_flood: 0.7889, Valid Recall_background: 0.9864
# Train: 100%|██████████| 219/219 [01:53<00:00,  1.93batch/s]
# Epoch 200, LR: 0.00000537, Train Loss: 0.0777, Train IoU: 0.8623, Train Accuracy: 0.9582, Train Dice: 0.9236, Train Precision: 0.9210, Train Recall: 0.9262, Train BalancedAccuracy: 0.9262, Train IoU_flood: 0.7733, Train IoU_background: 0.9513, Train Dice_flood: 0.8722, Train Dice_background: 0.9750, Train Precision_flood: 0.8655, Train Precision_background: 0.9765, Train Recall_flood: 0.8789, Train Recall_background: 0.9736
# INFO:training_logger:Epoch 200, LR: 0.00000537, Train Loss: 0.0777, Train IoU: 0.8623, Train Accuracy: 0.9582, Train Dice: 0.9236, Train Precision: 0.9210, Train Recall: 0.9262, Train BalancedAccuracy: 0.9262, Train IoU_flood: 0.7733, Train IoU_background: 0.9513, Train Dice_flood: 0.8722, Train Dice_background: 0.9750, Train Precision_flood: 0.8655, Train Precision_background: 0.9765, Train Recall_flood: 0.8789, Train Recall_background: 0.9736
# Valid: 100%|██████████| 5/5 [00:01<00:00,  4.10batch/s]
# Epoch 200, Valid Loss: 0.0933, Valid IoU: 0.8369, Valid Accuracy: 0.9648, Valid Dice: 0.9062, Valid Precision: 0.9256, Valid Recall: 0.8890, Valid BalancedAccuracy: 0.8890, Valid IoU_flood: 0.7124, Valid IoU_background: 0.9614, Valid Dice_flood: 0.8321, Valid Dice_background: 0.9803, Valid Precision_flood: 0.8768, Valid Precision_background: 0.9745, Valid Recall_flood: 0.7917, Valid Recall_background: 0.9862
# INFO:training_logger:Epoch 200, Valid Loss: 0.0933, Valid IoU: 0.8369, Valid Accuracy: 0.9648, Valid Dice: 0.9062, Valid Precision: 0.9256, Valid Recall: 0.8890, Valid BalancedAccuracy: 0.8890, Valid IoU_flood: 0.7124, Valid IoU_background: 0.9614, Valid Dice_flood: 0.8321, Valid Dice_background: 0.9803, Valid Precision_flood: 0.8768, Valid Precision_background: 0.9745, Valid Recall_flood: 0.7917, Valid Recall_background: 0.9862

# %%
# !mv {txt_train} {txt_dir}/

# %%
# !mv {weights} {weights_dir}/

# %%
# !mv {best_weights} {weights_dir}/

# %%
test(num_best_epoch)
test(num_epochs)
# Out:
# Test:   0%|          | 0/23 [00:00<?, ?batch/s]<ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# Test: 100%|██████████| 23/23 [00:58<00:00,  2.53s/batch]
# WeightsEpoch: 160, Test IoU: 0.8309, Test Accuracy: 0.9595, Test Dice: 0.9026, Test Precision: 0.9253, Test Recall: 0.8830, Test BalancedAccuracy: 0.8830, Test IoU_flood: 0.7067, Test IoU_background: 0.9551, Test Dice_flood: 0.8282, Test Dice_background: 0.9770, Test Precision_flood: 0.8814, Test Precision_background: 0.9692, Test Recall_flood: 0.7810, Test Recall_background: 0.9850
# INFO:testing_logger:WeightsEpoch: 160, Test IoU: 0.8309, Test Accuracy: 0.9595, Test Dice: 0.9026, Test Precision: 0.9253, Test Recall: 0.8830, Test BalancedAccuracy: 0.8830, Test IoU_flood: 0.7067, Test IoU_background: 0.9551, Test Dice_flood: 0.8282, Test Dice_background: 0.9770, Test Precision_flood: 0.8814, Test Precision_background: 0.9692, Test Recall_flood: 0.7810, Test Recall_background: 0.9850
# WeightsEpoch: 160, Test Aug IoU: 0.8309, Test Accuracy: 0.9596, Test Dice: 0.9026, Test Precision: 0.9272, Test Recall: 0.8816, Test BalancedAccuracy: 0.8816, Test IoU_flood: 0.7066, Test IoU_background: 0.9553, Test Dice_flood: 0.8281, Test Dice_background: 0.9771, Test Precision_flood: 0.8856, Test Precision_background: 0.9688, Test Recall_flood: 0.7776, Test Recall_background: 0.9856
# INFO:testing_logger:WeightsEpoch: 160, Test Aug IoU: 0.8309, Test Accuracy: 0.9596, Test Dice: 0.9026, Test Precision: 0.9272, Test Recall: 0.8816, Test BalancedAccuracy: 0.8816, Test IoU_flood: 0.7066, Test IoU_background: 0.9553, Test Dice_flood: 0.8281, Test Dice_background: 0.9771, Test Precision_flood: 0.8856, Test Precision_background: 0.9688, Test Recall_flood: 0.7776, Test Recall_background: 0.9856
# WeightsEpoch: 160, Test Aug CRF IoU: 0.8038, Test Accuracy: 0.9551, Test Dice: 0.8838, Test Precision: 0.9464, Test Recall: 0.8406, Test BalancedAccuracy: 0.8406, Test IoU_flood: 0.6569, Test IoU_background: 0.9508, Test Dice_flood: 0.7929, Test Dice_background: 0.9748, Test Precision_flood: 0.9357, Test Precision_background: 0.9570, Test Recall_flood: 0.6879, Test Recall_background: 0.9932
# INFO:testing_logger:WeightsEpoch: 160, Test Aug CRF IoU: 0.8038, Test Accuracy: 0.9551, Test Dice: 0.8838, Test Precision: 0.9464, Test Recall: 0.8406, Test BalancedAccuracy: 0.8406, Test IoU_flood: 0.6569, Test IoU_background: 0.9508, Test Dice_flood: 0.7929, Test Dice_background: 0.9748, Test Precision_flood: 0.9357, Test Precision_background: 0.9570, Test Recall_flood: 0.6879, Test Recall_background: 0.9932
# TP_flood = 2004131.0, FP_flood = 269768.0, TN_flood = 17681498.0, FN_flood = 561970.0
# TP_flood_aug = 1995470.0, FP_flood_aug = 257842.0, TN_flood_aug = 17693424.0, FN_flood_aug = 570631.0
# TP_floodaug_crf = 1765264.0, FP_floodaug_crf = 121314.0, TN_floodaug_crf = 17829952.0, FN_floodaug_crf = 800837.0
# Test Bolivia:   0%|          | 0/4 [00:00<?, ?batch/s]<ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# Test Bolivia: 100%|██████████| 4/4 [00:09<00:00,  2.47s/batch]
# WeightsEpoch: 160, TestBolivia IoU: 0.8051, TestB Accuracy: 0.9431, TestB Dice: 0.8862, TestB Precision: 0.9158, TestB Recall: 0.8624, TestB BalancedAccuracy: 0.8624, TestB IoU_flood: 0.6747, TestB IoU_background: 0.9355, TestB Dice_flood: 0.8057, TestB Dice_background: 0.9667, TestB Precision_flood: 0.8784, TestB Precision_background: 0.9531, TestB Recall_flood: 0.7442, TestB Recall_background: 0.9806
# INFO:testing_logger:WeightsEpoch: 160, TestBolivia IoU: 0.8051, TestB Accuracy: 0.9431, TestB Dice: 0.8862, TestB Precision: 0.9158, TestB Recall: 0.8624, TestB BalancedAccuracy: 0.8624, TestB IoU_flood: 0.6747, TestB IoU_background: 0.9355, TestB Dice_flood: 0.8057, TestB Dice_background: 0.9667, TestB Precision_flood: 0.8784, TestB Precision_background: 0.9531, TestB Recall_flood: 0.7442, TestB Recall_background: 0.9806
# WeightsEpoch: 160, TestBolivia Aug IoU: 0.8274, TestB Accuracy: 0.9576, TestB Dice: 0.9004, TestB Precision: 0.9257, TestB Recall: 0.8789, TestB BalancedAccuracy: 0.8789, TestB IoU_flood: 0.7019, TestB IoU_background: 0.9529, TestB Dice_flood: 0.8249, TestB Dice_background: 0.9759, TestB Precision_flood: 0.8845, TestB Precision_background: 0.9669, TestB Recall_flood: 0.7728, TestB Recall_background: 0.9850
# INFO:testing_logger:WeightsEpoch: 160, TestBolivia Aug IoU: 0.8274, TestB Accuracy: 0.9576, TestB Dice: 0.9004, TestB Precision: 0.9257, TestB Recall: 0.8789, TestB BalancedAccuracy: 0.8789, TestB IoU_flood: 0.7019, TestB IoU_background: 0.9529, TestB Dice_flood: 0.8249, TestB Dice_background: 0.9759, TestB Precision_flood: 0.8845, TestB Precision_background: 0.9669, TestB Recall_flood: 0.7728, TestB Recall_background: 0.9850
# WeightsEpoch: 160, TestBolivia Aug CRF IoU: 0.7981, TestB Accuracy: 0.9525, TestB Dice: 0.8799, TestB Precision: 0.9452, TestB Recall: 0.8357, TestB BalancedAccuracy: 0.8357, TestB IoU_flood: 0.6482, TestB IoU_background: 0.9479, TestB Dice_flood: 0.7866, TestB Dice_background: 0.9732, TestB Precision_flood: 0.9362, TestB Precision_background: 0.9541, TestB Recall_flood: 0.6782, TestB Recall_background: 0.9931
# INFO:testing_logger:WeightsEpoch: 160, TestBolivia Aug CRF IoU: 0.7981, TestB Accuracy: 0.9525, TestB Dice: 0.8799, TestB Precision: 0.9452, TestB Recall: 0.8357, TestB BalancedAccuracy: 0.8357, TestB IoU_flood: 0.6482, TestB IoU_background: 0.9479, TestB Dice_flood: 0.7866, TestB Dice_background: 0.9732, TestB Precision_flood: 0.9362, TestB Precision_background: 0.9541, TestB Recall_flood: 0.6782, TestB Recall_background: 0.9931
# Test:   0%|          | 0/23 [00:00<?, ?batch/s]<ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# Test: 100%|██████████| 23/23 [00:56<00:00,  2.44s/batch]
# WeightsEpoch: 100, Test IoU: 0.8288, Test Accuracy: 0.9592, Test Dice: 0.9012, Test Precision: 0.9278, Test Recall: 0.8787, Test BalancedAccuracy: 0.8787, Test IoU_flood: 0.7027, Test IoU_background: 0.9548, Test Dice_flood: 0.8254, Test Dice_background: 0.9769, Test Precision_flood: 0.8877, Test Precision_background: 0.9679, Test Recall_flood: 0.7713, Test Recall_background: 0.9861
# INFO:testing_logger:WeightsEpoch: 100, Test IoU: 0.8288, Test Accuracy: 0.9592, Test Dice: 0.9012, Test Precision: 0.9278, Test Recall: 0.8787, Test BalancedAccuracy: 0.8787, Test IoU_flood: 0.7027, Test IoU_background: 0.9548, Test Dice_flood: 0.8254, Test Dice_background: 0.9769, Test Precision_flood: 0.8877, Test Precision_background: 0.9679, Test Recall_flood: 0.7713, Test Recall_background: 0.9861
# WeightsEpoch: 100, Test Aug IoU: 0.8288, Test Accuracy: 0.9593, Test Dice: 0.9012, Test Precision: 0.9295, Test Recall: 0.8775, Test BalancedAccuracy: 0.8775, Test IoU_flood: 0.7027, Test IoU_background: 0.9550, Test Dice_flood: 0.8254, Test Dice_background: 0.9770, Test Precision_flood: 0.8914, Test Precision_background: 0.9675, Test Recall_flood: 0.7685, Test Recall_background: 0.9866
# INFO:testing_logger:WeightsEpoch: 100, Test Aug IoU: 0.8288, Test Accuracy: 0.9593, Test Dice: 0.9012, Test Precision: 0.9295, Test Recall: 0.8775, Test BalancedAccuracy: 0.8775, Test IoU_flood: 0.7027, Test IoU_background: 0.9550, Test Dice_flood: 0.8254, Test Dice_background: 0.9770, Test Precision_flood: 0.8914, Test Precision_background: 0.9675, Test Recall_flood: 0.7685, Test Recall_background: 0.9866
# WeightsEpoch: 100, Test Aug CRF IoU: 0.8007, Test Accuracy: 0.9544, Test Dice: 0.8816, Test Precision: 0.9468, Test Recall: 0.8372, Test BalancedAccuracy: 0.8372, Test IoU_flood: 0.6512, Test IoU_background: 0.9502, Test Dice_flood: 0.7888, Test Dice_background: 0.9744, Test Precision_flood: 0.9375, Test Precision_background: 0.9561, Test Recall_flood: 0.6808, Test Recall_background: 0.9935
# INFO:testing_logger:WeightsEpoch: 100, Test Aug CRF IoU: 0.8007, Test Accuracy: 0.9544, Test Dice: 0.8816, Test Precision: 0.9468, Test Recall: 0.8372, Test BalancedAccuracy: 0.8372, Test IoU_flood: 0.6512, Test IoU_background: 0.9502, Test Dice_flood: 0.7888, Test Dice_background: 0.9744, Test Precision_flood: 0.9375, Test Precision_background: 0.9561, Test Recall_flood: 0.6808, Test Recall_background: 0.9935
# TP_flood = 1979137.0, FP_flood = 250306.0, TN_flood = 17700960.0, FN_flood = 586964.0
# TP_flood_aug = 1971978.0, FP_flood_aug = 240255.0, TN_flood_aug = 17711011.0, FN_flood_aug = 594123.0
# TP_floodaug_crf = 1747018.0, FP_floodaug_crf = 116547.0, TN_floodaug_crf = 17834719.0, FN_floodaug_crf = 819083.0
# Test Bolivia:   0%|          | 0/4 [00:00<?, ?batch/s]<ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# Test Bolivia: 100%|██████████| 4/4 [00:09<00:00,  2.42s/batch]
# WeightsEpoch: 100, TestBolivia IoU: 0.8014, TestB Accuracy: 0.9422, TestB Dice: 0.8837, TestB Precision: 0.9164, TestB Recall: 0.8578, TestB BalancedAccuracy: 0.8578, TestB IoU_flood: 0.6683, TestB IoU_background: 0.9346, TestB Dice_flood: 0.8012, TestB Dice_background: 0.9662, TestB Precision_flood: 0.8814, TestB Precision_background: 0.9514, TestB Recall_flood: 0.7343, TestB Recall_background: 0.9814
# INFO:testing_logger:WeightsEpoch: 100, TestBolivia IoU: 0.8014, TestB Accuracy: 0.9422, TestB Dice: 0.8837, TestB Precision: 0.9164, TestB Recall: 0.8578, TestB BalancedAccuracy: 0.8578, TestB IoU_flood: 0.6683, TestB IoU_background: 0.9346, TestB Dice_flood: 0.8012, TestB Dice_background: 0.9662, TestB Precision_flood: 0.8814, TestB Precision_background: 0.9514, TestB Recall_flood: 0.7343, TestB Recall_background: 0.9814
# WeightsEpoch: 100, TestBolivia Aug IoU: 0.8248, TestB Accuracy: 0.9572, TestB Dice: 0.8986, TestB Precision: 0.9279, TestB Recall: 0.8743, TestB BalancedAccuracy: 0.8743, TestB IoU_flood: 0.6970, TestB IoU_background: 0.9525, TestB Dice_flood: 0.8215, TestB Dice_background: 0.9757, TestB Precision_flood: 0.8903, TestB Precision_background: 0.9655, TestB Recall_flood: 0.7625, TestB Recall_background: 0.9861
# INFO:testing_logger:WeightsEpoch: 100, TestBolivia Aug IoU: 0.8248, TestB Accuracy: 0.9572, TestB Dice: 0.8986, TestB Precision: 0.9279, TestB Recall: 0.8743, TestB BalancedAccuracy: 0.8743, TestB IoU_flood: 0.6970, TestB IoU_background: 0.9525, TestB Dice_flood: 0.8215, TestB Dice_background: 0.9757, TestB Precision_flood: 0.8903, TestB Precision_background: 0.9655, TestB Recall_flood: 0.7625, TestB Recall_background: 0.9861
# WeightsEpoch: 100, TestBolivia Aug CRF IoU: 0.7943, TestB Accuracy: 0.9517, TestB Dice: 0.8772, TestB Precision: 0.9457, TestB Recall: 0.8316, TestB BalancedAccuracy: 0.8316, TestB IoU_flood: 0.6416, TestB IoU_background: 0.9471, TestB Dice_flood: 0.7817, TestB Dice_background: 0.9728, TestB Precision_flood: 0.9385, TestB Precision_background: 0.9530, TestB Recall_flood: 0.6697, TestB Recall_background: 0.9935
# INFO:testing_logger:WeightsEpoch: 100, TestBolivia Aug CRF IoU: 0.7943, TestB Accuracy: 0.9517, TestB Dice: 0.8772, TestB Precision: 0.9457, TestB Recall: 0.8316, TestB BalancedAccuracy: 0.8316, TestB IoU_flood: 0.6416, TestB IoU_background: 0.9471, TestB Dice_flood: 0.7817, TestB Dice_background: 0.9728, TestB Precision_flood: 0.9385, TestB Precision_background: 0.9530, TestB Recall_flood: 0.6697, TestB Recall_background: 0.9935

# %%
# !mv {txt_test} {txt_dir}/
