# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install segmentation_models_pytorch
# !pip install git+https://github.com/lucasb-eyer/pydensecrf.git
# Out:
# Collecting segmentation_models_pytorch
#   Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: huggingface-hub>=0.24 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (0.31.2)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (2.0.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (11.2.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (0.5.3)
# Requirement already satisfied: timm>=0.9 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (1.0.15)
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8->segmentation_models_pytorch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8->segmentation_models_pytorch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (2025.4.26)
# Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 15.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 132.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 64.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 43.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.7 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, segmentation_models_pytorch
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 segmentation_models_pytorch-0.5.0
# Collecting git+https://github.com/lucasb-eyer/pydensecrf.git
#   Cloning https://github.com/lucasb-eyer/pydensecrf.git to /tmp/pip-req-build-tqovut3z
#   Running command git clone --filter=blob:none --quiet https://github.com/lucasb-eyer/pydensecrf.git /tmp/pip-req-build-tqovut3z
#   Resolved https://github.com/lucasb-eyer/pydensecrf.git to commit 2723c7fa4f2ead16ae1ce3d8afe977724bb8f87f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: pydensecrf
#   Building wheel for pydensecrf (pyproject.toml) ... done
#   Created wheel for pydensecrf: filename=pydensecrf-1.0-cp311-cp311-linux_x86_64.whl size=3440330 sha256=d2091dc39b0a9b6d13896823fd48ff2db2ead562e6a5ab2202d82ec76d8e1bbe
#   Stored in directory: /tmp/pip-ephem-wheel-cache-l9gkpf4k/wheels/ce/8e/34/6dcfa200a9e2ae3627d8009b8bd1ca9b24512bec50a93304de
# Successfully built pydensecrf
# Installing collected packages: pydensecrf
# Successfully installed pydensecrf-1.0

# %%
import numpy as np
import segmentation_models_pytorch as smp
import torch
import os
import cv2
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, BoundaryNorm
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
import torch.nn.functional as F
import glob
from tqdm import tqdm
import albumentations as A
import tifffile
from torch.amp import autocast
from torch.amp import GradScaler
import logging
import pydensecrf.densecrf as dcrf
from pydensecrf.utils import unary_from_softmax, create_pairwise_gaussian, create_pairwise_bilateral
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.7' (you have '2.0.6'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
# !cp -r /content/drive/MyDrive/datasets_and_models/HandLabeled.zip /content/

# %%
# !unzip /content/HandLabeled.zip -d /
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_2_791364_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_2_146222_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Somalia_3_989553_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_2_3285448_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_2_994009_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_3_187318_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_2_163406_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_1_1072277_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Nigeria_2_81933_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_1_348639_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_1_470303_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_1_909806_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_2_152185_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Mekong_1_1111068_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Somalia_3_295782_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_4_1167260_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_2_908474_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_3_956930_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_1_806273_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Mekong_4_1282475_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Somalia_1_989553_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_3_211386_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_4_56450_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_2_273873_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_1_66026_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_4_62897_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_2_953791_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_4_2938657_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_3_247288_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_4_8090_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_3_103447_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_3_1010394_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Mekong_4_213094_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Mekong_3_1282475_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_3_1056717_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_2_707886_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_2_500266_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_3_178753_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_4_7496_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_2_36146_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_2_83200_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_4_187318_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_1_161233_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_1_36146_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_1_883641_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_4_2594119_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_1_997480_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Mekong_3_1395593_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_4_154838_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_4_198534_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_2_474121_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_3_566697_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_2_249079_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Nigeria_4_143329_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_2_486103_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_4_52223_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_3_6199994_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_4_181263_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_2_2523247_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_4_1089161_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_3_5816638_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_3_605682_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_3_655230_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_4_24341_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Somalia_2_886726_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_1_179917_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_4_548910_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Nigeria_2_952958_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_4_65724_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_4_217598_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_3_347609_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Mekong_2_213094_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_1_181503_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_4_97516_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_1_265762_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_1_166709_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Somalia_3_1068756_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Somalia_4_32375_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_3_65724_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_4_748447_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_2_375183_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_2_401863_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_4_146222_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_4_774689_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_3_170264_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_1_132143_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_3_115033_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_1_134751_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_4_8104659_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_3_721886_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_3_54421_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_2_198534_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_4_161233_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Somalia_1_1068756_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_1_7786924_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Mekong_3_16233_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_1_403081_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_1_989230_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Somalia_4_295782_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_2_246718_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_3_324254_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_1_8090_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Nigeria_3_78061_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_3_795075_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_4_956930_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_2_591549_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_4_207862_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_2_337094_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_1_921838_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_4_921838_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_4_170264_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Somalia_2_992457_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_3_86502_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_2_5678382_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_1_943439_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_4_285297_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_1_128663_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_3_712873_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_1_149830_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_4_212687_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_3_25540_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_4_591549_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_3_953791_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_2_712873_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_1_217598_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_1_136196_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_1_212687_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_3_233609_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_3_7856615_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_2_207862_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_2_1036366_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_1_215904_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_4_246510_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_3_354981_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_1_54421_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_3_246718_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_3_373039_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_4_707886_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_4_474121_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_4_134751_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_2_892933_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_3_166709_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_1_1068362_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_2_831672_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_1_59460_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_2_1167260_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_2_161233_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Somalia_2_1068756_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_3_652955_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_2_2938657_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_2_847275_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_3_486103_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_1_981708_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_3_748447_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_4_66026_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_1_58086_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_2_373039_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_2_2594119_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_1_387945_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_2_11422_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_1_887131_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Nigeria_4_439488_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Mekong_1_342411_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Somalia_4_230192_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Mekong_3_774566_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_2_716716_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_4_86502_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Somalia_4_195014_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_2_58086_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_2_721886_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Mekong_2_1191208_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_1_847275_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Mekong_2_119477_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_4_653336_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_2_822142_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_1_2938657_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_3_207862_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Somalia_1_7931_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Nigeria_2_78061_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_2_247656_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_4_943439_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_4_141910_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_1_211406_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_3_591549_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_4_806273_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Nigeria_1_600295_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_1_892933_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_3_760290_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_4_716716_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_3_231124_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_1_194723_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_4_847275_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_1_8104659_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_4_273873_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_4_120804_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_2_103272_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_3_212687_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_3_7786924_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_1_804466_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Somalia_4_1068756_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_1_534470_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_1_91379_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_2_126224_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_1_5816638_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_3_362274_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_3_2594119_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Mekong_2_846007_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Mekong_4_221789_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_2_247288_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Mekong_2_774566_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_3_152185_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_4_1038087_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Somalia_1_295782_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_4_1017769_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_2_1010394_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_1_566697_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_3_49764_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_3_916628_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_2_740461_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_1_5678382_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_2_287642_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Mekong_1_846007_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_4_136196_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_2_179238_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_2_921838_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_1_148318_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_1_500266_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Mekong_4_52610_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Somalia_4_371421_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_2_181503_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Somalia_2_970508_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_1_1017769_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_2_211406_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_1_65724_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_2_8199661_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Somalia_1_992457_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_2_387945_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_3_664261_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_2_548910_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_3_73419_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_2_1068362_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_4_5923267_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_4_247288_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_4_887131_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_3_605492_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_1_24858_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_1_791364_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_4_655230_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_2_48673_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_2_65724_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_1_770353_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Mekong_2_1439641_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_4_605492_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_2_1072277_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_1_482517_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_1_7496_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_3_2523247_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_2_523539_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_1_716716_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Nigeria_2_707067_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_4_791364_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_3_224845_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Somalia_2_32375_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_3_791364_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Somalia_4_970508_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_1_548910_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_2_842775_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_4_638521_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Nigeria_1_143329_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_4_7786924_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_2_181263_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_1_339807_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_2_154838_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_2_8154154_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_3_264787_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_1_36015_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_3_135713_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Somalia_1_626316_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_1_285297_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_3_892933_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_2_11745_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Somalia_3_626316_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_3_249079_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_3_97516_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_1_979278_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_2_760290_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_1_391908_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Mekong_2_221789_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Mekong_1_221789_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_4_5678382_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_3_149787_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_1_73419_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_3_597288_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_4_152185_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Nigeria_4_81933_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Somalia_3_32375_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Nigeria_3_35845_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_4_605682_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_4_773682_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_1_147015_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_4_12870_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_1_61925_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Mekong_1_269835_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_4_24858_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Mekong_3_596495_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_4_149830_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_4_693819_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_1_5923267_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_1_55568_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_3_979278_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_1_956740_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_1_62897_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_3_548910_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_3_147015_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_2_339807_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Nigeria_2_600295_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_2_604222_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Mekong_4_596495_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_3_132143_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_3_246510_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_2_579082_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_2_693819_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_3_36146_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_3_981708_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_1_664261_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_4_892933_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_1_831672_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_4_373039_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_3_1068362_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_4_347609_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_4_115033_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_4_470303_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_1_693819_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_1_224845_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_2_187318_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_3_8090_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_3_148318_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_3_804466_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_1_135389_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_1_604222_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Mekong_2_1395593_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_3_136196_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_2_148318_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_3_909806_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_4_25540_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_3_773682_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_1_149787_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Nigeria_1_78061_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_1_2523247_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Nigeria_4_707067_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_4_383430_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Mekong_2_1248200_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_1_92824_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_2_24341_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_1_551926_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_3_1017769_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_1_638521_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_4_132143_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_3_84195_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_3_2472849_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_1_181263_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_3_179917_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_1_135713_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_3_337094_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_1_260929_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_3_179238_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Nigeria_3_143329_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_4_5816638_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_3_401863_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_1_652955_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_3_11745_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Nigeria_1_529525_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_3_198534_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_3_11869_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_1_48673_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_1_225187_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_1_135434_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_3_400518_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_3_144050_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_2_748447_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_2_354981_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_2_7856615_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_4_1036366_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_4_232060_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_2_136196_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_1_605682_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_4_1076204_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Pakistan_4_667363_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_2_1056717_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_2_324254_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Somalia_1_205466_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_3_707886_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_3_638521_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_3_698338_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_3_4915752_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_3_943439_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Mekong_3_1396181_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_2_66026_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_4_92824_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_2_482517_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_4_178753_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Nigeria_3_952958_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Somalia_3_992457_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_1_400518_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_2_225187_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_1_916628_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_4_981708_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_4_49890_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_4_908474_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_2_168875_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Paraguay_3_24341_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/USA_4_387945_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/India_4_534470_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_4_7856615_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Sri-Lanka_2_551926_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Ghana_1_154838_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Pseudo-labels/Label/Spain_3_8154154_LabelHand.tif
# ...
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/RGB+NIR/Bolivia_4_233925_S2Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/RGB+NIR/Bolivia_2_60373_S2Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/RGB+NIR/Bolivia_2_233925_S2Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/RGB+NIR/Bolivia_2_195474_S2Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/RGB+NIR/Bolivia_2_129334_S2Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/RGB+NIR/Bolivia_3_379434_S2Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/RGB+NIR/Bolivia_4_290290_S2Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/RGB+NIR/Bolivia_3_129334_S2Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/RGB+NIR/Bolivia_3_314919_S2Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/RGB+NIR/Bolivia_1_129334_S2Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/RGB+NIR/Bolivia_1_195474_S2Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/RGB+NIR/Bolivia_3_103757_S2Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/RGB+NIR/Bolivia_1_60373_S2Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/RGB+NIR/Bolivia_1_76104_S2Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/RGB+NIR/Bolivia_2_314919_S2Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/RGB+NIR/Bolivia_3_432776_S2Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/RGB+NIR/Bolivia_4_432776_S2Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/RGB+NIR/Bolivia_4_379434_S2Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/RGB+NIR/Bolivia_4_129334_S2Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/RGB+NIR/Bolivia_1_290290_S2Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/RGB+NIR/Bolivia_4_242570_S2Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/RGB+NIR/Bolivia_3_294583_S2Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/RGB+NIR/Bolivia_1_294583_S2Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/RGB+NIR/Bolivia_4_312675_S2Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/RGB+NIR/Bolivia_1_360519_S2Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/RGB+NIR/Bolivia_2_242570_S2Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/RGB+NIR/Bolivia_3_290290_S2Hand.tif
#    creating: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_2_233925_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_4_312675_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_3_242570_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_3_360519_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_2_432776_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_3_314919_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_1_312675_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_2_103757_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_3_23014_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_1_233925_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_3_294583_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_2_60373_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_4_129334_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_1_195474_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_3_379434_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_4_360519_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_3_312675_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_2_379434_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_1_360519_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_2_195474_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_2_360519_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_1_290290_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_4_379434_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_2_242570_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_3_195474_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_2_23014_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_1_294583_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_4_76104_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_4_294583_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_3_129334_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_1_379434_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_1_76104_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_1_242570_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_3_233925_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_2_312675_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_2_294583_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_1_60373_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_3_76104_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_2_76104_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_1_432776_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_2_290290_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_2_129334_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_3_290290_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_3_103757_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_4_23014_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_4_60373_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_4_314919_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_2_314919_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_3_432776_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_4_290290_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_1_129334_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_1_314919_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_3_60373_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_4_103757_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_1_23014_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_4_195474_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_4_242570_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_1_103757_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_4_233925_LabelHand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/Label/Bolivia_4_432776_LabelHand.tif
#    creating: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_3_76104_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_1_195474_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_3_432776_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_2_242570_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_2_76104_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_2_432776_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_3_290290_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_4_360519_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_4_60373_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_1_294583_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_3_312675_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_3_103757_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_2_129334_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_3_314919_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_1_432776_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_4_312675_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_1_103757_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_4_294583_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_3_242570_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_1_312675_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_3_129334_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_3_294583_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_2_290290_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_4_432776_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_4_290290_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_4_129334_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_2_312675_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_2_294583_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_1_233925_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_1_360519_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_4_195474_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_4_379434_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_2_233925_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_1_60373_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_1_129334_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_1_242570_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_1_314919_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_2_360519_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_1_76104_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_2_314919_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_4_76104_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_2_195474_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_3_60373_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_3_233925_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_3_360519_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_2_103757_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_1_290290_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_4_233925_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_4_23014_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_2_23014_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_3_379434_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_2_379434_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_4_103757_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_4_314919_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_3_23014_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_4_242570_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_3_195474_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_1_379434_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_2_60373_S1Hand.tif
#  extracting: /content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia/VV_VH/Bolivia_1_23014_S1Hand.tif

# %%
# Параметры конфигурации
train_dir = "/content/dataset_sen1floods11_RGB_NIR_VV_VH/train/Handlabeled"
validation_dir = "/content/dataset_sen1floods11_RGB_NIR_VV_VH/validation"
test_dir = "/content/dataset_sen1floods11_RGB_NIR_VV_VH/test"
test_Bolivia_dir = "/content/dataset_sen1floods11_RGB_NIR_VV_VH/test_Bolivia"
local_batch_size = 64
learning_rate = 1e-3
num_epochs = 200
model_serialization = "SegFormer_B5"
folder = "SegFormer_B5"
channels = "VV_VH"
data = "HandLabeled"

# %%
# Предопределённые списки для преобразований D4 и их инверсии
D4_TRANSFORMS = [
    lambda x: x,                                 # I
    lambda x: torch.rot90(x, 1, [2, 3]),         # R90
    lambda x: torch.rot90(x, 2, [2, 3]),         # R180
    lambda x: torch.rot90(x, 3, [2, 3]),         # R270
    lambda x: torch.flip(x, [3]),                # F
    lambda x: torch.rot90(torch.flip(x, [3]), 1, [2, 3]),  # F_R90
    lambda x: torch.rot90(torch.flip(x, [3]), 2, [2, 3]),  # F_R180
    lambda x: torch.rot90(torch.flip(x, [3]), 3, [2, 3]),  # F_R270
]

INVERSE_TRANSFORMS = [
    lambda x: x,                                 # I
    lambda x: torch.rot90(x, -1, [2, 3]),        # R90
    lambda x: torch.rot90(x, -2, [2, 3]),        # R180
    lambda x: torch.rot90(x, -3, [2, 3]),        # R270
    lambda x: torch.flip(x, [3]),                # F
    lambda x: torch.flip(torch.rot90(x, -1, [2, 3]), [3]),  # F_R90
    lambda x: torch.flip(torch.rot90(x, -2, [2, 3]), [3]),  # F_R180
    lambda x: torch.flip(torch.rot90(x, -3, [2, 3]), [3]),  # F_R270
]

# %%
transform = A.Compose([
    A.HorizontalFlip(p = 0.5),
    A.RandomRotate90(p = 0.5),
    A.VerticalFlip(p = 0.5)
])

# %%
def get_filename(filepath):
    return os.path.split(filepath)[1]

# %%
def create_df(main_dir):
    vv_vh_image_paths = sorted(glob.glob(main_dir + '/VV_VH/*.tif', recursive=True))
    vv_vh_image_names = [get_filename(pth) for pth in vv_vh_image_paths]
    mask_paths = []

    for i in range(len(vv_vh_image_paths)):
        # Путь к изображению vh
        mask_name = vv_vh_image_names[i]
        parts = mask_name.split('_')
        mask_name = '_'.join(parts[:3]) + '_'
        mask_path = os.path.join(
            main_dir, "Label", f"{mask_name}LabelHand.tif"
        )
        mask_paths.append(mask_path)

    paths = {
        "vv_vh_image_path": vv_vh_image_paths,
        "mask_path": mask_paths,
    }

    return pd.DataFrame(paths)

# %%
class MyDataset(Dataset):
    def __init__(self, dataframe, split, transform=None):
        self.split = split
        self.dataset = dataframe
        self.transform = transform

    def __len__(self):
        return self.dataset.shape[0]

    def __getitem__(self, index):

        row = self.dataset.iloc[index]
        img_path = row["vv_vh_image_path"]
        mask_path = row["mask_path"]

        # Загружаем 2-канальное изображение TIFF (VV, VH)
        image = tifffile.imread(img_path).astype(np.float32)
        image = np.nan_to_num(image, 0)

        # Нормируем [0, 1]
        image = np.clip(image, -35, 3)
        image = (image + 35.0)/38.0

        image = image.transpose(1, 2, 0)  # (H, W, 2), каналы: VV, VH

        # Вычисляем ratio и добавляем как третий канал
        VV = image[:, :, 0]
        VH = image[:, :, 1]
        ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
        ratio = ratio[:, :, np.newaxis]

        # Объединяем в трёхканальное изображение (VV, VH, ratio)
        image = np.concatenate((image, ratio), axis=2)

        # Загружаем маску (одноканальная)
        mask = tifffile.imread(mask_path).astype(np.int64)

        # Аугментация только для train
        if self.split == "train" and self.transform is not None:
            augmented = self.transform(image=image, mask=mask)
            image = augmented["image"]
            mask = augmented["mask"]

        # Транспонируем каналы для PyTorch (C, H, W)
        image = image.transpose(2, 0, 1)

        return {
                "image": torch.from_numpy(image.astype(np.float32)),
                "mask": torch.from_numpy(mask).long()
            }

# %%
def calculate_TP_FP_TN_FN(pred, target):
    # Получаем предсказанные метки (из логитов)
    pred_labels = pred.argmax(dim=1)  # dim=1 — классы, на выходе (B, H, W)

    TP = ((pred_labels == 1) & (target == 1)).sum().item()
    FP = ((pred_labels == 1) & (target == 0)).sum().item()
    TN = ((pred_labels == 0) & (target == 0)).sum().item()
    FN = ((pred_labels == 0) & (target == 1)).sum().item()

    return float(TP), float(FP), float(TN), float(FN), float(TN), float(FN), float(TP), float(FP)

# %%
def calculate_metrics(TP_flood, FP_flood, TN_flood, FN_flood, TP_background, FP_background, TN_background, FN_background):
    Accuracy = (TP_flood + TN_flood)/(TP_flood + FP_flood + TN_flood + FN_flood + 1e-6)
    IoU_flood = TP_flood/(TP_flood + FP_flood + FN_flood + 1e-6)
    IoU_background = TP_background/(TP_background + FP_background + FN_background + 1e-6)
    IoU = (IoU_flood + IoU_background)/2
    Dice_flood = 2*TP_flood/(2*TP_flood + FP_flood + FN_flood + 1e-6)
    Dice_background = 2*TP_background/(2*TP_background + FP_background + FN_background + 1e-6)
    Dice = (Dice_flood + Dice_background)/2
    Precision_flood = TP_flood/(TP_flood + FP_flood + 1e-6)
    Precision_background = TP_background/(TP_background + FP_background + 1e-6)
    Precision = (Precision_flood + Precision_background)/2
    Recall_flood = TP_flood/(TP_flood + FN_flood + 1e-6)
    Recall_background = TP_background/(TP_background + FN_background + 1e-6)
    Recall = (Recall_flood + Recall_background)/2
    BalancedAccuracy = (TP_flood/(TP_flood + FN_flood + 1e-6) + TN_flood/(TN_flood + FP_flood + 1e-6))/2

    return Accuracy, IoU_flood, IoU_background, IoU, Dice_flood, Dice_background, Dice, Precision_flood, Precision_background, Precision, Recall_flood, Recall_background, Recall, BalancedAccuracy

# %%
def d4_mask_batch(images: torch.Tensor, model: torch.nn.Module, device="cuda" if torch.cuda.is_available() else "cpu") -> torch.Tensor:
    """
    Test-Time D4-аугментация: возвращает усреднённые вероятности классов (B,2,H,W).
    """
    model.eval()
    images = images.to(device)
    B, C, H, W = images.shape
    acc = torch.zeros((B, 2, H, W), dtype=torch.float32, device=device)

    with torch.no_grad():
        for transform, inv in zip(D4_TRANSFORMS, INVERSE_TRANSFORMS):

            imgs_t = transform(images)

            logits = model(imgs_t)                  # (B,2,H,W)
            prob = F.softmax(logits, dim=1)
            prob_inv = inv(prob)
            acc += prob_inv

    # Усреднение по 8 вариантам
    avg = acc / len(D4_TRANSFORMS)          # (B,2,H,W)
    return avg

# %%
def apply_crf_to_batch(images, probs, n_iters=10):
    """
    Применяет CRF к батчу изображений.

    :param images: тензор изображений формы (B, C, H, W), где C >= 3
    :param probs: тензор вероятностей классов формы (B, 2, H, W)
    :param n_iters: количество итераций для CRF
    :return: тензор уточнённых масок формы (B, H, W)
    """
    B, C, H, W = probs.shape
    device = images.device
    refined_masks = torch.zeros((B, 2, H, W), dtype = torch.uint8, device = device)
    for i in range(B):
        # Извлекаем первые три канала изображения и масштабируем в диапазон [0, 255]
        image_rgb = (images[i, :3, :, :] * 255).cpu().numpy().transpose(1, 2, 0).copy().astype(np.uint8)

        # Получаем вероятности классов
        prob = probs[i].cpu().numpy()

        # Инициализация CRF
        d = dcrf.DenseCRF2D(W, H, 2)
        unary = unary_from_softmax(prob)
        d.setUnaryEnergy(unary)

        # Добавление парных потенциалов
        d.addPairwiseGaussian(sxy=3, compat=3)
        d.addPairwiseBilateral(sxy=80, srgb=13, rgbim=image_rgb, compat=10)

        # Инференс CRF
        Q = d.inference(n_iters)
        refined_mask = np.array(Q).reshape((2, H, W)).astype(np.float32)

        refined_masks[i] = torch.tensor(refined_mask, dtype = torch.float32, device = device)

    return refined_masks

# %%
def calculate_flood_percentage(mask):
    flood_pixels = np.sum(mask == 1)
    total_pixels = mask.size
    return (flood_pixels / total_pixels) * 100

# %%
def visualize_predictions(images, masks, predictions):

    cmap = ListedColormap(['black', '#ffc0cb', '#0000FF'])  # Цвета для -1, 0, 1
    bounds = [-1.5, -0.5, 0.5, 1.5]  # Границы значений
    norm = BoundaryNorm(bounds, cmap.N)

    batch_size = images.shape[0]
    for i in range(batch_size):
        # Извлечение изображения и маски
        image = images[i].permute(1, 2, 0).cpu().numpy()  # Перестановка осей и перевод на CPU
        mask = masks[i].cpu().numpy()  # Перевод маски на CPU
        prediction = predictions[i].argmax(dim=0).cpu().numpy()  # Перевод предсказания на CPU

        # Расчёт процента затопления
        flood_percentage = calculate_flood_percentage(prediction)

        # Отображение изображений
        fig, axes = plt.subplots(1, 3, figsize=(15, 5))

        # 3-х канальное изображение
        axes[0].imshow(image)
        axes[0].set_title("3-х канальное изображение")
        axes[0].axis("off")

        # Маска
        axes[1].imshow(mask, cmap=cmap, norm=norm)
        axes[1].set_title("Маска")
        axes[1].axis("off")

        # Предсказание модели
        axes[2].imshow(prediction, cmap=cmap, norm=norm)
        axes[2].set_title(f"Сегментация модели\n{flood_percentage:.2f}% воды")
        axes[2].axis("off")

        plt.tight_layout()
        plt.show()

# %%
def train(num_epochs = 200):

    global validation_iou
    global num_best_epoch

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Создание модели
    model = smp.Segformer(
        encoder_name="mit_b5", encoder_weights='imagenet', in_channels=3, classes=2
    ).to(device)

    # Оптимизатор
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    # Шедулер
    scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
        optimizer,
        T_0=25,
        T_mult=1,
        eta_min=5e-6
    )

    scaler = GradScaler('cuda')

    # Функция потерь
    criterion_dice = smp.losses.DiceLoss(mode="multiclass", ignore_index=-1)

    # Создание DataLoader-ов
    train_df = create_df(train_dir)
    validation_df = create_df(validation_dir)
    if train_df.empty:
        raise ValueError("Train DataFrame is empty!")
    if validation_df.empty:
        raise ValueError("Validation DataFrame is empty!")

    train_dataset = MyDataset(train_df, split="train", transform = transform)
    validation_dataset = MyDataset(validation_df, split="validation", transform=None)

    train_loader = DataLoader(
        train_dataset, batch_size=local_batch_size, shuffle=True, num_workers = os.cpu_count()-1,
        pin_memory=True, persistent_workers=True
    )
    validation_loader = DataLoader(
        validation_dataset, batch_size=local_batch_size, shuffle=False, num_workers = os.cpu_count()-1,
        pin_memory=True, persistent_workers=True
    )
    if len(train_loader) == 0:
        raise ValueError("Train DataLoader is empty!")
    if len(validation_loader) == 0:
        raise ValueError("Validation DataLoader is empty!")

    ## Начало обучения ##
    for epoch in range(num_epochs):
        # Тренировочный этап
        model.train()
        train_losses = []
        TP_flood, FP_flood, TN_flood, FN_flood = 0.0, 0.0, 0.0, 0.0
        TP_background, FP_background, TN_background, FN_background = 0.0, 0.0, 0.0, 0.0

        progress_bar = tqdm(train_loader, desc="Train", unit="batch", leave=True)
        for batch in progress_bar:

            image = batch["image"].to(device, non_blocking=True)
            mask = batch["mask"].to(device, non_blocking=True)

            optimizer.zero_grad()

            with autocast('cuda'):
                pred = model(image)
                loss = criterion_dice(pred, mask)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            train_losses.append(loss.item())
            TP_flood_batch, FP_flood_batch, TN_flood_batch, FN_flood_batch, TP_background_batch, FP_background_batch, TN_background_batch, FN_background_batch = calculate_TP_FP_TN_FN(pred, mask)
            TP_flood += TP_flood_batch
            FP_flood += FP_flood_batch
            TN_flood += TN_flood_batch
            FN_flood += FN_flood_batch
            TP_background += TP_background_batch
            FP_background += FP_background_batch
            TN_background += TN_background_batch
            FN_background += FN_background_batch

        Avg_loss = sum(train_losses) / (len(train_losses) + 1e-6)
        Accuracy, IoU_flood, IoU_background, IoU, Dice_flood, Dice_background, Dice, Precision_flood, Precision_background, Precision, Recall_flood, Recall_background, Recall, BalancedAccuracy = calculate_metrics(TP_flood = TP_flood, FP_flood = FP_flood, TN_flood = TN_flood, FN_flood = FN_flood, TP_background = TP_background, FP_background = FP_background, TN_background = TN_background, FN_background = FN_background)
        logger1.info(f"Epoch {epoch+1}, LR: {optimizer.param_groups[0]['lr']:.8f}, Train Loss: {Avg_loss:.4f}, Train IoU: {IoU:.4f}, Train Accuracy: {Accuracy:.4f}, Train Dice: {Dice:.4f}, Train Precision: {Precision:.4f}, Train Recall: {Recall:.4f}, Train BalancedAccuracy: {BalancedAccuracy:.4f}, Train IoU_flood: {IoU_flood:.4f}, Train IoU_background: {IoU_background:.4f}, Train Dice_flood: {Dice_flood:.4f}, Train Dice_background: {Dice_background:.4f}, Train Precision_flood: {Precision_flood:.4f}, Train Precision_background: {Precision_background:.4f}, Train Recall_flood: {Recall_flood:.4f}, Train Recall_background: {Recall_background:.4f}")

        scheduler.step()

        # Оценка на валидационном наборе
        model.eval()
        with torch.no_grad():
            valid_losses = []
            TP_flood, FP_flood, TN_flood, FN_flood = 0.0, 0.0, 0.0, 0.0
            TP_background, FP_background, TN_background, FN_background = 0.0, 0.0, 0.0, 0.0

            progress_bar = tqdm(validation_loader, desc="Valid", unit="batch", leave=True)
            for batch in progress_bar:
                image = batch["image"].to(device, non_blocking=True)
                mask = batch["mask"].to(device, non_blocking=True)

                with autocast('cuda'):
                    pred = model(image)
                    loss = criterion_dice(pred, mask)

                # Метрики
                valid_losses.append(loss.item())
                TP_flood_batch, FP_flood_batch, TN_flood_batch, FN_flood_batch, TP_background_batch, FP_background_batch, TN_background_batch, FN_background_batch = calculate_TP_FP_TN_FN(pred, mask)
                TP_flood += TP_flood_batch
                FP_flood += FP_flood_batch
                TN_flood += TN_flood_batch
                FN_flood += FN_flood_batch
                TP_background += TP_background_batch
                FP_background += FP_background_batch
                TN_background += TN_background_batch
                FN_background += FN_background_batch

        Avg_loss = sum(valid_losses) / (len(valid_losses) + 1e-6)
        Accuracy, IoU_flood, IoU_background, IoU, Dice_flood, Dice_background, Dice, Precision_flood, Precision_background, Precision, Recall_flood, Recall_background, Recall, BalancedAccuracy = calculate_metrics(TP_flood = TP_flood, FP_flood = FP_flood, TN_flood = TN_flood, FN_flood = FN_flood, TP_background = TP_background, FP_background = FP_background, TN_background = TN_background, FN_background = FN_background)
        if IoU > validation_iou:
            num_best_epoch = epoch + 1
            validation_iou = IoU
        logger1.info(f"Epoch {epoch+1}, Valid Loss: {Avg_loss:.4f}, Valid IoU: {IoU:.4f}, Valid Accuracy: {Accuracy:.4f}, Valid Dice: {Dice:.4f}, Valid Precision: {Precision:.4f}, Valid Recall: {Recall:.4f}, Valid BalancedAccuracy: {BalancedAccuracy:.4f}, Valid IoU_flood: {IoU_flood:.4f}, Valid IoU_background: {IoU_background:.4f}, Valid Dice_flood: {Dice_flood:.4f}, Valid Dice_background: {Dice_background:.4f}, Valid Precision_flood: {Precision_flood:.4f}, Valid Precision_background: {Precision_background:.4f}, Valid Recall_flood: {Recall_flood:.4f}, Valid Recall_background: {Recall_background:.4f}")

        # Сохранение модели
        torch.save({
            'epoch': epoch+1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'scheduler_state_dict': scheduler.state_dict(),
            'loss': Avg_loss
        }, f"/content/drive/MyDrive/datasets_and_models/{folder}/{folder_of_weights}/{model_serialization}_{epoch+1}_{channels}_{data}.pth")

# %%
def addtrain(num_epochs = 200, initEpoch = 100):

    global validation_iou
    global num_best_epoch

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    checkpoint = torch.load(f"/content/drive/MyDrive/datasets_and_models/{folder}/{folder_of_weights}/{model_serialization}_{initEpoch}_{channels}_{data}.pth", map_location=device)

    # Создание модели
    model = smp.Segformer(
        encoder_name="mit_b5", encoder_weights='imagenet', in_channels=3, classes=2
    ).to(device)
    model.load_state_dict(checkpoint['model_state_dict'])

    # Оптимизатор
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

    # Шедулер
    scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
        optimizer,
        T_0=25,
        T_mult=1,
        eta_min=5e-6
    )
    scheduler.load_state_dict(checkpoint['scheduler_state_dict'])

    scaler = GradScaler('cuda')

    # Функция потерь
    criterion_dice = smp.losses.DiceLoss(mode="multiclass", ignore_index=-1)

    # Создание DataLoader-ов
    train_df = create_df(train_dir)
    validation_df = create_df(validation_dir)
    if train_df.empty:
        raise ValueError("Train DataFrame is empty!")
    if validation_df.empty:
        raise ValueError("Validation DataFrame is empty!")

    train_dataset = MyDataset(train_df, split="train", transform = transform)
    validation_dataset = MyDataset(validation_df, split="validation", transform=None)

    train_loader = DataLoader(
        train_dataset, batch_size=local_batch_size, shuffle=True, num_workers = os.cpu_count()-1,
        pin_memory=True, persistent_workers=True
    )
    validation_loader = DataLoader(
        validation_dataset, batch_size=local_batch_size, shuffle=False, num_workers = os.cpu_count()-1,
        pin_memory=True, persistent_workers=True
    )
    if len(train_loader) == 0:
        raise ValueError("Train DataLoader is empty!")
    if len(validation_loader) == 0:
        raise ValueError("Validation DataLoader is empty!")

    ## Начало обучения ##
    for epoch in range(num_epochs):
        # Тренировочный этап
        model.train()
        train_losses = []
        TP_flood, FP_flood, TN_flood, FN_flood = 0.0, 0.0, 0.0, 0.0
        TP_background, FP_background, TN_background, FN_background = 0.0, 0.0, 0.0, 0.0

        progress_bar = tqdm(train_loader, desc="Train", unit="batch", leave=True)
        for batch in progress_bar:

            image = batch["image"].to(device, non_blocking=True)
            mask = batch["mask"].to(device, non_blocking=True)

            optimizer.zero_grad()

            with autocast('cuda'):
                pred = model(image)
                loss = criterion_dice(pred, mask)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            train_losses.append(loss.item())
            TP_flood_batch, FP_flood_batch, TN_flood_batch, FN_flood_batch, TP_background_batch, FP_background_batch, TN_background_batch, FN_background_batch = calculate_TP_FP_TN_FN(pred, mask)
            TP_flood += TP_flood_batch
            FP_flood += FP_flood_batch
            TN_flood += TN_flood_batch
            FN_flood += FN_flood_batch
            TP_background += TP_background_batch
            FP_background += FP_background_batch
            TN_background += TN_background_batch
            FN_background += FN_background_batch

        Avg_loss = sum(train_losses) / (len(train_losses) + 1e-6)
        Accuracy, IoU_flood, IoU_background, IoU, Dice_flood, Dice_background, Dice, Precision_flood, Precision_background, Precision, Recall_flood, Recall_background, Recall, BalancedAccuracy = calculate_metrics(TP_flood = TP_flood, FP_flood = FP_flood, TN_flood = TN_flood, FN_flood = FN_flood, TP_background = TP_background, FP_background = FP_background, TN_background = TN_background, FN_background = FN_background)
        logger1.info(f"Epoch {epoch+initEpoch+1}, LR: {optimizer.param_groups[0]['lr']:.8f}, Train Loss: {Avg_loss:.4f}, Train IoU: {IoU:.4f}, Train Accuracy: {Accuracy:.4f}, Train Dice: {Dice:.4f}, Train Precision: {Precision:.4f}, Train Recall: {Recall:.4f}, Train BalancedAccuracy: {BalancedAccuracy:.4f}, Train IoU_flood: {IoU_flood:.4f}, Train IoU_background: {IoU_background:.4f}, Train Dice_flood: {Dice_flood:.4f}, Train Dice_background: {Dice_background:.4f}, Train Precision_flood: {Precision_flood:.4f}, Train Precision_background: {Precision_background:.4f}, Train Recall_flood: {Recall_flood:.4f}, Train Recall_background: {Recall_background:.4f}")

        scheduler.step()

        # Оценка на валидационном наборе
        model.eval()
        with torch.no_grad():
            valid_losses = []
            TP_flood, FP_flood, TN_flood, FN_flood = 0.0, 0.0, 0.0, 0.0
            TP_background, FP_background, TN_background, FN_background = 0.0, 0.0, 0.0, 0.0

            progress_bar = tqdm(validation_loader, desc="Valid", unit="batch", leave=True)
            for batch in progress_bar:
                image = batch["image"].to(device, non_blocking=True)
                mask = batch["mask"].to(device, non_blocking=True)

                with autocast('cuda'):
                    pred = model(image)
                    loss = criterion_dice(pred, mask)

                # Метрики
                valid_losses.append(loss.item())
                TP_flood_batch, FP_flood_batch, TN_flood_batch, FN_flood_batch, TP_background_batch, FP_background_batch, TN_background_batch, FN_background_batch = calculate_TP_FP_TN_FN(pred, mask)
                TP_flood += TP_flood_batch
                FP_flood += FP_flood_batch
                TN_flood += TN_flood_batch
                FN_flood += FN_flood_batch
                TP_background += TP_background_batch
                FP_background += FP_background_batch
                TN_background += TN_background_batch
                FN_background += FN_background_batch

        Avg_loss = sum(valid_losses) / (len(valid_losses) + 1e-6)
        Accuracy, IoU_flood, IoU_background, IoU, Dice_flood, Dice_background, Dice, Precision_flood, Precision_background, Precision, Recall_flood, Recall_background, Recall, BalancedAccuracy = calculate_metrics(TP_flood = TP_flood, FP_flood = FP_flood, TN_flood = TN_flood, FN_flood = FN_flood, TP_background = TP_background, FP_background = FP_background, TN_background = TN_background, FN_background = FN_background)
        if IoU > validation_iou:
            num_best_epoch = epoch + initEpoch +1
            validation_iou = IoU
        logger1.info(f"Epoch {epoch+initEpoch+1}, Valid Loss: {Avg_loss:.4f}, Valid IoU: {IoU:.4f}, Valid Accuracy: {Accuracy:.4f}, Valid Dice: {Dice:.4f}, Valid Precision: {Precision:.4f}, Valid Recall: {Recall:.4f}, Valid BalancedAccuracy: {BalancedAccuracy:.4f}, Valid IoU_flood: {IoU_flood:.4f}, Valid IoU_background: {IoU_background:.4f}, Valid Dice_flood: {Dice_flood:.4f}, Valid Dice_background: {Dice_background:.4f}, Valid Precision_flood: {Precision_flood:.4f}, Valid Precision_background: {Precision_background:.4f}, Valid Recall_flood: {Recall_flood:.4f}, Valid Recall_background: {Recall_background:.4f}")

        # Сохранение модели
        torch.save({
            'epoch': epoch+initEpoch+1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'scheduler_state_dict': scheduler.state_dict(),
            'loss': Avg_loss
        }, f"/content/drive/MyDrive/datasets_and_models/{folder}/{folder_of_weights}/{model_serialization}_{epoch+initEpoch+1}_{channels}_{data}.pth")

# %%
def test(TestEpoch = 200):

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    checkpoint = torch.load(f"/content/drive/MyDrive/datasets_and_models/{folder}/{folder_of_weights}/{model_serialization}_{TestEpoch}_{channels}_{data}.pth", map_location=device)

    # Создание модели
    model = smp.Segformer(
        encoder_name="mit_b5", encoder_weights='imagenet', in_channels=3, classes=2
    ).to(device)
    model.load_state_dict(checkpoint['model_state_dict'])

    scaler = GradScaler('cuda')

    # Создание DataLoader-ов
    test_df = create_df(test_dir)
    test_Bolivia_df = create_df(test_Bolivia_dir)
    if test_df.empty:
        raise ValueError("Test DataFrame is empty!")
    if  test_Bolivia_df.empty:
        raise ValueError("Test Bolivia DataFrame is empty!")

    test_dataset = MyDataset(test_df, split="test", transform = None)
    test_Bolivia_dataset = MyDataset(test_Bolivia_df, split="test", transform=None)

    test_loader = DataLoader(
        test_dataset, batch_size=16, shuffle=False, num_workers = os.cpu_count()-1,
        pin_memory=True, persistent_workers=True
    )
    test_Bolivia_loader = DataLoader(
        test_Bolivia_dataset, batch_size=16, shuffle=False, num_workers = os.cpu_count()-1,
        pin_memory=True, persistent_workers=True
    )
    if len(test_loader) == 0:
        raise ValueError("Test DataLoader is empty!")
    if len(test_Bolivia_loader) == 0:
        raise ValueError("Test Bolivia DataLoader is empty!")

    # Оценка на тестовом наборе
    model.eval()
    with torch.no_grad():
        test_losses = []
        TP_flood, FP_flood, TN_flood, FN_flood = 0.0, 0.0, 0.0, 0.0
        TP_background, FP_background, TN_background, FN_background = 0.0, 0.0, 0.0, 0.0
        TP_flood_aug, FP_flood_aug, TN_flood_aug, FN_flood_aug = 0.0, 0.0, 0.0, 0.0
        TP_background_aug, FP_background_aug, TN_background_aug, FN_background_aug = 0.0, 0.0, 0.0, 0.0
        TP_flood_aug_crf, FP_flood_aug_crf, TN_flood_aug_crf, FN_flood_aug_crf = 0.0, 0.0, 0.0, 0.0
        TP_background_aug_crf, FP_background_aug_crf, TN_background_aug_crf, FN_background_aug_crf = 0.0, 0.0, 0.0, 0.0

        progress_bar = tqdm(test_loader, desc="Test", unit="batch", leave=True)
        for batch in progress_bar:
            image = batch["image"].to(device, non_blocking=True)
            mask = batch["mask"].to(device, non_blocking=True)

            with autocast('cuda'):
                pred = model(image)

            pred_aug = d4_mask_batch(images = image, model = model, device = device)
            pred_aug_CRF = apply_crf_to_batch(images = image, probs = pred_aug)

            #visualize_predictions(images = image , masks = mask, predictions = pred)
            #visualize_predictions(images = image , masks = mask, predictions = pred_aug)
            #visualize_predictions(images = image , masks = mask, predictions = pred_aug_CRF)

            # Метрики
            TP_flood_batch, FP_flood_batch, TN_flood_batch, FN_flood_batch, TP_background_batch, FP_background_batch, TN_background_batch, FN_background_batch = calculate_TP_FP_TN_FN(pred, mask)
            TP_flood += TP_flood_batch
            FP_flood += FP_flood_batch
            TN_flood += TN_flood_batch
            FN_flood += FN_flood_batch
            TP_background += TP_background_batch
            FP_background += FP_background_batch
            TN_background += TN_background_batch
            FN_background += FN_background_batch
            TP_flood_batch, FP_flood_batch, TN_flood_batch, FN_flood_batch, TP_background_batch, FP_background_batch, TN_background_batch, FN_background_batch = calculate_TP_FP_TN_FN(pred_aug, mask)
            TP_flood_aug += TP_flood_batch
            FP_flood_aug += FP_flood_batch
            TN_flood_aug += TN_flood_batch
            FN_flood_aug += FN_flood_batch
            TP_background_aug += TP_background_batch
            FP_background_aug += FP_background_batch
            TN_background_aug += TN_background_batch
            FN_background_aug += FN_background_batch
            TP_flood_batch, FP_flood_batch, TN_flood_batch, FN_flood_batch, TP_background_batch, FP_background_batch, TN_background_batch, FN_background_batch = calculate_TP_FP_TN_FN(pred_aug_CRF, mask)
            TP_flood_aug_crf += TP_flood_batch
            FP_flood_aug_crf += FP_flood_batch
            TN_flood_aug_crf += TN_flood_batch
            FN_flood_aug_crf += FN_flood_batch
            TP_background_aug_crf += TP_background_batch
            FP_background_aug_crf += FP_background_batch
            TN_background_aug_crf += TN_background_batch
            FN_background_aug_crf += FN_background_batch
    print(f"TP_flood = {TP_flood}, FP_flood = {FP_flood}, TN_flood = {TN_flood}, FN_flood = {FN_flood}")
    print(f"TP_flood_aug = {TP_flood_aug}, FP_flood_aug = {FP_flood_aug}, TN_flood_aug = {TN_flood_aug}, FN_flood_aug = {FN_flood_aug}")
    print(f"TP_floodaug_crf = {TP_flood_aug_crf}, FP_floodaug_crf = {FP_flood_aug_crf}, TN_floodaug_crf = {TN_flood_aug_crf}, FN_floodaug_crf = {FN_flood_aug_crf}")
    Accuracy, IoU_flood, IoU_background, IoU, Dice_flood, Dice_background, Dice, Precision_flood, Precision_background, Precision, Recall_flood, Recall_background, Recall, BalancedAccuracy = calculate_metrics(TP_flood = TP_flood, FP_flood = FP_flood, TN_flood = TN_flood, FN_flood = FN_flood, TP_background = TP_background, FP_background = FP_background, TN_background = TN_background, FN_background = FN_background)
    Accuracy_aug, IoU_flood_aug, IoU_background_aug, IoU_aug, Dice_flood_aug, Dice_background_aug, Dice_aug, Precision_flood_aug, Precision_background_aug, Precision_aug, Recall_flood_aug, Recall_background_aug, Recall_aug, BalancedAccuracy_aug = calculate_metrics(TP_flood = TP_flood_aug, FP_flood = FP_flood_aug, TN_flood = TN_flood_aug, FN_flood = FN_flood_aug, TP_background = TP_background_aug, FP_background = FP_background_aug, TN_background = TN_background_aug, FN_background = FN_background_aug)
    Accuracy_aug_crf, IoU_flood_aug_crf, IoU_background_aug_crf, IoU_aug_crf, Dice_flood_aug_crf, Dice_background_aug_crf, Dice_aug_crf, Precision_flood_aug_crf, Precision_background_aug_crf, Precision_aug_crf, Recall_flood_aug_crf, Recall_background_aug_crf, Recall_aug_crf, BalancedAccuracy_aug_crf = calculate_metrics(TP_flood = TP_flood_aug_crf, FP_flood = FP_flood_aug_crf, TN_flood = TN_flood_aug_crf, FN_flood = FN_flood_aug_crf, TP_background = TP_background_aug_crf, FP_background = FP_background_aug_crf, TN_background = TN_background_aug_crf, FN_background = FN_background_aug_crf)
    logger2.info(f"WeightsEpoch: {checkpoint['epoch']}, Test IoU: {IoU:.4f}, Test Accuracy: {Accuracy:.4f}, Test Dice: {Dice:.4f}, Test Precision: {Precision:.4f}, Test Recall: {Recall:.4f}, Test BalancedAccuracy: {BalancedAccuracy:.4f}, Test IoU_flood: {IoU_flood:.4f}, Test IoU_background: {IoU_background:.4f}, Test Dice_flood: {Dice_flood:.4f}, Test Dice_background: {Dice_background:.4f}, Test Precision_flood: {Precision_flood:.4f}, Test Precision_background: {Precision_background:.4f}, Test Recall_flood: {Recall_flood:.4f}, Test Recall_background: {Recall_background:.4f}")
    logger2.info(f"WeightsEpoch: {checkpoint['epoch']}, Test Aug IoU: {IoU_aug:.4f}, Test Accuracy: {Accuracy_aug:.4f}, Test Dice: {Dice_aug:.4f}, Test Precision: {Precision_aug:.4f}, Test Recall: {Recall_aug:.4f}, Test BalancedAccuracy: {BalancedAccuracy_aug:.4f}, Test IoU_flood: {IoU_flood_aug:.4f}, Test IoU_background: {IoU_background_aug:.4f}, Test Dice_flood: {Dice_flood_aug:.4f}, Test Dice_background: {Dice_background_aug:.4f}, Test Precision_flood: {Precision_flood_aug:.4f}, Test Precision_background: {Precision_background_aug:.4f}, Test Recall_flood: {Recall_flood_aug:.4f}, Test Recall_background: {Recall_background_aug:.4f}")
    logger2.info(f"WeightsEpoch: {checkpoint['epoch']}, Test Aug CRF IoU: {IoU_aug_crf:.4f}, Test Accuracy: {Accuracy_aug_crf:.4f}, Test Dice: {Dice_aug_crf:.4f}, Test Precision: {Precision_aug_crf:.4f}, Test Recall: {Recall_aug_crf:.4f}, Test BalancedAccuracy: {BalancedAccuracy_aug_crf:.4f}, Test IoU_flood: {IoU_flood_aug_crf:.4f}, Test IoU_background: {IoU_background_aug_crf:.4f}, Test Dice_flood: {Dice_flood_aug_crf:.4f}, Test Dice_background: {Dice_background_aug_crf:.4f}, Test Precision_flood: {Precision_flood_aug_crf:.4f}, Test Precision_background: {Precision_background_aug_crf:.4f}, Test Recall_flood: {Recall_flood_aug_crf:.4f}, Test Recall_background: {Recall_background_aug_crf:.4f}")

    # Оценка на тестовом наборе Боливии
    model.eval()
    with torch.no_grad():
        test_Bolivia_losses = []
        TP_flood, FP_flood, TN_flood, FN_flood = 0.0, 0.0, 0.0, 0.0
        TP_background, FP_background, TN_background, FN_background = 0.0, 0.0, 0.0, 0.0

        progress_bar = tqdm(test_Bolivia_loader, desc="Test Bolivia", unit="batch", leave=True)
        for batch in progress_bar:
            image = batch["image"].to(device, non_blocking=True)
            mask = batch["mask"].to(device, non_blocking=True)

            with autocast('cuda'):
                pred = model(image)

            pred_aug = d4_mask_batch(images = image, model = model, device = device)
            pred_aug_CRF = apply_crf_to_batch(images = image, probs = pred_aug)

            #visualize_predictions(images = image , masks = mask, predictions = pred)
            #visualize_predictions(images = image , masks = mask, predictions = pred_aug)
            #visualize_predictions(images = image , masks = mask, predictions = pred_aug_CRF)

            # Метрики
            TP_flood_batch, FP_flood_batch, TN_flood_batch, FN_flood_batch, TP_background_batch, FP_background_batch, TN_background_batch, FN_background_batch = calculate_TP_FP_TN_FN(pred, mask)
            TP_flood += TP_flood_batch
            FP_flood += FP_flood_batch
            TN_flood += TN_flood_batch
            FN_flood += FN_flood_batch
            TP_background += TP_background_batch
            FP_background += FP_background_batch
            TN_background += TN_background_batch
            FN_background += FN_background_batch
            TP_flood_batch, FP_flood_batch, TN_flood_batch, FN_flood_batch, TP_background_batch, FP_background_batch, TN_background_batch, FN_background_batch = calculate_TP_FP_TN_FN(pred_aug, mask)
            TP_flood_aug += TP_flood_batch
            FP_flood_aug += FP_flood_batch
            TN_flood_aug += TN_flood_batch
            FN_flood_aug += FN_flood_batch
            TP_background_aug += TP_background_batch
            FP_background_aug += FP_background_batch
            TN_background_aug += TN_background_batch
            FN_background_aug += FN_background_batch
            TP_flood_batch, FP_flood_batch, TN_flood_batch, FN_flood_batch, TP_background_batch, FP_background_batch, TN_background_batch, FN_background_batch = calculate_TP_FP_TN_FN(pred_aug_CRF, mask)
            TP_flood_aug_crf += TP_flood_batch
            FP_flood_aug_crf += FP_flood_batch
            TN_flood_aug_crf += TN_flood_batch
            FN_flood_aug_crf += FN_flood_batch
            TP_background_aug_crf += TP_background_batch
            FP_background_aug_crf += FP_background_batch
            TN_background_aug_crf += TN_background_batch
            FN_background_aug_crf += FN_background_batch

    Accuracy, IoU_flood, IoU_background, IoU, Dice_flood, Dice_background, Dice, Precision_flood, Precision_background, Precision, Recall_flood, Recall_background, Recall, BalancedAccuracy = calculate_metrics(TP_flood = TP_flood, FP_flood = FP_flood, TN_flood = TN_flood, FN_flood = FN_flood, TP_background = TP_background, FP_background = FP_background, TN_background = TN_background, FN_background = FN_background)
    Accuracy_aug, IoU_flood_aug, IoU_background_aug, IoU_aug, Dice_flood_aug, Dice_background_aug, Dice_aug, Precision_flood_aug, Precision_background_aug, Precision_aug, Recall_flood_aug, Recall_background_aug, Recall_aug, BalancedAccuracy_aug = calculate_metrics(TP_flood = TP_flood_aug, FP_flood = FP_flood_aug, TN_flood = TN_flood_aug, FN_flood = FN_flood_aug, TP_background = TP_background_aug, FP_background = FP_background_aug, TN_background = TN_background_aug, FN_background = FN_background_aug)
    Accuracy_aug_crf, IoU_flood_aug_crf, IoU_background_aug_crf, IoU_aug_crf, Dice_flood_aug_crf, Dice_background_aug_crf, Dice_aug_crf, Precision_flood_aug_crf, Precision_background_aug_crf, Precision_aug_crf, Recall_flood_aug_crf, Recall_background_aug_crf, Recall_aug_crf, BalancedAccuracy_aug_crf = calculate_metrics(TP_flood = TP_flood_aug_crf, FP_flood = FP_flood_aug_crf, TN_flood = TN_flood_aug_crf, FN_flood = FN_flood_aug_crf, TP_background = TP_background_aug_crf, FP_background = FP_background_aug_crf, TN_background = TN_background_aug_crf, FN_background = FN_background_aug_crf)
    logger2.info(f"WeightsEpoch: {checkpoint['epoch']}, TestBolivia IoU: {IoU:.4f}, TestB Accuracy: {Accuracy:.4f}, TestB Dice: {Dice:.4f}, TestB Precision: {Precision:.4f}, TestB Recall: {Recall:.4f}, TestB BalancedAccuracy: {BalancedAccuracy:.4f}, TestB IoU_flood: {IoU_flood:.4f}, TestB IoU_background: {IoU_background:.4f}, TestB Dice_flood: {Dice_flood:.4f}, TestB Dice_background: {Dice_background:.4f}, TestB Precision_flood: {Precision_flood:.4f}, TestB Precision_background: {Precision_background:.4f}, TestB Recall_flood: {Recall_flood:.4f}, TestB Recall_background: {Recall_background:.4f}")
    logger2.info(f"WeightsEpoch: {checkpoint['epoch']}, TestBolivia Aug IoU: {IoU_aug:.4f}, TestB Accuracy: {Accuracy_aug:.4f}, TestB Dice: {Dice_aug:.4f}, TestB Precision: {Precision_aug:.4f}, TestB Recall: {Recall_aug:.4f}, TestB BalancedAccuracy: {BalancedAccuracy_aug:.4f}, TestB IoU_flood: {IoU_flood_aug:.4f}, TestB IoU_background: {IoU_background_aug:.4f}, TestB Dice_flood: {Dice_flood_aug:.4f}, TestB Dice_background: {Dice_background_aug:.4f}, TestB Precision_flood: {Precision_flood_aug:.4f}, TestB Precision_background: {Precision_background_aug:.4f}, TestB Recall_flood: {Recall_flood_aug:.4f}, TestB Recall_background: {Recall_background_aug:.4f}")
    logger2.info(f"WeightsEpoch: {checkpoint['epoch']}, TestBolivia Aug CRF IoU: {IoU_aug_crf:.4f}, TestB Accuracy: {Accuracy_aug_crf:.4f}, TestB Dice: {Dice_aug_crf:.4f}, TestB Precision: {Precision_aug_crf:.4f}, TestB Recall: {Recall_aug_crf:.4f}, TestB BalancedAccuracy: {BalancedAccuracy_aug_crf:.4f}, TestB IoU_flood: {IoU_flood_aug_crf:.4f}, TestB IoU_background: {IoU_background_aug_crf:.4f}, TestB Dice_flood: {Dice_flood_aug_crf:.4f}, TestB Dice_background: {Dice_background_aug_crf:.4f}, TestB Precision_flood: {Precision_flood_aug_crf:.4f}, TestB Precision_background: {Precision_background_aug_crf:.4f}, TestB Recall_flood: {Recall_flood_aug_crf:.4f}, TestB Recall_background: {Recall_background_aug_crf:.4f}")

# %%
if __name__ == "__main__":

    folder_of_weights = "Weights_VV_VH_HandLabeled"

    num_best_epoch = 0
    validation_iou = 0
    # Настройка логирования train
    logger1 = logging.getLogger(f"training_logger")
    logger1.setLevel(logging.INFO)
    # Формат логов
    formatter = logging.Formatter('%(message)s')
    # Вывод в консоль
    console_handler = logging.StreamHandler()
    console_handler.setFormatter(formatter)
    # Запись в файл
    file_handler = logging.FileHandler(f"/content/drive/MyDrive/datasets_and_models/{folder}/{channels}_{data}_train.txt", mode='a')
    file_handler.setFormatter(formatter)
    if not logger1.handlers:
      logger1.addHandler(console_handler)
      logger1.addHandler(file_handler)

    # Настройка логирования test
    logger2 = logging.getLogger(f"testing_logger")
    logger2.setLevel(logging.INFO)
    # Формат логов
    formatter2 = logging.Formatter('%(message)s')
    # Вывод в консоль
    console_handler2 = logging.StreamHandler()
    console_handler2.setFormatter(formatter2)
    # Запись в файл
    file_handler2 = logging.FileHandler(f"/content/drive/MyDrive/datasets_and_models/{folder}/{channels}_{data}_test.txt", mode='a')
    file_handler2.setFormatter(formatter2)
    if not logger2.handlers:
      logger2.addHandler(console_handler2)
      logger2.addHandler(file_handler2)

    train(num_epochs)
    test(num_best_epoch)
    test(num_epochs)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/135 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/328M [00:00<?, ?B/s]
# Train:   0%|          | 0/16 [00:00<?, ?batch/s]<ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# Train: 100%|██████████| 16/16 [00:14<00:00,  1.07batch/s]
# Epoch 1, LR: 0.00100000, Train Loss: 0.2688, Train IoU: 0.5954, Train Accuracy: 0.8695, Train Dice: 0.7109, Train Precision: 0.6777, Train Recall: 0.7837, Train BalancedAccuracy: 0.7837, Train IoU_flood: 0.3304, Train IoU_background: 0.8605, Train Dice_flood: 0.4967, Train Dice_background: 0.9250, Train Precision_flood: 0.3920, Train Precision_background: 0.9633, Train Recall_flood: 0.6777, Train Recall_background: 0.8896
# INFO:training_logger:Epoch 1, LR: 0.00100000, Train Loss: 0.2688, Train IoU: 0.5954, Train Accuracy: 0.8695, Train Dice: 0.7109, Train Precision: 0.6777, Train Recall: 0.7837, Train BalancedAccuracy: 0.7837, Train IoU_flood: 0.3304, Train IoU_background: 0.8605, Train Dice_flood: 0.4967, Train Dice_background: 0.9250, Train Precision_flood: 0.3920, Train Precision_background: 0.9633, Train Recall_flood: 0.6777, Train Recall_background: 0.8896
# Valid:   0%|          | 0/6 [00:00<?, ?batch/s]<ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# Valid: 100%|██████████| 6/6 [00:02<00:00,  2.76batch/s]
# Epoch 1, Valid Loss: 0.1645, Valid IoU: 0.7533, Valid Accuracy: 0.9434, Valid Dice: 0.8464, Valid Precision: 0.8711, Valid Recall: 0.8257, Valid BalancedAccuracy: 0.8257, Valid IoU_flood: 0.5679, Valid IoU_background: 0.9388, Valid Dice_flood: 0.7244, Valid Dice_background: 0.9684, Valid Precision_flood: 0.7818, Valid Precision_background: 0.9604, Valid Recall_flood: 0.6748, Valid Recall_background: 0.9767
# INFO:training_logger:Epoch 1, Valid Loss: 0.1645, Valid IoU: 0.7533, Valid Accuracy: 0.9434, Valid Dice: 0.8464, Valid Precision: 0.8711, Valid Recall: 0.8257, Valid BalancedAccuracy: 0.8257, Valid IoU_flood: 0.5679, Valid IoU_background: 0.9388, Valid Dice_flood: 0.7244, Valid Dice_background: 0.9684, Valid Precision_flood: 0.7818, Valid Precision_background: 0.9604, Valid Recall_flood: 0.6748, Valid Recall_background: 0.9767
# Train: 100%|██████████| 16/16 [00:12<00:00,  1.25batch/s]
# Epoch 2, LR: 0.00099608, Train Loss: 0.1760, Train IoU: 0.7372, Train Accuracy: 0.9457, Train Dice: 0.8324, Train Precision: 0.8548, Train Recall: 0.8134, Train BalancedAccuracy: 0.8134, Train IoU_flood: 0.5322, Train IoU_background: 0.9421, Train Dice_flood: 0.6947, Train Dice_background: 0.9702, Train Precision_flood: 0.7459, Train Precision_background: 0.9637, Train Recall_flood: 0.6500, Train Recall_background: 0.9767
# INFO:training_logger:Epoch 2, LR: 0.00099608, Train Loss: 0.1760, Train IoU: 0.7372, Train Accuracy: 0.9457, Train Dice: 0.8324, Train Precision: 0.8548, Train Recall: 0.8134, Train BalancedAccuracy: 0.8134, Train IoU_flood: 0.5322, Train IoU_background: 0.9421, Train Dice_flood: 0.6947, Train Dice_background: 0.9702, Train Precision_flood: 0.7459, Train Precision_background: 0.9637, Train Recall_flood: 0.6500, Train Recall_background: 0.9767
# Valid: 100%|██████████| 6/6 [00:01<00:00,  3.05batch/s]
# Epoch 2, Valid Loss: 0.1490, Valid IoU: 0.7579, Valid Accuracy: 0.9456, Valid Dice: 0.8498, Valid Precision: 0.8832, Valid Recall: 0.8232, Valid BalancedAccuracy: 0.8232, Valid IoU_flood: 0.5745, Valid IoU_background: 0.9413, Valid Dice_flood: 0.7298, Valid Dice_background: 0.9698, Valid Precision_flood: 0.8070, Valid Precision_background: 0.9595, Valid Recall_flood: 0.6661, Valid Recall_background: 0.9803
# INFO:training_logger:Epoch 2, Valid Loss: 0.1490, Valid IoU: 0.7579, Valid Accuracy: 0.9456, Valid Dice: 0.8498, Valid Precision: 0.8832, Valid Recall: 0.8232, Valid BalancedAccuracy: 0.8232, Valid IoU_flood: 0.5745, Valid IoU_background: 0.9413, Valid Dice_flood: 0.7298, Valid Dice_background: 0.9698, Valid Precision_flood: 0.8070, Valid Precision_background: 0.9595, Valid Recall_flood: 0.6661, Valid Recall_background: 0.9803
# Train: 100%|██████████| 16/16 [00:12<00:00,  1.26batch/s]
# Epoch 3, LR: 0.00098437, Train Loss: 0.1704, Train IoU: 0.7478, Train Accuracy: 0.9485, Train Dice: 0.8410, Train Precision: 0.8646, Train Recall: 0.8209, Train BalancedAccuracy: 0.8209, Train IoU_flood: 0.5506, Train IoU_background: 0.9451, Train Dice_flood: 0.7102, Train Dice_background: 0.9718, Train Precision_flood: 0.7641, Train Precision_background: 0.9651, Train Recall_flood: 0.6633, Train Recall_background: 0.9785
# INFO:training_logger:Epoch 3, LR: 0.00098437, Train Loss: 0.1704, Train IoU: 0.7478, Train Accuracy: 0.9485, Train Dice: 0.8410, Train Precision: 0.8646, Train Recall: 0.8209, Train BalancedAccuracy: 0.8209, Train IoU_flood: 0.5506, Train IoU_background: 0.9451, Train Dice_flood: 0.7102, Train Dice_background: 0.9718, Train Precision_flood: 0.7641, Train Precision_background: 0.9651, Train Recall_flood: 0.6633, Train Recall_background: 0.9785
# Valid: 100%|██████████| 6/6 [00:01<00:00,  3.04batch/s]
# Epoch 3, Valid Loss: 0.1483, Valid IoU: 0.7569, Valid Accuracy: 0.9396, Valid Dice: 0.8499, Valid Precision: 0.8415, Valid Recall: 0.8590, Valid BalancedAccuracy: 0.8590, Valid IoU_flood: 0.5797, Valid IoU_background: 0.9341, Valid Dice_flood: 0.7340, Valid Dice_background: 0.9659, Valid Precision_flood: 0.7135, Valid Precision_background: 0.9695, Valid Recall_flood: 0.7556, Valid Recall_background: 0.9624
# INFO:training_logger:Epoch 3, Valid Loss: 0.1483, Valid IoU: 0.7569, Valid Accuracy: 0.9396, Valid Dice: 0.8499, Valid Precision: 0.8415, Valid Recall: 0.8590, Valid BalancedAccuracy: 0.8590, Valid IoU_flood: 0.5797, Valid IoU_background: 0.9341, Valid Dice_flood: 0.7340, Valid Dice_background: 0.9659, Valid Precision_flood: 0.7135, Valid Precision_background: 0.9695, Valid Recall_flood: 0.7556, Valid Recall_background: 0.9624
# Train: 100%|██████████| 16/16 [00:12<00:00,  1.24batch/s]
# Epoch 4, LR: 0.00096506, Train Loss: 0.1649, Train IoU: 0.7461, Train Accuracy: 0.9464, Train Dice: 0.8399, Train Precision: 0.8498, Train Recall: 0.8306, Train BalancedAccuracy: 0.8306, Train IoU_flood: 0.5495, Train IoU_background: 0.9427, Train Dice_flood: 0.7092, Train Dice_background: 0.9705, Train Precision_flood: 0.7322, Train Precision_background: 0.9674, Train Recall_flood: 0.6877, Train Recall_background: 0.9736
# INFO:training_logger:Epoch 4, LR: 0.00096506, Train Loss: 0.1649, Train IoU: 0.7461, Train Accuracy: 0.9464, Train Dice: 0.8399, Train Precision: 0.8498, Train Recall: 0.8306, Train BalancedAccuracy: 0.8306, Train IoU_flood: 0.5495, Train IoU_background: 0.9427, Train Dice_flood: 0.7092, Train Dice_background: 0.9705, Train Precision_flood: 0.7322, Train Precision_background: 0.9674, Train Recall_flood: 0.6877, Train Recall_background: 0.9736
# Valid: 100%|██████████| 6/6 [00:01<00:00,  3.00batch/s]
# Epoch 4, Valid Loss: 0.1524, Valid IoU: 0.7653, Valid Accuracy: 0.9466, Valid Dice: 0.8555, Valid Precision: 0.8797, Valid Recall: 0.8352, Valid BalancedAccuracy: 0.8352, Valid IoU_flood: 0.5884, Valid IoU_background: 0.9422, Valid Dice_flood: 0.7409, Valid Dice_background: 0.9702, Valid Precision_flood: 0.7969, Valid Precision_background: 0.9625, Valid Recall_flood: 0.6922, Valid Recall_background: 0.9781
# INFO:training_logger:Epoch 4, Valid Loss: 0.1524, Valid IoU: 0.7653, Valid Accuracy: 0.9466, Valid Dice: 0.8555, Valid Precision: 0.8797, Valid Recall: 0.8352, Valid BalancedAccuracy: 0.8352, Valid IoU_flood: 0.5884, Valid IoU_background: 0.9422, Valid Dice_flood: 0.7409, Valid Dice_background: 0.9702, Valid Precision_flood: 0.7969, Valid Precision_background: 0.9625, Valid Recall_flood: 0.6922, Valid Recall_background: 0.9781
# Train: 100%|██████████| 16/16 [00:12<00:00,  1.25batch/s]
# Epoch 5, LR: 0.00093846, Train Loss: 0.1577, Train IoU: 0.7601, Train Accuracy: 0.9517, Train Dice: 0.8505, Train Precision: 0.8757, Train Recall: 0.8293, Train BalancedAccuracy: 0.8293, Train IoU_flood: 0.5717, Train IoU_background: 0.9484, Train Dice_flood: 0.7275, Train Dice_background: 0.9735, Train Precision_flood: 0.7847, Train Precision_background: 0.9667, Train Recall_flood: 0.6781, Train Recall_background: 0.9805
# INFO:training_logger:Epoch 5, LR: 0.00093846, Train Loss: 0.1577, Train IoU: 0.7601, Train Accuracy: 0.9517, Train Dice: 0.8505, Train Precision: 0.8757, Train Recall: 0.8293, Train BalancedAccuracy: 0.8293, Train IoU_flood: 0.5717, Train IoU_background: 0.9484, Train Dice_flood: 0.7275, Train Dice_background: 0.9735, Train Precision_flood: 0.7847, Train Precision_background: 0.9667, Train Recall_flood: 0.6781, Train Recall_background: 0.9805
# Valid: 100%|██████████| 6/6 [00:01<00:00,  3.01batch/s]
# Epoch 5, Valid Loss: 0.1479, Valid IoU: 0.7711, Valid Accuracy: 0.9491, Valid Dice: 0.8598, Valid Precision: 0.8933, Valid Recall: 0.8329, Valid BalancedAccuracy: 0.8329, Valid IoU_flood: 0.5972, Valid IoU_background: 0.9450, Valid Dice_flood: 0.7478, Valid Dice_background: 0.9717, Valid Precision_flood: 0.8250, Valid Precision_background: 0.9616, Valid Recall_flood: 0.6839, Valid Recall_background: 0.9820
# INFO:training_logger:Epoch 5, Valid Loss: 0.1479, Valid IoU: 0.7711, Valid Accuracy: 0.9491, Valid Dice: 0.8598, Valid Precision: 0.8933, Valid Recall: 0.8329, Valid BalancedAccuracy: 0.8329, Valid IoU_flood: 0.5972, Valid IoU_background: 0.9450, Valid Dice_flood: 0.7478, Valid Dice_background: 0.9717, Valid Precision_flood: 0.8250, Valid Precision_background: 0.9616, Valid Recall_flood: 0.6839, Valid Recall_background: 0.9820
# Train: 100%|██████████| 16/16 [00:12<00:00,  1.24batch/s]
# Epoch 6, LR: 0.00090499, Train Loss: 0.1683, Train IoU: 0.7498, Train Accuracy: 0.9488, Train Dice: 0.8426, Train Precision: 0.8644, Train Recall: 0.8238, Train BalancedAccuracy: 0.8238, Train IoU_flood: 0.5543, Train IoU_background: 0.9454, Train Dice_flood: 0.7133, Train Dice_background: 0.9719, Train Precision_flood: 0.7632, Train Precision_background: 0.9657, Train Recall_flood: 0.6695, Train Recall_background: 0.9782
# INFO:training_logger:Epoch 6, LR: 0.00090499, Train Loss: 0.1683, Train IoU: 0.7498, Train Accuracy: 0.9488, Train Dice: 0.8426, Train Precision: 0.8644, Train Recall: 0.8238, Train BalancedAccuracy: 0.8238, Train IoU_flood: 0.5543, Train IoU_background: 0.9454, Train Dice_flood: 0.7133, Train Dice_background: 0.9719, Train Precision_flood: 0.7632, Train Precision_background: 0.9657, Train Recall_flood: 0.6695, Train Recall_background: 0.9782
# Valid: 100%|██████████| 6/6 [00:02<00:00,  2.88batch/s]
# Epoch 6, Valid Loss: 0.1495, Valid IoU: 0.7597, Valid Accuracy: 0.9468, Valid Dice: 0.8510, Valid Precision: 0.8911, Valid Recall: 0.8203, Valid BalancedAccuracy: 0.8203, Valid IoU_flood: 0.5768, Valid IoU_background: 0.9426, Valid Dice_flood: 0.7316, Valid Dice_background: 0.9705, Valid Precision_flood: 0.8236, Valid Precision_background: 0.9587, Valid Recall_flood: 0.6581, Valid Recall_background: 0.9825
# INFO:training_logger:Epoch 6, Valid Loss: 0.1495, Valid IoU: 0.7597, Valid Accuracy: 0.9468, Valid Dice: 0.8510, Valid Precision: 0.8911, Valid Recall: 0.8203, Valid BalancedAccuracy: 0.8203, Valid IoU_flood: 0.5768, Valid IoU_background: 0.9426, Valid Dice_flood: 0.7316, Valid Dice_background: 0.9705, Valid Precision_flood: 0.8236, Valid Precision_background: 0.9587, Valid Recall_flood: 0.6581, Valid Recall_background: 0.9825
# Train: 100%|██████████| 16/16 [00:12<00:00,  1.24batch/s]
# Epoch 7, LR: 0.00086516, Train Loss: 0.1479, Train IoU: 0.7688, Train Accuracy: 0.9540, Train Dice: 0.8572, Train Precision: 0.8842, Train Recall: 0.8346, Train BalancedAccuracy: 0.8346, Train IoU_flood: 0.5869, Train IoU_background: 0.9508, Train Dice_flood: 0.7397, Train Dice_background: 0.9748, Train Precision_flood: 0.8008, Train Precision_background: 0.9676, Train Recall_flood: 0.6872, Train Recall_background: 0.9820
# INFO:training_logger:Epoch 7, LR: 0.00086516, Train Loss: 0.1479, Train IoU: 0.7688, Train Accuracy: 0.9540, Train Dice: 0.8572, Train Precision: 0.8842, Train Recall: 0.8346, Train BalancedAccuracy: 0.8346, Train IoU_flood: 0.5869, Train IoU_background: 0.9508, Train Dice_flood: 0.7397, Train Dice_background: 0.9748, Train Precision_flood: 0.8008, Train Precision_background: 0.9676, Train Recall_flood: 0.6872, Train Recall_background: 0.9820
# Valid: 100%|██████████| 6/6 [00:01<00:00,  3.03batch/s]
# Epoch 7, Valid Loss: 0.1663, Valid IoU: 0.7433, Valid Accuracy: 0.9429, Valid Dice: 0.8381, Valid Precision: 0.8832, Valid Recall: 0.8049, Valid BalancedAccuracy: 0.8049, Valid IoU_flood: 0.5479, Valid IoU_background: 0.9386, Valid Dice_flood: 0.7079, Valid Dice_background: 0.9683, Valid Precision_flood: 0.8113, Valid Precision_background: 0.9551, Valid Recall_flood: 0.6279, Valid Recall_background: 0.9819
# INFO:training_logger:Epoch 7, Valid Loss: 0.1663, Valid IoU: 0.7433, Valid Accuracy: 0.9429, Valid Dice: 0.8381, Valid Precision: 0.8832, Valid Recall: 0.8049, Valid BalancedAccuracy: 0.8049, Valid IoU_flood: 0.5479, Valid IoU_background: 0.9386, Valid Dice_flood: 0.7079, Valid Dice_background: 0.9683, Valid Precision_flood: 0.8113, Valid Precision_background: 0.9551, Valid Recall_flood: 0.6279, Valid Recall_background: 0.9819
# Train: 100%|██████████| 16/16 [00:13<00:00,  1.19batch/s]
# Epoch 8, LR: 0.00081962, Train Loss: 0.1605, Train IoU: 0.7485, Train Accuracy: 0.9489, Train Dice: 0.8414, Train Precision: 0.8672, Train Recall: 0.8199, Train BalancedAccuracy: 0.8199, Train IoU_flood: 0.5514, Train IoU_background: 0.9455, Train Dice_flood: 0.7109, Train Dice_background: 0.9720, Train Precision_flood: 0.7695, Train Precision_background: 0.9649, Train Recall_flood: 0.6606, Train Recall_background: 0.9792
# INFO:training_logger:Epoch 8, LR: 0.00081962, Train Loss: 0.1605, Train IoU: 0.7485, Train Accuracy: 0.9489, Train Dice: 0.8414, Train Precision: 0.8672, Train Recall: 0.8199, Train BalancedAccuracy: 0.8199, Train IoU_flood: 0.5514, Train IoU_background: 0.9455, Train Dice_flood: 0.7109, Train Dice_background: 0.9720, Train Precision_flood: 0.7695, Train Precision_background: 0.9649, Train Recall_flood: 0.6606, Train Recall_background: 0.9792
# Valid: 100%|██████████| 6/6 [00:02<00:00,  2.90batch/s]
# Epoch 8, Valid Loss: 0.1434, Valid IoU: 0.7656, Valid Accuracy: 0.9477, Valid Dice: 0.8556, Valid Precision: 0.8895, Valid Recall: 0.8286, Valid BalancedAccuracy: 0.8286, Valid IoU_flood: 0.5876, Valid IoU_background: 0.9435, Valid Dice_flood: 0.7403, Valid Dice_background: 0.9709, Valid Precision_flood: 0.8183, Valid Precision_background: 0.9607, Valid Recall_flood: 0.6758, Valid Recall_background: 0.9814
# INFO:training_logger:Epoch 8, Valid Loss: 0.1434, Valid IoU: 0.7656, Valid Accuracy: 0.9477, Valid Dice: 0.8556, Valid Precision: 0.8895, Valid Recall: 0.8286, Valid BalancedAccuracy: 0.8286, Valid IoU_flood: 0.5876, Valid IoU_background: 0.9435, Valid Dice_flood: 0.7403, Valid Dice_background: 0.9709, Valid Precision_flood: 0.8183, Valid Precision_background: 0.9607, Valid Recall_flood: 0.6758, Valid Recall_background: 0.9814
# Train: 100%|██████████| 16/16 [00:13<00:00,  1.20batch/s]
# Epoch 9, LR: 0.00076907, Train Loss: 0.1519, Train IoU: 0.7661, Train Accuracy: 0.9530, Train Dice: 0.8552, Train Precision: 0.8784, Train Recall: 0.8353, Train BalancedAccuracy: 0.8353, Train IoU_flood: 0.5825, Train IoU_background: 0.9497, Train Dice_flood: 0.7362, Train Dice_background: 0.9742, Train Precision_flood: 0.7889, Train Precision_background: 0.9679, Train Recall_flood: 0.6901, Train Recall_background: 0.9806
# INFO:training_logger:Epoch 9, LR: 0.00076907, Train Loss: 0.1519, Train IoU: 0.7661, Train Accuracy: 0.9530, Train Dice: 0.8552, Train Precision: 0.8784, Train Recall: 0.8353, Train BalancedAccuracy: 0.8353, Train IoU_flood: 0.5825, Train IoU_background: 0.9497, Train Dice_flood: 0.7362, Train Dice_background: 0.9742, Train Precision_flood: 0.7889, Train Precision_background: 0.9679, Train Recall_flood: 0.6901, Train Recall_background: 0.9806
# Valid: 100%|██████████| 6/6 [00:02<00:00,  2.79batch/s]
# Epoch 9, Valid Loss: 0.1425, Valid IoU: 0.7691, Valid Accuracy: 0.9476, Valid Dice: 0.8584, Valid Precision: 0.8823, Valid Recall: 0.8382, Valid BalancedAccuracy: 0.8382, Valid IoU_flood: 0.5949, Valid IoU_background: 0.9433, Valid Dice_flood: 0.7460, Valid Dice_background: 0.9708, Valid Precision_flood: 0.8015, Valid Precision_background: 0.9631, Valid Recall_flood: 0.6978, Valid Recall_background: 0.9786
# INFO:training_logger:Epoch 9, Valid Loss: 0.1425, Valid IoU: 0.7691, Valid Accuracy: 0.9476, Valid Dice: 0.8584, Valid Precision: 0.8823, Valid Recall: 0.8382, Valid BalancedAccuracy: 0.8382, Valid IoU_flood: 0.5949, Valid IoU_background: 0.9433, Valid Dice_flood: 0.7460, Valid Dice_background: 0.9708, Valid Precision_flood: 0.8015, Valid Precision_background: 0.9631, Valid Recall_flood: 0.6978, Valid Recall_background: 0.9786
# Train: 100%|██████████| 16/16 [00:13<00:00,  1.21batch/s]
# Epoch 10, LR: 0.00071433, Train Loss: 0.1446, Train IoU: 0.7740, Train Accuracy: 0.9556, Train Dice: 0.8611, Train Precision: 0.8919, Train Recall: 0.8357, Train BalancedAccuracy: 0.8357, Train IoU_flood: 0.5955, Train IoU_background: 0.9525, Train Dice_flood: 0.7464, Train Dice_background: 0.9757, Train Precision_flood: 0.8161, Train Precision_background: 0.9677, Train Recall_flood: 0.6877, Train Recall_background: 0.9837
# INFO:training_logger:Epoch 10, LR: 0.00071433, Train Loss: 0.1446, Train IoU: 0.7740, Train Accuracy: 0.9556, Train Dice: 0.8611, Train Precision: 0.8919, Train Recall: 0.8357, Train BalancedAccuracy: 0.8357, Train IoU_flood: 0.5955, Train IoU_background: 0.9525, Train Dice_flood: 0.7464, Train Dice_background: 0.9757, Train Precision_flood: 0.8161, Train Precision_background: 0.9677, Train Recall_flood: 0.6877, Train Recall_background: 0.9837
# Valid: 100%|██████████| 6/6 [00:02<00:00,  2.77batch/s]
# Epoch 10, Valid Loss: 0.1448, Valid IoU: 0.7674, Valid Accuracy: 0.9489, Valid Dice: 0.8569, Valid Precision: 0.8984, Valid Recall: 0.8252, Valid BalancedAccuracy: 0.8252, Valid IoU_flood: 0.5899, Valid IoU_background: 0.9449, Valid Dice_flood: 0.7421, Valid Dice_background: 0.9717, Valid Precision_flood: 0.8371, Valid Precision_background: 0.9597, Valid Recall_flood: 0.6665, Valid Recall_background: 0.9839
# INFO:training_logger:Epoch 10, Valid Loss: 0.1448, Valid IoU: 0.7674, Valid Accuracy: 0.9489, Valid Dice: 0.8569, Valid Precision: 0.8984, Valid Recall: 0.8252, Valid BalancedAccuracy: 0.8252, Valid IoU_flood: 0.5899, Valid IoU_background: 0.9449, Valid Dice_flood: 0.7421, Valid Dice_background: 0.9717, Valid Precision_flood: 0.8371, Valid Precision_background: 0.9597, Valid Recall_flood: 0.6665, Valid Recall_background: 0.9839
# Train: 100%|██████████| 16/16 [00:13<00:00,  1.20batch/s]
# Epoch 11, LR: 0.00065624, Train Loss: 0.1454, Train IoU: 0.7756, Train Accuracy: 0.9559, Train Dice: 0.8623, Train Precision: 0.8922, Train Recall: 0.8377, Train BalancedAccuracy: 0.8377, Train IoU_flood: 0.5985, Train IoU_background: 0.9528, Train Dice_flood: 0.7488, Train Dice_background: 0.9758, Train Precision_flood: 0.8162, Train Precision_background: 0.9681, Train Recall_flood: 0.6917, Train Recall_background: 0.9836
# INFO:training_logger:Epoch 11, LR: 0.00065624, Train Loss: 0.1454, Train IoU: 0.7756, Train Accuracy: 0.9559, Train Dice: 0.8623, Train Precision: 0.8922, Train Recall: 0.8377, Train BalancedAccuracy: 0.8377, Train IoU_flood: 0.5985, Train IoU_background: 0.9528, Train Dice_flood: 0.7488, Train Dice_background: 0.9758, Train Precision_flood: 0.8162, Train Precision_background: 0.9681, Train Recall_flood: 0.6917, Train Recall_background: 0.9836
# Valid: 100%|██████████| 6/6 [00:02<00:00,  2.87batch/s]
# Epoch 11, Valid Loss: 0.1366, Valid IoU: 0.7777, Valid Accuracy: 0.9500, Valid Dice: 0.8648, Valid Precision: 0.8892, Valid Recall: 0.8441, Valid BalancedAccuracy: 0.8441, Valid IoU_flood: 0.6096, Valid IoU_background: 0.9458, Valid Dice_flood: 0.7575, Valid Dice_background: 0.9721, Valid Precision_flood: 0.8141, Valid Precision_background: 0.9644, Valid Recall_flood: 0.7082, Valid Recall_background: 0.9800
# INFO:training_logger:Epoch 11, Valid Loss: 0.1366, Valid IoU: 0.7777, Valid Accuracy: 0.9500, Valid Dice: 0.8648, Valid Precision: 0.8892, Valid Recall: 0.8441, Valid BalancedAccuracy: 0.8441, Valid IoU_flood: 0.6096, Valid IoU_background: 0.9458, Valid Dice_flood: 0.7575, Valid Dice_background: 0.9721, Valid Precision_flood: 0.8141, Valid Precision_background: 0.9644, Valid Recall_flood: 0.7082, Valid Recall_background: 0.9800
# Train: 100%|██████████| 16/16 [00:13<00:00,  1.22batch/s]
# Epoch 12, LR: 0.00059572, Train Loss: 0.1430, Train IoU: 0.7764, Train Accuracy: 0.9559, Train Dice: 0.8629, Train Precision: 0.8913, Train Recall: 0.8392, Train BalancedAccuracy: 0.8392, Train IoU_flood: 0.6000, Train IoU_background: 0.9528, Train Dice_flood: 0.7500, Train Dice_background: 0.9758, Train Precision_flood: 0.8142, Train Precision_background: 0.9685, Train Recall_flood: 0.6952, Train Recall_background: 0.9833
# INFO:training_logger:Epoch 12, LR: 0.00059572, Train Loss: 0.1430, Train IoU: 0.7764, Train Accuracy: 0.9559, Train Dice: 0.8629, Train Precision: 0.8913, Train Recall: 0.8392, Train BalancedAccuracy: 0.8392, Train IoU_flood: 0.6000, Train IoU_background: 0.9528, Train Dice_flood: 0.7500, Train Dice_background: 0.9758, Train Precision_flood: 0.8142, Train Precision_background: 0.9685, Train Recall_flood: 0.6952, Train Recall_background: 0.9833
# Valid: 100%|██████████| 6/6 [00:02<00:00,  2.81batch/s]
# Epoch 12, Valid Loss: 0.1472, Valid IoU: 0.7655, Valid Accuracy: 0.9495, Valid Dice: 0.8553, Valid Precision: 0.9084, Valid Recall: 0.8172, Valid BalancedAccuracy: 0.8172, Valid IoU_flood: 0.5855, Valid IoU_background: 0.9456, Valid Dice_flood: 0.7386, Valid Dice_background: 0.9720, Valid Precision_flood: 0.8593, Valid Precision_background: 0.9576, Valid Recall_flood: 0.6476, Valid Recall_background: 0.9869
# INFO:training_logger:Epoch 12, Valid Loss: 0.1472, Valid IoU: 0.7655, Valid Accuracy: 0.9495, Valid Dice: 0.8553, Valid Precision: 0.9084, Valid Recall: 0.8172, Valid BalancedAccuracy: 0.8172, Valid IoU_flood: 0.5855, Valid IoU_background: 0.9456, Valid Dice_flood: 0.7386, Valid Dice_background: 0.9720, Valid Precision_flood: 0.8593, Valid Precision_background: 0.9576, Valid Recall_flood: 0.6476, Valid Recall_background: 0.9869
# Train: 100%|██████████| 16/16 [00:13<00:00,  1.21batch/s]
# Epoch 13, LR: 0.00053374, Train Loss: 0.1380, Train IoU: 0.7798, Train Accuracy: 0.9574, Train Dice: 0.8654, Train Precision: 0.9021, Train Recall: 0.8362, Train BalancedAccuracy: 0.8362, Train IoU_flood: 0.6052, Train IoU_background: 0.9545, Train Dice_flood: 0.7540, Train Dice_background: 0.9767, Train Precision_flood: 0.8364, Train Precision_background: 0.9677, Train Recall_flood: 0.6864, Train Recall_background: 0.9859
# INFO:training_logger:Epoch 13, LR: 0.00053374, Train Loss: 0.1380, Train IoU: 0.7798, Train Accuracy: 0.9574, Train Dice: 0.8654, Train Precision: 0.9021, Train Recall: 0.8362, Train BalancedAccuracy: 0.8362, Train IoU_flood: 0.6052, Train IoU_background: 0.9545, Train Dice_flood: 0.7540, Train Dice_background: 0.9767, Train Precision_flood: 0.8364, Train Precision_background: 0.9677, Train Recall_flood: 0.6864, Train Recall_background: 0.9859
# Valid: 100%|██████████| 6/6 [00:02<00:00,  2.83batch/s]
# Epoch 13, Valid Loss: 0.1276, Valid IoU: 0.7891, Valid Accuracy: 0.9504, Valid Dice: 0.8735, Valid Precision: 0.8741, Valid Recall: 0.8729, Valid BalancedAccuracy: 0.8729, Valid IoU_flood: 0.6324, Valid IoU_background: 0.9458, Valid Dice_flood: 0.7748, Valid Dice_background: 0.9722, Valid Precision_flood: 0.7762, Valid Precision_background: 0.9719, Valid Recall_flood: 0.7735, Valid Recall_background: 0.9724
# INFO:training_logger:Epoch 13, Valid Loss: 0.1276, Valid IoU: 0.7891, Valid Accuracy: 0.9504, Valid Dice: 0.8735, Valid Precision: 0.8741, Valid Recall: 0.8729, Valid BalancedAccuracy: 0.8729, Valid IoU_flood: 0.6324, Valid IoU_background: 0.9458, Valid Dice_flood: 0.7748, Valid Dice_background: 0.9722, Valid Precision_flood: 0.7762, Valid Precision_background: 0.9719, Valid Recall_flood: 0.7735, Valid Recall_background: 0.9724
# Train: 100%|██████████| 16/16 [00:13<00:00,  1.20batch/s]
# Epoch 14, LR: 0.00047126, Train Loss: 0.1407, Train IoU: 0.7827, Train Accuracy: 0.9578, Train Dice: 0.8675, Train Precision: 0.9005, Train Recall: 0.8407, Train BalancedAccuracy: 0.8407, Train IoU_flood: 0.6106, Train IoU_background: 0.9548, Train Dice_flood: 0.7582, Train Dice_background: 0.9769, Train Precision_flood: 0.8324, Train Precision_background: 0.9686, Train Recall_flood: 0.6962, Train Recall_background: 0.9853
# INFO:training_logger:Epoch 14, LR: 0.00047126, Train Loss: 0.1407, Train IoU: 0.7827, Train Accuracy: 0.9578, Train Dice: 0.8675, Train Precision: 0.9005, Train Recall: 0.8407, Train BalancedAccuracy: 0.8407, Train IoU_flood: 0.6106, Train IoU_background: 0.9548, Train Dice_flood: 0.7582, Train Dice_background: 0.9769, Train Precision_flood: 0.8324, Train Precision_background: 0.9686, Train Recall_flood: 0.6962, Train Recall_background: 0.9853
# Valid: 100%|██████████| 6/6 [00:02<00:00,  2.94batch/s]
# Epoch 14, Valid Loss: 0.1345, Valid IoU: 0.7817, Valid Accuracy: 0.9511, Valid Dice: 0.8677, Valid Precision: 0.8925, Valid Recall: 0.8468, Valid BalancedAccuracy: 0.8468, Valid IoU_flood: 0.6165, Valid IoU_background: 0.9469, Valid Dice_flood: 0.7627, Valid Dice_background: 0.9727, Valid Precision_flood: 0.8199, Valid Precision_background: 0.9650, Valid Recall_flood: 0.7130, Valid Recall_background: 0.9806
# INFO:training_logger:Epoch 14, Valid Loss: 0.1345, Valid IoU: 0.7817, Valid Accuracy: 0.9511, Valid Dice: 0.8677, Valid Precision: 0.8925, Valid Recall: 0.8468, Valid BalancedAccuracy: 0.8468, Valid IoU_flood: 0.6165, Valid IoU_background: 0.9469, Valid Dice_flood: 0.7627, Valid Dice_background: 0.9727, Valid Precision_flood: 0.8199, Valid Precision_background: 0.9650, Valid Recall_flood: 0.7130, Valid Recall_background: 0.9806
# Train: 100%|██████████| 16/16 [00:13<00:00,  1.21batch/s]
# Epoch 15, LR: 0.00040928, Train Loss: 0.1343, Train IoU: 0.7843, Train Accuracy: 0.9574, Train Dice: 0.8688, Train Precision: 0.8927, Train Recall: 0.8484, Train BalancedAccuracy: 0.8484, Train IoU_flood: 0.6143, Train IoU_background: 0.9543, Train Dice_flood: 0.7611, Train Dice_background: 0.9766, Train Precision_flood: 0.8150, Train Precision_background: 0.9703, Train Recall_flood: 0.7138, Train Recall_background: 0.9830
# INFO:training_logger:Epoch 15, LR: 0.00040928, Train Loss: 0.1343, Train IoU: 0.7843, Train Accuracy: 0.9574, Train Dice: 0.8688, Train Precision: 0.8927, Train Recall: 0.8484, Train BalancedAccuracy: 0.8484, Train IoU_flood: 0.6143, Train IoU_background: 0.9543, Train Dice_flood: 0.7611, Train Dice_background: 0.9766, Train Precision_flood: 0.8150, Train Precision_background: 0.9703, Train Recall_flood: 0.7138, Train Recall_background: 0.9830
# Valid: 100%|██████████| 6/6 [00:02<00:00,  2.83batch/s]
# Epoch 15, Valid Loss: 0.1319, Valid IoU: 0.7861, Valid Accuracy: 0.9518, Valid Dice: 0.8710, Valid Precision: 0.8911, Valid Recall: 0.8535, Valid BalancedAccuracy: 0.8535, Valid IoU_flood: 0.6246, Valid IoU_background: 0.9476, Valid Dice_flood: 0.7689, Valid Dice_background: 0.9731, Valid Precision_flood: 0.8156, Valid Precision_background: 0.9667, Valid Recall_flood: 0.7273, Valid Recall_background: 0.9796
# INFO:training_logger:Epoch 15, Valid Loss: 0.1319, Valid IoU: 0.7861, Valid Accuracy: 0.9518, Valid Dice: 0.8710, Valid Precision: 0.8911, Valid Recall: 0.8535, Valid BalancedAccuracy: 0.8535, Valid IoU_flood: 0.6246, Valid IoU_background: 0.9476, Valid Dice_flood: 0.7689, Valid Dice_background: 0.9731, Valid Precision_flood: 0.8156, Valid Precision_background: 0.9667, Valid Recall_flood: 0.7273, Valid Recall_background: 0.9796
# Train: 100%|██████████| 16/16 [00:13<00:00,  1.21batch/s]
# Epoch 16, LR: 0.00034876, Train Loss: 0.1372, Train IoU: 0.7828, Train Accuracy: 0.9575, Train Dice: 0.8676, Train Precision: 0.8970, Train Recall: 0.8433, Train BalancedAccuracy: 0.8433, Train IoU_flood: 0.6110, Train IoU_background: 0.9545, Train Dice_flood: 0.7586, Train Dice_background: 0.9767, Train Precision_flood: 0.8248, Train Precision_background: 0.9692, Train Recall_flood: 0.7022, Train Recall_background: 0.9843
# INFO:training_logger:Epoch 16, LR: 0.00034876, Train Loss: 0.1372, Train IoU: 0.7828, Train Accuracy: 0.9575, Train Dice: 0.8676, Train Precision: 0.8970, Train Recall: 0.8433, Train BalancedAccuracy: 0.8433, Train IoU_flood: 0.6110, Train IoU_background: 0.9545, Train Dice_flood: 0.7586, Train Dice_background: 0.9767, Train Precision_flood: 0.8248, Train Precision_background: 0.9692, Train Recall_flood: 0.7022, Train Recall_background: 0.9843
# Valid: 100%|██████████| 6/6 [00:02<00:00,  2.88batch/s]
# Epoch 16, Valid Loss: 0.1279, Valid IoU: 0.7895, Valid Accuracy: 0.9505, Valid Dice: 0.8738, Valid Precision: 0.8737, Valid Recall: 0.8738, Valid BalancedAccuracy: 0.8738, Valid IoU_flood: 0.6332, Valid IoU_background: 0.9458, Valid Dice_flood: 0.7754, Valid Dice_background: 0.9722, Valid Precision_flood: 0.7753, Valid Precision_background: 0.9722, Valid Recall_flood: 0.7755, Valid Recall_background: 0.9721
# INFO:training_logger:Epoch 16, Valid Loss: 0.1279, Valid IoU: 0.7895, Valid Accuracy: 0.9505, Valid Dice: 0.8738, Valid Precision: 0.8737, Valid Recall: 0.8738, Valid BalancedAccuracy: 0.8738, Valid IoU_flood: 0.6332, Valid IoU_background: 0.9458, Valid Dice_flood: 0.7754, Valid Dice_background: 0.9722, Valid Precision_flood: 0.7753, Valid Precision_background: 0.9722, Valid Recall_flood: 0.7755, Valid Recall_background: 0.9721
# Train: 100%|██████████| 16/16 [00:13<00:00,  1.21batch/s]
# Epoch 17, LR: 0.00029067, Train Loss: 0.1343, Train IoU: 0.7868, Train Accuracy: 0.9585, Train Dice: 0.8706, Train Precision: 0.9011, Train Recall: 0.8455, Train BalancedAccuracy: 0.8455, Train IoU_flood: 0.6181, Train IoU_background: 0.9556, Train Dice_flood: 0.7640, Train Dice_background: 0.9773, Train Precision_flood: 0.8325, Train Precision_background: 0.9696, Train Recall_flood: 0.7059, Train Recall_background: 0.9851
# INFO:training_logger:Epoch 17, LR: 0.00029067, Train Loss: 0.1343, Train IoU: 0.7868, Train Accuracy: 0.9585, Train Dice: 0.8706, Train Precision: 0.9011, Train Recall: 0.8455, Train BalancedAccuracy: 0.8455, Train IoU_flood: 0.6181, Train IoU_background: 0.9556, Train Dice_flood: 0.7640, Train Dice_background: 0.9773, Train Precision_flood: 0.8325, Train Precision_background: 0.9696, Train Recall_flood: 0.7059, Train Recall_background: 0.9851
# Valid: 100%|██████████| 6/6 [00:02<00:00,  2.94batch/s]
# Epoch 17, Valid Loss: 0.1314, Valid IoU: 0.7854, Valid Accuracy: 0.9511, Valid Dice: 0.8706, Valid Precision: 0.8857, Valid Recall: 0.8569, Valid BalancedAccuracy: 0.8569, Valid IoU_flood: 0.6240, Valid IoU_background: 0.9468, Valid Dice_flood: 0.7685, Valid Dice_background: 0.9727, Valid Precision_flood: 0.8038, Valid Precision_background: 0.9676, Valid Recall_flood: 0.7362, Valid Recall_background: 0.9777
# INFO:training_logger:Epoch 17, Valid Loss: 0.1314, Valid IoU: 0.7854, Valid Accuracy: 0.9511, Valid Dice: 0.8706, Valid Precision: 0.8857, Valid Recall: 0.8569, Valid BalancedAccuracy: 0.8569, Valid IoU_flood: 0.6240, Valid IoU_background: 0.9468, Valid Dice_flood: 0.7685, Valid Dice_background: 0.9727, Valid Precision_flood: 0.8038, Valid Precision_background: 0.9676, Valid Recall_flood: 0.7362, Valid Recall_background: 0.9777
# Train: 100%|██████████| 16/16 [00:13<00:00,  1.21batch/s]
# Epoch 18, LR: 0.00023593, Train Loss: 0.1342, Train IoU: 0.7847, Train Accuracy: 0.9579, Train Dice: 0.8691, Train Precision: 0.8977, Train Recall: 0.8452, Train BalancedAccuracy: 0.8452, Train IoU_flood: 0.6146, Train IoU_background: 0.9549, Train Dice_flood: 0.7613, Train Dice_background: 0.9769, Train Precision_flood: 0.8259, Train Precision_background: 0.9696, Train Recall_flood: 0.7061, Train Recall_background: 0.9844
# INFO:training_logger:Epoch 18, LR: 0.00023593, Train Loss: 0.1342, Train IoU: 0.7847, Train Accuracy: 0.9579, Train Dice: 0.8691, Train Precision: 0.8977, Train Recall: 0.8452, Train BalancedAccuracy: 0.8452, Train IoU_flood: 0.6146, Train IoU_background: 0.9549, Train Dice_flood: 0.7613, Train Dice_background: 0.9769, Train Precision_flood: 0.8259, Train Precision_background: 0.9696, Train Recall_flood: 0.7061, Train Recall_background: 0.9844
# Valid: 100%|██████████| 6/6 [00:02<00:00,  2.84batch/s]
# Epoch 18, Valid Loss: 0.1319, Valid IoU: 0.7864, Valid Accuracy: 0.9527, Valid Dice: 0.8711, Valid Precision: 0.8997, Valid Recall: 0.8474, Valid BalancedAccuracy: 0.8474, Valid IoU_flood: 0.6241, Valid IoU_background: 0.9487, Valid Dice_flood: 0.7686, Valid Dice_background: 0.9737, Valid Precision_flood: 0.8343, Valid Precision_background: 0.9650, Valid Recall_flood: 0.7124, Valid Recall_background: 0.9825
# INFO:training_logger:Epoch 18, Valid Loss: 0.1319, Valid IoU: 0.7864, Valid Accuracy: 0.9527, Valid Dice: 0.8711, Valid Precision: 0.8997, Valid Recall: 0.8474, Valid BalancedAccuracy: 0.8474, Valid IoU_flood: 0.6241, Valid IoU_background: 0.9487, Valid Dice_flood: 0.7686, Valid Dice_background: 0.9737, Valid Precision_flood: 0.8343, Valid Precision_background: 0.9650, Valid Recall_flood: 0.7124, Valid Recall_background: 0.9825
# Train: 100%|██████████| 16/16 [00:13<00:00,  1.22batch/s]
# Epoch 19, LR: 0.00018538, Train Loss: 0.1276, Train IoU: 0.7965, Train Accuracy: 0.9608, Train Dice: 0.8777, Train Precision: 0.9092, Train Recall: 0.8517, Train BalancedAccuracy: 0.8517, Train IoU_flood: 0.6351, Train IoU_background: 0.9580, Train Dice_flood: 0.7768, Train Dice_background: 0.9785, Train Precision_flood: 0.8476, Train Precision_background: 0.9707, Train Recall_flood: 0.7170, Train Recall_background: 0.9865
# INFO:training_logger:Epoch 19, LR: 0.00018538, Train Loss: 0.1276, Train IoU: 0.7965, Train Accuracy: 0.9608, Train Dice: 0.8777, Train Precision: 0.9092, Train Recall: 0.8517, Train BalancedAccuracy: 0.8517, Train IoU_flood: 0.6351, Train IoU_background: 0.9580, Train Dice_flood: 0.7768, Train Dice_background: 0.9785, Train Precision_flood: 0.8476, Train Precision_background: 0.9707, Train Recall_flood: 0.7170, Train Recall_background: 0.9865
# Valid: 100%|██████████| 6/6 [00:02<00:00,  2.94batch/s]
# Epoch 19, Valid Loss: 0.1352, Valid IoU: 0.7820, Valid Accuracy: 0.9519, Valid Dice: 0.8679, Valid Precision: 0.8999, Valid Recall: 0.8420, Valid BalancedAccuracy: 0.8420, Valid IoU_flood: 0.6162, Valid IoU_background: 0.9478, Valid Dice_flood: 0.7626, Valid Dice_background: 0.9732, Valid Precision_flood: 0.8360, Valid Precision_background: 0.9637, Valid Recall_flood: 0.7010, Valid Recall_background: 0.9830
# INFO:training_logger:Epoch 19, Valid Loss: 0.1352, Valid IoU: 0.7820, Valid Accuracy: 0.9519, Valid Dice: 0.8679, Valid Precision: 0.8999, Valid Recall: 0.8420, Valid BalancedAccuracy: 0.8420, Valid IoU_flood: 0.6162, Valid IoU_background: 0.9478, Valid Dice_flood: 0.7626, Valid Dice_background: 0.9732, Valid Precision_flood: 0.8360, Valid Precision_background: 0.9637, Valid Recall_flood: 0.7010, Valid Recall_background: 0.9830
# Train: 100%|██████████| 16/16 [00:13<00:00,  1.23batch/s]
# Epoch 20, LR: 0.00013984, Train Loss: 0.1300, Train IoU: 0.7942, Train Accuracy: 0.9600, Train Dice: 0.8760, Train Precision: 0.9041, Train Recall: 0.8525, Train BalancedAccuracy: 0.8525, Train IoU_flood: 0.6313, Train IoU_background: 0.9571, Train Dice_flood: 0.7740, Train Dice_background: 0.9781, Train Precision_flood: 0.8372, Train Precision_background: 0.9710, Train Recall_flood: 0.7197, Train Recall_background: 0.9853
# INFO:training_logger:Epoch 20, LR: 0.00013984, Train Loss: 0.1300, Train IoU: 0.7942, Train Accuracy: 0.9600, Train Dice: 0.8760, Train Precision: 0.9041, Train Recall: 0.8525, Train BalancedAccuracy: 0.8525, Train IoU_flood: 0.6313, Train IoU_background: 0.9571, Train Dice_flood: 0.7740, Train Dice_background: 0.9781, Train Precision_flood: 0.8372, Train Precision_background: 0.9710, Train Recall_flood: 0.7197, Train Recall_background: 0.9853
# Valid: 100%|██████████| 6/6 [00:02<00:00,  2.90batch/s]
# Epoch 20, Valid Loss: 0.1354, Valid IoU: 0.7812, Valid Accuracy: 0.9525, Valid Dice: 0.8672, Valid Precision: 0.9084, Valid Recall: 0.8354, Valid BalancedAccuracy: 0.8354, Valid IoU_flood: 0.6139, Valid IoU_background: 0.9486, Valid Dice_flood: 0.7607, Valid Dice_background: 0.9736, Valid Precision_flood: 0.8549, Valid Precision_background: 0.9619, Valid Recall_flood: 0.6853, Valid Recall_background: 0.9856
# INFO:training_logger:Epoch 20, Valid Loss: 0.1354, Valid IoU: 0.7812, Valid Accuracy: 0.9525, Valid Dice: 0.8672, Valid Precision: 0.9084, Valid Recall: 0.8354, Valid BalancedAccuracy: 0.8354, Valid IoU_flood: 0.6139, Valid IoU_background: 0.9486, Valid Dice_flood: 0.7607, Valid Dice_background: 0.9736, Valid Precision_flood: 0.8549, Valid Precision_background: 0.9619, Valid Recall_flood: 0.6853, Valid Recall_background: 0.9856
# Train: 100%|██████████| 16/16 [00:13<00:00,  1.21batch/s]
# Epoch 21, LR: 0.00010001, Train Loss: 0.1307, Train IoU: 0.7978, Train Accuracy: 0.9608, Train Dice: 0.8786, Train Precision: 0.9063, Train Recall: 0.8553, Train BalancedAccuracy: 0.8553, Train IoU_flood: 0.6376, Train IoU_background: 0.9579, Train Dice_flood: 0.7787, Train Dice_background: 0.9785, Train Precision_flood: 0.8410, Train Precision_background: 0.9715, Train Recall_flood: 0.7251, Train Recall_background: 0.9856
# INFO:training_logger:Epoch 21, LR: 0.00010001, Train Loss: 0.1307, Train IoU: 0.7978, Train Accuracy: 0.9608, Train Dice: 0.8786, Train Precision: 0.9063, Train Recall: 0.8553, Train BalancedAccuracy: 0.8553, Train IoU_flood: 0.6376, Train IoU_background: 0.9579, Train Dice_flood: 0.7787, Train Dice_background: 0.9785, Train Precision_flood: 0.8410, Train Precision_background: 0.9715, Train Recall_flood: 0.7251, Train Recall_background: 0.9856
# Valid: 100%|██████████| 6/6 [00:02<00:00,  2.92batch/s]
# Epoch 21, Valid Loss: 0.1358, Valid IoU: 0.7824, Valid Accuracy: 0.9525, Valid Dice: 0.8681, Valid Precision: 0.9056, Valid Recall: 0.8386, Valid BalancedAccuracy: 0.8386, Valid IoU_flood: 0.6163, Valid IoU_background: 0.9485, Valid Dice_flood: 0.7626, Valid Dice_background: 0.9736, Valid Precision_flood: 0.8484, Valid Precision_background: 0.9627, Valid Recall_flood: 0.6925, Valid Recall_background: 0.9847
# INFO:training_logger:Epoch 21, Valid Loss: 0.1358, Valid IoU: 0.7824, Valid Accuracy: 0.9525, Valid Dice: 0.8681, Valid Precision: 0.9056, Valid Recall: 0.8386, Valid BalancedAccuracy: 0.8386, Valid IoU_flood: 0.6163, Valid IoU_background: 0.9485, Valid Dice_flood: 0.7626, Valid Dice_background: 0.9736, Valid Precision_flood: 0.8484, Valid Precision_background: 0.9627, Valid Recall_flood: 0.6925, Valid Recall_background: 0.9847
# Train: 100%|██████████| 16/16 [00:13<00:00,  1.20batch/s]
# Epoch 22, LR: 0.00006654, Train Loss: 0.1264, Train IoU: 0.8024, Train Accuracy: 0.9619, Train Dice: 0.8819, Train Precision: 0.9104, Train Recall: 0.8580, Train BalancedAccuracy: 0.8580, Train IoU_flood: 0.6457, Train IoU_background: 0.9591, Train Dice_flood: 0.7847, Train Dice_background: 0.9791, Train Precision_flood: 0.8488, Train Precision_background: 0.9720, Train Recall_flood: 0.7297, Train Recall_background: 0.9863
# INFO:training_logger:Epoch 22, LR: 0.00006654, Train Loss: 0.1264, Train IoU: 0.8024, Train Accuracy: 0.9619, Train Dice: 0.8819, Train Precision: 0.9104, Train Recall: 0.8580, Train BalancedAccuracy: 0.8580, Train IoU_flood: 0.6457, Train IoU_background: 0.9591, Train Dice_flood: 0.7847, Train Dice_background: 0.9791, Train Precision_flood: 0.8488, Train Precision_background: 0.9720, Train Recall_flood: 0.7297, Train Recall_background: 0.9863
# Valid: 100%|██████████| 6/6 [00:02<00:00,  2.89batch/s]
# Epoch 22, Valid Loss: 0.1324, Valid IoU: 0.7871, Valid Accuracy: 0.9531, Valid Dice: 0.8716, Valid Precision: 0.9027, Valid Recall: 0.8462, Valid BalancedAccuracy: 0.8462, Valid IoU_flood: 0.6251, Valid IoU_background: 0.9491, Valid Dice_flood: 0.7693, Valid Dice_background: 0.9739, Valid Precision_flood: 0.8409, Valid Precision_background: 0.9646, Valid Recall_flood: 0.7090, Valid Recall_background: 0.9834
# INFO:training_logger:Epoch 22, Valid Loss: 0.1324, Valid IoU: 0.7871, Valid Accuracy: 0.9531, Valid Dice: 0.8716, Valid Precision: 0.9027, Valid Recall: 0.8462, Valid BalancedAccuracy: 0.8462, Valid IoU_flood: 0.6251, Valid IoU_background: 0.9491, Valid Dice_flood: 0.7693, Valid Dice_background: 0.9739, Valid Precision_flood: 0.8409, Valid Precision_background: 0.9646, Valid Recall_flood: 0.7090, Valid Recall_background: 0.9834
# Train: 100%|██████████| 16/16 [00:13<00:00,  1.22batch/s]
# Epoch 23, LR: 0.00003994, Train Loss: 0.1247, Train IoU: 0.8022, Train Accuracy: 0.9617, Train Dice: 0.8818, Train Precision: 0.9081, Train Recall: 0.8595, Train BalancedAccuracy: 0.8595, Train IoU_flood: 0.6456, Train IoU_background: 0.9589, Train Dice_flood: 0.7846, Train Dice_background: 0.9790, Train Precision_flood: 0.8437, Train Precision_background: 0.9724, Train Recall_flood: 0.7333, Train Recall_background: 0.9857
# INFO:training_logger:Epoch 23, LR: 0.00003994, Train Loss: 0.1247, Train IoU: 0.8022, Train Accuracy: 0.9617, Train Dice: 0.8818, Train Precision: 0.9081, Train Recall: 0.8595, Train BalancedAccuracy: 0.8595, Train IoU_flood: 0.6456, Train IoU_background: 0.9589, Train Dice_flood: 0.7846, Train Dice_background: 0.9790, Train Precision_flood: 0.8437, Train Precision_background: 0.9724, Train Recall_flood: 0.7333, Train Recall_background: 0.9857
# Valid: 100%|██████████| 6/6 [00:02<00:00,  2.90batch/s]
# Epoch 23, Valid Loss: 0.1363, Valid IoU: 0.7811, Valid Accuracy: 0.9525, Valid Dice: 0.8671, Valid Precision: 0.9088, Valid Recall: 0.8351, Valid BalancedAccuracy: 0.8351, Valid IoU_flood: 0.6136, Valid IoU_background: 0.9486, Valid Dice_flood: 0.7605, Valid Dice_background: 0.9736, Valid Precision_flood: 0.8557, Valid Precision_background: 0.9618, Valid Recall_flood: 0.6844, Valid Recall_background: 0.9857
# INFO:training_logger:Epoch 23, Valid Loss: 0.1363, Valid IoU: 0.7811, Valid Accuracy: 0.9525, Valid Dice: 0.8671, Valid Precision: 0.9088, Valid Recall: 0.8351, Valid BalancedAccuracy: 0.8351, Valid IoU_flood: 0.6136, Valid IoU_background: 0.9486, Valid Dice_flood: 0.7605, Valid Dice_background: 0.9736, Valid Precision_flood: 0.8557, Valid Precision_background: 0.9618, Valid Recall_flood: 0.6844, Valid Recall_background: 0.9857
# Train: 100%|██████████| 16/16 [00:13<00:00,  1.21batch/s]
# Epoch 24, LR: 0.00002063, Train Loss: 0.1222, Train IoU: 0.8055, Train Accuracy: 0.9626, Train Dice: 0.8841, Train Precision: 0.9118, Train Recall: 0.8607, Train BalancedAccuracy: 0.8607, Train IoU_flood: 0.6512, Train IoU_background: 0.9598, Train Dice_flood: 0.7887, Train Dice_background: 0.9795, Train Precision_flood: 0.8511, Train Precision_background: 0.9725, Train Recall_flood: 0.7349, Train Recall_background: 0.9865
# INFO:training_logger:Epoch 24, LR: 0.00002063, Train Loss: 0.1222, Train IoU: 0.8055, Train Accuracy: 0.9626, Train Dice: 0.8841, Train Precision: 0.9118, Train Recall: 0.8607, Train BalancedAccuracy: 0.8607, Train IoU_flood: 0.6512, Train IoU_background: 0.9598, Train Dice_flood: 0.7887, Train Dice_background: 0.9795, Train Precision_flood: 0.8511, Train Precision_background: 0.9725, Train Recall_flood: 0.7349, Train Recall_background: 0.9865
# Valid: 100%|██████████| 6/6 [00:02<00:00,  2.88batch/s]
# Epoch 24, Valid Loss: 0.1372, Valid IoU: 0.7799, Valid Accuracy: 0.9521, Valid Dice: 0.8662, Valid Precision: 0.9074, Valid Recall: 0.8345, Valid BalancedAccuracy: 0.8345, Valid IoU_flood: 0.6116, Valid IoU_background: 0.9482, Valid Dice_flood: 0.7590, Valid Dice_background: 0.9734, Valid Precision_flood: 0.8531, Valid Precision_background: 0.9617, Valid Recall_flood: 0.6836, Valid Recall_background: 0.9854
# INFO:training_logger:Epoch 24, Valid Loss: 0.1372, Valid IoU: 0.7799, Valid Accuracy: 0.9521, Valid Dice: 0.8662, Valid Precision: 0.9074, Valid Recall: 0.8345, Valid BalancedAccuracy: 0.8345, Valid IoU_flood: 0.6116, Valid IoU_background: 0.9482, Valid Dice_flood: 0.7590, Valid Dice_background: 0.9734, Valid Precision_flood: 0.8531, Valid Precision_background: 0.9617, Valid Recall_flood: 0.6836, Valid Recall_background: 0.9854
# Train: 100%|██████████| 16/16 [00:13<00:00,  1.22batch/s]
# Epoch 25, LR: 0.00000892, Train Loss: 0.1210, Train IoU: 0.8051, Train Accuracy: 0.9627, Train Dice: 0.8838, Train Precision: 0.9144, Train Recall: 0.8583, Train BalancedAccuracy: 0.8583, Train IoU_flood: 0.6502, Train IoU_background: 0.9599, Train Dice_flood: 0.7881, Train Dice_background: 0.9796, Train Precision_flood: 0.8568, Train Precision_background: 0.9720, Train Recall_flood: 0.7295, Train Recall_background: 0.9872
# ...
# INFO:training_logger:Epoch 200, Valid Loss: 0.1424, Valid IoU: 0.7770, Valid Accuracy: 0.9508, Valid Dice: 0.8641, Valid Precision: 0.8992, Valid Recall: 0.8362, Valid BalancedAccuracy: 0.8362, Valid IoU_flood: 0.6071, Valid IoU_background: 0.9468, Valid Dice_flood: 0.7555, Valid Dice_background: 0.9727, Valid Precision_flood: 0.8362, Valid Precision_background: 0.9623, Valid Recall_flood: 0.6891, Valid Recall_background: 0.9833
# Test:   0%|          | 0/23 [00:00<?, ?batch/s]<ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# Test: 100%|██████████| 23/23 [01:10<00:00,  3.05s/batch]
# WeightsEpoch: 143, Test IoU: 0.7974, Test Accuracy: 0.9478, Test Dice: 0.8800, Test Precision: 0.8826, Test Recall: 0.8776, Test BalancedAccuracy: 0.8776, Test IoU_flood: 0.6527, Test IoU_background: 0.9422, Test Dice_flood: 0.7898, Test Dice_background: 0.9702, Test Precision_flood: 0.7960, Test Precision_background: 0.9692, Test Recall_flood: 0.7838, Test Recall_background: 0.9713
# INFO:testing_logger:WeightsEpoch: 143, Test IoU: 0.7974, Test Accuracy: 0.9478, Test Dice: 0.8800, Test Precision: 0.8826, Test Recall: 0.8776, Test BalancedAccuracy: 0.8776, Test IoU_flood: 0.6527, Test IoU_background: 0.9422, Test Dice_flood: 0.7898, Test Dice_background: 0.9702, Test Precision_flood: 0.7960, Test Precision_background: 0.9692, Test Recall_flood: 0.7838, Test Recall_background: 0.9713
# WeightsEpoch: 143, Test Aug IoU: 0.8004, Test Accuracy: 0.9492, Test Dice: 0.8820, Test Precision: 0.8885, Test Recall: 0.8759, Test BalancedAccuracy: 0.8759, Test IoU_flood: 0.6570, Test IoU_background: 0.9437, Test Dice_flood: 0.7930, Test Dice_background: 0.9710, Test Precision_flood: 0.8085, Test Precision_background: 0.9684, Test Recall_flood: 0.7780, Test Recall_background: 0.9737
# INFO:testing_logger:WeightsEpoch: 143, Test Aug IoU: 0.8004, Test Accuracy: 0.9492, Test Dice: 0.8820, Test Precision: 0.8885, Test Recall: 0.8759, Test BalancedAccuracy: 0.8759, Test IoU_flood: 0.6570, Test IoU_background: 0.9437, Test Dice_flood: 0.7930, Test Dice_background: 0.9710, Test Precision_flood: 0.8085, Test Precision_background: 0.9684, Test Recall_flood: 0.7780, Test Recall_background: 0.9737
# WeightsEpoch: 143, Test Aug CRF IoU: 0.7887, Test Accuracy: 0.9503, Test Dice: 0.8732, Test Precision: 0.9261, Test Recall: 0.8351, Test BalancedAccuracy: 0.8351, Test IoU_flood: 0.6317, Test IoU_background: 0.9457, Test Dice_flood: 0.7743, Test Dice_background: 0.9721, Test Precision_flood: 0.8962, Test Precision_background: 0.9560, Test Recall_flood: 0.6816, Test Recall_background: 0.9887
# INFO:testing_logger:WeightsEpoch: 143, Test Aug CRF IoU: 0.7887, Test Accuracy: 0.9503, Test Dice: 0.8732, Test Precision: 0.9261, Test Recall: 0.8351, Test BalancedAccuracy: 0.8351, Test IoU_flood: 0.6317, Test IoU_background: 0.9457, Test Dice_flood: 0.7743, Test Dice_background: 0.9721, Test Precision_flood: 0.8962, Test Precision_background: 0.9560, Test Recall_flood: 0.6816, Test Recall_background: 0.9887
# TP_flood = 2011383.0, FP_flood = 515632.0, TN_flood = 17435634.0, FN_flood = 554718.0
# TP_flood_aug = 1996521.0, FP_flood_aug = 472778.0, TN_flood_aug = 17478488.0, FN_flood_aug = 569580.0
# TP_floodaug_crf = 1748953.0, FP_floodaug_crf = 202626.0, TN_floodaug_crf = 17748640.0, FN_floodaug_crf = 817148.0
# Test Bolivia:   0%|          | 0/4 [00:00<?, ?batch/s]<ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# Test Bolivia: 100%|██████████| 4/4 [00:12<00:00,  3.03s/batch]
# WeightsEpoch: 143, TestBolivia IoU: 0.7904, TestB Accuracy: 0.9367, TestB Dice: 0.8763, TestB Precision: 0.8940, TestB Recall: 0.8609, TestB BalancedAccuracy: 0.8609, TestB IoU_flood: 0.6527, TestB IoU_background: 0.9282, TestB Dice_flood: 0.7898, TestB Dice_background: 0.9627, TestB Precision_flood: 0.8343, TestB Precision_background: 0.9537, TestB Recall_flood: 0.7498, TestB Recall_background: 0.9719
# INFO:testing_logger:WeightsEpoch: 143, TestBolivia IoU: 0.7904, TestB Accuracy: 0.9367, TestB Dice: 0.8763, TestB Precision: 0.8940, TestB Recall: 0.8609, TestB BalancedAccuracy: 0.8609, TestB IoU_flood: 0.6527, TestB IoU_background: 0.9282, TestB Dice_flood: 0.7898, TestB Dice_background: 0.9627, TestB Precision_flood: 0.8343, TestB Precision_background: 0.9537, TestB Recall_flood: 0.7498, TestB Recall_background: 0.9719
# WeightsEpoch: 143, TestBolivia Aug IoU: 0.8007, TestB Accuracy: 0.9481, TestB Dice: 0.8824, TestB Precision: 0.8899, TestB Recall: 0.8753, TestB BalancedAccuracy: 0.8753, TestB IoU_flood: 0.6591, TestB IoU_background: 0.9423, TestB Dice_flood: 0.7946, TestB Dice_background: 0.9703, TestB Precision_flood: 0.8127, TestB Precision_background: 0.9672, TestB Recall_flood: 0.7772, TestB Recall_background: 0.9734
# INFO:testing_logger:WeightsEpoch: 143, TestBolivia Aug IoU: 0.8007, TestB Accuracy: 0.9481, TestB Dice: 0.8824, TestB Precision: 0.8899, TestB Recall: 0.8753, TestB BalancedAccuracy: 0.8753, TestB IoU_flood: 0.6591, TestB IoU_background: 0.9423, TestB Dice_flood: 0.7946, TestB Dice_background: 0.9703, TestB Precision_flood: 0.8127, TestB Precision_background: 0.9672, TestB Recall_flood: 0.7772, TestB Recall_background: 0.9734
# WeightsEpoch: 143, TestBolivia Aug CRF IoU: 0.7827, TestB Accuracy: 0.9476, TestB Dice: 0.8690, TestB Precision: 0.9259, TestB Recall: 0.8292, TestB BalancedAccuracy: 0.8292, TestB IoU_flood: 0.6227, TestB IoU_background: 0.9426, TestB Dice_flood: 0.7675, TestB Dice_background: 0.9705, TestB Precision_flood: 0.8991, TestB Precision_background: 0.9528, TestB Recall_flood: 0.6695, TestB Recall_background: 0.9889
# INFO:testing_logger:WeightsEpoch: 143, TestBolivia Aug CRF IoU: 0.7827, TestB Accuracy: 0.9476, TestB Dice: 0.8690, TestB Precision: 0.9259, TestB Recall: 0.8292, TestB BalancedAccuracy: 0.8292, TestB IoU_flood: 0.6227, TestB IoU_background: 0.9426, TestB Dice_flood: 0.7675, TestB Dice_background: 0.9705, TestB Precision_flood: 0.8991, TestB Precision_background: 0.9528, TestB Recall_flood: 0.6695, TestB Recall_background: 0.9889
# Test:   0%|          | 0/23 [00:00<?, ?batch/s]<ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# Test: 100%|██████████| 23/23 [01:08<00:00,  3.00s/batch]
# WeightsEpoch: 200, Test IoU: 0.7881, Test Accuracy: 0.9479, Test Dice: 0.8730, Test Precision: 0.9010, Test Recall: 0.8499, Test BalancedAccuracy: 0.8499, Test IoU_flood: 0.6334, Test IoU_background: 0.9428, Test Dice_flood: 0.7755, Test Dice_background: 0.9705, Test Precision_flood: 0.8413, Test Precision_background: 0.9607, Test Recall_flood: 0.7193, Test Recall_background: 0.9806
# INFO:testing_logger:WeightsEpoch: 200, Test IoU: 0.7881, Test Accuracy: 0.9479, Test Dice: 0.8730, Test Precision: 0.9010, Test Recall: 0.8499, Test BalancedAccuracy: 0.8499, Test IoU_flood: 0.6334, Test IoU_background: 0.9428, Test Dice_flood: 0.7755, Test Dice_background: 0.9705, Test Precision_flood: 0.8413, Test Precision_background: 0.9607, Test Recall_flood: 0.7193, Test Recall_background: 0.9806
# WeightsEpoch: 200, Test Aug IoU: 0.7856, Test Accuracy: 0.9476, Test Dice: 0.8712, Test Precision: 0.9029, Test Recall: 0.8457, Test BalancedAccuracy: 0.8457, Test IoU_flood: 0.6288, Test IoU_background: 0.9425, Test Dice_flood: 0.7721, Test Dice_background: 0.9704, Test Precision_flood: 0.8463, Test Precision_background: 0.9595, Test Recall_flood: 0.7099, Test Recall_background: 0.9816
# INFO:testing_logger:WeightsEpoch: 200, Test Aug IoU: 0.7856, Test Accuracy: 0.9476, Test Dice: 0.8712, Test Precision: 0.9029, Test Recall: 0.8457, Test BalancedAccuracy: 0.8457, Test IoU_flood: 0.6288, Test IoU_background: 0.9425, Test Dice_flood: 0.7721, Test Dice_background: 0.9704, Test Precision_flood: 0.8463, Test Precision_background: 0.9595, Test Recall_flood: 0.7099, Test Recall_background: 0.9816
# WeightsEpoch: 200, Test Aug CRF IoU: 0.7606, Test Accuracy: 0.9445, Test Dice: 0.8521, Test Precision: 0.9293, Test Recall: 0.8039, Test BalancedAccuracy: 0.8039, Test IoU_flood: 0.5814, Test IoU_background: 0.9398, Test Dice_flood: 0.7353, Test Dice_background: 0.9690, Test Precision_flood: 0.9109, Test Precision_background: 0.9476, Test Recall_flood: 0.6164, Test Recall_background: 0.9914
# INFO:testing_logger:WeightsEpoch: 200, Test Aug CRF IoU: 0.7606, Test Accuracy: 0.9445, Test Dice: 0.8521, Test Precision: 0.9293, Test Recall: 0.8039, Test BalancedAccuracy: 0.8039, Test IoU_flood: 0.5814, Test IoU_background: 0.9398, Test Dice_flood: 0.7353, Test Dice_background: 0.9690, Test Precision_flood: 0.9109, Test Precision_background: 0.9476, Test Recall_flood: 0.6164, Test Recall_background: 0.9914
# TP_flood = 1845729.0, FP_flood = 348052.0, TN_flood = 17603214.0, FN_flood = 720372.0
# TP_flood_aug = 1821592.0, FP_flood_aug = 330853.0, TN_flood_aug = 17620413.0, FN_flood_aug = 744509.0
# TP_floodaug_crf = 1581743.0, FP_floodaug_crf = 154626.0, TN_floodaug_crf = 17796640.0, FN_floodaug_crf = 984358.0
# Test Bolivia:   0%|          | 0/4 [00:00<?, ?batch/s]<ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# <ipython-input-11-b592da887fab>:29: RuntimeWarning: invalid value encountered in divide
#   ratio = np.clip(np.nan_to_num((VV - VH) / (VV + VH), 0), 0, 1)
# Test Bolivia: 100%|██████████| 4/4 [00:11<00:00,  2.96s/batch]
# WeightsEpoch: 200, TestBolivia IoU: 0.6568, TestB Accuracy: 0.8989, TestB Dice: 0.7683, TestB Precision: 0.8619, TestB Recall: 0.7237, TestB BalancedAccuracy: 0.7237, TestB IoU_flood: 0.4228, TestB IoU_background: 0.8908, TestB Dice_flood: 0.5943, TestB Dice_background: 0.9422, TestB Precision_flood: 0.8168, TestB Precision_background: 0.9070, TestB Recall_flood: 0.4671, TestB Recall_background: 0.9803
# INFO:testing_logger:WeightsEpoch: 200, TestBolivia IoU: 0.6568, TestB Accuracy: 0.8989, TestB Dice: 0.7683, TestB Precision: 0.8619, TestB Recall: 0.7237, TestB BalancedAccuracy: 0.7237, TestB IoU_flood: 0.4228, TestB IoU_background: 0.8908, TestB Dice_flood: 0.5943, TestB Dice_background: 0.9422, TestB Precision_flood: 0.8168, TestB Precision_background: 0.9070, TestB Recall_flood: 0.4671, TestB Recall_background: 0.9803
# WeightsEpoch: 200, TestBolivia Aug IoU: 0.7715, TestB Accuracy: 0.9428, TestB Dice: 0.8610, TestB Precision: 0.9000, TestB Recall: 0.8312, TestB BalancedAccuracy: 0.8312, TestB IoU_flood: 0.6057, TestB IoU_background: 0.9372, TestB Dice_flood: 0.7544, TestB Dice_background: 0.9676, TestB Precision_flood: 0.8460, TestB Precision_background: 0.9540, TestB Recall_flood: 0.6808, TestB Recall_background: 0.9816
# INFO:testing_logger:WeightsEpoch: 200, TestBolivia Aug IoU: 0.7715, TestB Accuracy: 0.9428, TestB Dice: 0.8610, TestB Precision: 0.9000, TestB Recall: 0.8312, TestB BalancedAccuracy: 0.8312, TestB IoU_flood: 0.6057, TestB IoU_background: 0.9372, TestB Dice_flood: 0.7544, TestB Dice_background: 0.9676, TestB Precision_flood: 0.8460, TestB Precision_background: 0.9540, TestB Recall_flood: 0.6808, TestB Recall_background: 0.9816
# WeightsEpoch: 200, TestBolivia Aug CRF IoU: 0.7339, TestB Accuracy: 0.9368, TestB Dice: 0.8313, TestB Precision: 0.9253, TestB Recall: 0.7787, TestB BalancedAccuracy: 0.7787, TestB IoU_flood: 0.5360, TestB IoU_background: 0.9318, TestB Dice_flood: 0.6980, TestB Dice_background: 0.9647, TestB Precision_flood: 0.9116, TestB Precision_background: 0.9390, TestB Recall_flood: 0.5654, TestB Recall_background: 0.9919
# INFO:testing_logger:WeightsEpoch: 200, TestBolivia Aug CRF IoU: 0.7339, TestB Accuracy: 0.9368, TestB Dice: 0.8313, TestB Precision: 0.9253, TestB Recall: 0.7787, TestB BalancedAccuracy: 0.7787, TestB IoU_flood: 0.5360, TestB IoU_background: 0.9318, TestB Dice_flood: 0.6980, TestB Dice_background: 0.9647, TestB Precision_flood: 0.9116, TestB Precision_background: 0.9390, TestB Recall_flood: 0.5654, TestB Recall_background: 0.9919
